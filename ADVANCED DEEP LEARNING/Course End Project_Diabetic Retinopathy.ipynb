# %% [markdown]
# # Course End Project : Diabetic Retinopathy Detection

# %% [markdown]
# # Academic Institution: SimpliLearn
#
# ## Prgram: PG AI
#
# ## Course No.6: Advanced Deep Learning and Computer Vision
#
# ## Learner : Chaitanya Kumar Battula
#
# ## Academic Advisior: Sayan Dey
#
# ## Submitted on : 08-Jun-2021

# %% [markdown]
# # Tasks
#
# ## Steps to be followed:
#
# ## Download and preprocess the dataset to correct for noise and under and over exposure
#
# ## Augment the dataset and split it into training and test sets
#
# ## Define the distributed training strategy
#
# ## Define the number of shared instances
#
# ## Define a CNN architecture to extract features from the model data
#
# ## Define parameters like the loss, optimizer, epochs, learning rate, and evaluation metric
#
# ## Define checkpoints
#
# ## Train the model until an accuracy of at least 80% is obtained
#
# ## Save the model
#
# ## Deploy the saved model using TensorFlow Serving

# %% [markdown]
# # Step.1    Import Libraries

# %%
import os
import sys
import datetime


from tqdm import tqdm
from cv2 import cv2
from PIL import Image


import numpy as np # linear algebra
from numpy import array
from numpy import savez_compressed
from numpy import load


import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

from imblearn.over_sampling import RandomOverSampler

import tensorflow as tf


import keras
from keras.layers import Dense, Dropout, Flatten, Input 
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.preprocessing import image
from keras.utils import plot_model
from keras.models import Model
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras import backend
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.optimizers import Adam



from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print('>>Imported all required Libraries.')
# Out:
# >>Imported all required Libraries.

# %% [markdown]
# # Step.2     Import data set

# %% [markdown]
# ## Step.2-1   Sample a single image file and understand its attributes

# %%
path=r"C:\Users\USER\1 PGP AI\Diabetic-Retinopathy\Image_dataset\851_left.jpeg"

img = cv2.imread(path)
print("img_type:", type(img))
print("imd_ndim:", img.ndim)
print("img_shape:", img.shape)

img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show
# Out:
# img_type: <class 'numpy.ndarray'>
# imd_ndim: 3
# img_shape: (3264, 4928, 3)
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Step.2-2    Import  a csv file that has the target  labels

# %%
df_train = pd.read_csv('trainLabels.csv')
type(df_train.values)
# Out:
# numpy.ndarray

# %%
df_train.head()
# Out:
#       image  level
# 0   84_left      0
# 1  84_right      0
# 2   95_left      0
# 3  95_right      0
# 4   99_left      3

# %% [markdown]
# Understand that there are MORE than 2nos classes and requires further processing

# %% [markdown]
# ##  Step-2.3        Data  imbalance cheque

# %%
sns.countplot("level",data= df_train)

# %% [markdown]
# Comments:
#
# Data is definitely imbalanced and requires augmentation.

# %% [markdown]
# ## Step  2.3      Extract Features

# %%
y1 = pd.Series(df_train['level'])
y1[0]
# Out:
# 0

# %% [markdown]
# ###  Observation
#
# There are 5types of lables 0/1/2/3/4  or 5nos classes and each stands for as follows
#
# Class — Name
#
# 0 — Normal
#
# 1 — Mild NPDR
#
# 2 — Moderate NPDR
#
# 3 — Severe NPDR
#
# 4 — PDR

# %% [markdown]
# # Step.3-     Load images and labels

# %% [markdown]
# ## Step.3-1   Read Image Names as in Image data set

# %%
i = 0 
for f, breed in tqdm(df_train.values):
    print(f)
# Out:
#  18%|█████████████▌                                                               | 252/1427 [00:00<00:00, 2517.25it/s]
# 84_left
# 84_right
# 95_left
# 95_right
# 99_left
# 99_right
# 842_left
# 842_right
# 844_left
# 844_right
# 845_left
# 845_right
# 851_left
# 851_right
# 857_left
# 857_right
# 862_left
# 862_right
# 863_left
# 863_right
# 865_left
# 865_right
# 866_left
# 866_right
# 869_left
# 869_right
# 876_left
# 876_right
# 877_left
# 877_right
# 878_left
# 878_right
# 879_left
# 879_right
# 880_left
# 880_right
# 885_left
# 885_right
# 886_left
# 886_right
# 897_left
# 897_right
# 899_left
# 899_right
# 904_left
# 904_right
# 905_left
# 905_right
# 906_left
# 906_right
# 909_left
# 909_right
# 910_left
# 910_right
# 912_left
# 912_right
# 914_left
# 914_right
# 916_left
# 916_right
# 917_left
# 917_right
# 921_left
# 921_right
# 925_left
# 925_right
# 928_left
# 928_right
# 929_left
# 929_right
# 930_left
# 930_right
# 931_left
# 931_right
# 932_left
# 932_right
# 934_left
# 934_right
# 935_left
# 935_right
# 936_left
# 936_right
# 939_left
# 939_right
# 940_left
# 940_right
# 941_left
# 941_right
# 943_left
# 943_right
# 945_left
# 945_right
# 947_left
# 947_right
# 953_left
# 953_right
# 958_left
# 958_right
# 959_left
# 959_right
# 960_left
# 960_right
# 963_left
# 963_right
# 966_left
# 966_right
# 967_left
# 967_right
# 968_left
# 968_right
# 969_left
# 969_right
# 970_left
# 970_right
# 971_left
# 971_right
# 977_left
# 977_right
# 978_left
# 978_right
# 979_left
# 979_right
# 980_left
# 980_right
# 983_left
# 983_right
# 985_left
# 985_right
# 986_left
# 986_right
# 987_left
# 987_right
# 990_left
# 990_right
# 992_left
# 992_right
# 994_left
# 994_right
# 997_left
# 997_right
# 998_left
# 998_right
# 8421_left
# 8421_right
# 8424_left
# 8424_right
# 8425_left
# 8425_right
# 8426_left
# 8426_right
# 8430_left
# 8430_right
# 8433_left
# 8433_right
# 8434_left
# 8434_right
# 8439_left
# 8439_right
# 8447_left
# 8447_right
# 8449_left
# 8449_right
# 8451_left
# 8451_right
# 8452_left
# 8452_right
# 8453_left
# 8453_right
# 8455_left
# 8455_right
# 8456_left
# 8456_right
# 8462_left
# 8462_right
# 8466_left
# 8466_right
# 8469_left
# 8469_right
# 8470_left
# 8470_right
# 8471_left
# 8471_right
# 8473_left
# 8473_right
# 8477_left
# 8477_right
# 8479_left
# 8479_right
# 8482_left
# 8482_right
# 8484_left
# 8484_right
# 8486_left
# 8486_right
# 8487_left
# 8487_right
# 8490_left
# 8490_right
# 8492_left
# 8492_right
# 8493_left
# 8493_right
# 8494_left
# 8494_right
# 8495_left
# 8495_right
# 8496_left
# 8496_right
# 8498_left
# 8498_right
# 8499_left
# 8499_right
# 8500_left
# 8500_right
# 8503_left
# 8503_right
# 8504_left
# 8504_right
# 8507_left
# 8507_right
# 8511_left
# 8511_right
# 8513_left
# 8513_right
# 8514_left
# 8514_right
# 8515_left
# 8515_right
# 8517_left
# 8517_right
# 8519_left
# 8519_right
# 8522_left
# 8522_right
# 8526_left
# 8526_right
# 8527_left
# 8527_right
# 8531_left
# 8531_right
# 8532_left
# 8532_right
# 8533_left
# 8533_right
# 8538_left
# 8538_right
# 8539_left
# 8539_right
# 8540_left
# 8540_right
# 8541_left
# 8541_right
# 8543_left
# 8543_right
# 8551_left
# 8551_right
# 8553_left
# 8553_right
# 8554_left
# 8554_right
# 8555_left
# 8555_right
# 8556_left
# 8556_right
# 8558_left
# 8558_right
# 8561_left
# 8561_right
# 8562_left
# 8562_right
# 8565_left
# 8565_right
# 8569_left
# 8569_right
# 8576_left
# 8576_right
# 8578_left
# 8578_right
# 8581_left
# 8581_right
# 8583_left
# 8583_right
# 8585_left
# 8585_right
# 8586_left
# 8586_right
# 8588_left
# 8588_right
# 8589_left
# 8589_right
# 8593_left
# 8593_right
# 8594_left
# 8594_right
# 8596_left
# 8596_right
# 8598_left
# 8598_right
# 8605_left
# 8605_right
# 8610_left
# 8610_right
# 8614_left
# 8614_right
# 8616_left
# 8616_right
# 8619_left
# 8619_right
# 8620_left
# 8620_right
# 8621_left
# 8621_right
# 8623_left
# 8623_right
# 8627_left
# 8627_right
# 8631_left
# 8631_right
# 8632_left
# 8632_right
# 8637_left
# 8637_right
# 8638_left
# 8638_right
# 8640_left
# 8640_right
# 8642_left
# 8642_right
# 8643_left
# 8643_right
# 8644_left
# 8644_right
# 8645_left
# 8645_right
# 8646_left
# 8646_right
# 8649_left
# 8649_right
# 8650_left
# 8650_right
# 8651_left
# 8651_right
# 8652_left
# 8652_right
# 8653_left
# 8653_right
# 8654_left
# 8654_right
# 8655_left
# 8655_right
# 8657_left
# 8657_right
# 8660_left
# 8660_right
# 8662_left
# 8662_right
# 8663_left
# 8663_right
# 8664_left
# 8664_right
# 8666_left
# 8666_right
# 8669_left
# 8669_right
# 8673_left
# 8673_right
# 8675_left
# 8675_right
# 8677_left
# 8677_right
# 8678_left
# 8678_right
# 8679_left
# 8679_right
# 8681_left
# 8681_right
# 8682_left
# 8682_right
# 8683_left
# 8683_right
# 8695_left
# 8695_right
# 8698_left
# 8698_right
# 8699_left
# 8699_right
# 8706_left
# 8706_right
# 8709_left
# 8709_right
# 8711_left
# 8711_right
# 8716_left
# 8716_right
# 8723_left
# 8723_right
# 8726_left
# 8726_right
# 8740_left
# 8740_right
# 8742_left
# 8742_right
# 8743_left
# 8743_right
# 8744_left
# 8744_right
# 8749_left
# 8749_right
# 8752_left
# 8752_right
# 8753_left
# 8753_right
# 8754_left
# 8754_right
# 8755_left
# 8755_right
# 8759_left
# 8759_right
# 8760_left
# 8760_right
# 8762_left
# 8762_right
# 8767_left
# 8767_right
# 8768_left
# 8768_right
# 8769_left
# 8769_right
# 8770_left
# 8770_right
# 8771_left
# 8771_right
# 8776_left
# 8776_right
# 8778_left
# 8778_right
# 8779_left
# 8779_right
# 8781_left
# 8781_right
# 8782_left
# 8782_right
# 8783_left
# 8783_right
# 8784_left
# 8784_right
# 8786_left
# 8786_right
# 8788_left
# 8788_right
# 8789_left
# 8789_right
# 8790_left
# 8790_right
# 8793_left
# 8793_right
# 8794_left
# 8794_right
# 8795_left
# 8795_right
# 8797_left
# 8797_right
# 8798_left
# 8798_right
# 8799_left
# 8799_right
# 8804_left
# 8804_right
# 8806_left
# 8806_right
# 8807_left
# 8807_right
# 8810_left
# 8810_right
# 8812_left
# 8812_right
# 8814_left
# 8814_right
# 8816_left
# 8816_right
# 8817_left
# 8817_right
# 8818_left
# 8818_right
# 8822_left
# 8822_right
# 8825_left
# 8825_right
# 8827_left
# 8827_right
# 8830_left
# 8830_right
# 8831_left
# 8831_right
# 8834_left
# 8834_right
# 8835_left
# 8835_right
# 8837_left
# 8837_right
# 8839_left
# 8839_right
# 8842_left
# 8842_right
# 8843_left
# 8843_right
# 8845_left
# 8845_right
# 8851_left
# 8851_right
# 8852_left
# 8852_right
# 8858_left
# 8858_right
# 8860_left
# 8860_right
# 8864_left
# 8864_right
# 8866_left
# 8866_right
# 8873_left
# 8873_right
# 8874_left
# 8874_right
# 8876_left
# 8876_right
# 8877_left
# 8877_right
# 8878_left
# 8878_right
# 8879_left
# 8879_right
# 8881_left
# 8881_right
# 8882_left
# 8882_right
# 8883_left
# 8883_right
# 8884_left
# 8884_right
# 8885_left
# 8885_right
# 8888_left
# 8888_right
# 8889_left
# 8889_right
# 8893_left
# 8893_right
# 8895_left
# 8895_right
# 8896_left
# 8896_right
# 8897_left
# 8897_right
# 8899_left
# 8899_right
# 8900_left
# 8900_right
# 8906_left
# 8906_right
# 8907_left
# 8907_right
# 8912_left
# 8912_right
# 8914_left
# 8914_right
# 8915_left
# 8915_right
# 8919_left
# 8919_right
# 8927_left
# 8927_right
# 8928_left
# 8928_right
# 8935_left
# 8935_right
# 8936_left
# 8936_right
# 8939_left
# 8939_right
# 8940_left
# 8940_right
# 8945_left
# 8945_right
# 8949_left
# 8949_right
# 8950_left
# 8950_right
# 8951_left
# 8951_right
# 8954_left
# 8954_right
# 8956_left
# 8956_right
# 8958_left
# 8958_right
# 8959_left
# 8959_right
# 8962_left
# 8962_right
# 8964_left
# 8964_right
# 8965_left
# 8965_right
# 8966_left
# 8966_right
# 8967_left
# 8967_right
# 8968_left
# 8968_right
# 8971_left
# 8971_right
# 8974_left
# 8974_right
# 8975_left
# 8975_right
# 8977_left
# 8977_right
# 8981_left
# 8981_right
# 8988_left
# 8988_right
# 8993_left
# 8993_right
# 8995_left
# 8995_right
# 8999_left
# 8999_right
# 9000_left
# 9000_right
# 9001_left
# 9001_right
# 9003_left
# 9003_right
# 9005_left
# 9005_right
# 9008_left
# 9008_right
# 9010_left
# 9010_right
# 9011_left
# 9011_right
# 9015_left
# 9015_right
# 9016_left
# 9016_right
# 9017_left
# 9017_right
# 9020_left
# 9020_right
# 9024_left
# 9024_right
# 9025_left
# 9025_right
# 9033_left
# 9033_right
# 9036_left
# 9036_right
# 9040_left
# 9040_right
# 9042_left
# 9042_right
# 9049_left
# 9049_right
# 9051_left
# 9051_right
# 9063_left
# 9063_right
# 9066_left
# 9066_right
# 9068_left
# 9068_right
# 9069_left
# 9069_right
# 9074_left
# 9074_right
# 9080_left
# 9080_right
# 9082_left
# 9082_right
# 9083_left
# 9083_right
# 9088_left
# 9088_right
# 9092_left
# 9092_right
# 9096_left
# 9096_right
# 9098_left
# 9098_right
# 9099_left
# 9099_right
# 9100_left
# 9100_right
# 9101_left
# 9101_right
# 9103_left
# 9103_right
# 9106_left
# 9106_right
# 9107_left
# 9107_right
# 9115_left
# 9115_right
# 9116_left
# 9116_right
# 9119_left
# 9119_right
# 9120_left
# 9120_right
# 9122_left
# 9122_right
# 9123_left
# 9123_right
# 9126_left
# 9126_right
# 9131_left
# 9131_right
# 9133_left
# 9133_right
# 9134_left
# 9134_right
# 9135_left
# 9135_right
# 9144_left
# 9144_right
# 9145_left
# 9145_right
# 9147_left
# 9147_right
# 9148_left
# 9148_right
# 9151_left
# 9151_right
# 9154_left
# 9154_right
# 9156_left
# 9156_right
# 9157_left
# 9157_right
# 9159_left
# 9159_right
# 9163_left
# 9163_right
# 9166_left
# 9166_right
# 9167_left
# 9167_right
# 9168_left
# 9168_right
# 9173_left
# 9173_right
# 9177_left
# 9177_right
# 9180_left
# 9180_right
# 9183_left
# 9183_right
# 9189_left
# 9189_right
# 9190_left
# 9190_right
# 9198_left
# 9198_right
# 9199_left
# 9199_right
# 9200_left
# 9200_right
# 9203_left
# 9203_right
# 9204_left
# 9204_right
# 9205_left
# 9205_right
# 9207_left
# 9207_right
# 9213_left
# 9213_right
# 9214_left
# 9214_right
# 9216_left
# 9216_right
# 9218_left
# 9218_right
# 9219_left
# 9219_right
# 9220_left
# 9220_right
# 9224_left
# 9224_right
# 9226_left
# 9226_right
# 9232_left
# 9232_right
# 9233_left
# 9233_right
# 9237_left
# 9237_right
# 9238_left
# 9238_right
# 9243_left
# 9243_right
# 9244_left
# 9244_right
# 9251_left
# 9251_right
# 9253_left
# 9253_right
# 9255_left
# 9255_right
# 9257_left
# 9257_right
# 9258_left
# 9258_right
# 9259_left
# 9259_right
# 9266_left
# 9266_right
# 9268_left
# 9268_right
# 9269_left
# 9269_right
# 9271_left
# 9271_right
# 9277_left
# 9277_right
# 9278_left
# 9278_right
# 9279_left
# 9279_right
# 9280_left
# 9280_right
# 9281_left
# 9281_right
# 9282_left
# 9282_right
# 9284_left
# 9284_right
# 9285_left
# 9285_right
# 9287_left
# 9287_right
# 9288_left
# 9288_right
# 9294_left
# 9294_right
# 9297_left
# 9297_right
# 9298_left
# 9298_right
# 9300_left
# 9300_right
# 9307_left
# 9307_right
# 9308_left
# 9308_right
# 9310_left
# 9310_right
# 9311_left
# 9311_right
# 9312_left
# 9312_right
# 9313_left
# 9313_right
# 9317_left
# 9317_right
# 9322_left
# 9322_right
# 9324_left
# 9324_right
# 9325_left
# 9325_right
# 9333_left
# 9333_right
# 9339_left
# 9339_right
# 9340_left
# 9340_right
# 9342_left
# 9342_right
# 9346_left
# 9346_right
# 9348_left
# 9348_right
# 9351_left
# 9351_right
# 9353_left
# 9353_right
# 9358_left
# 9358_right
# 9359_left
# 9359_right
# 9366_left
# 9366_right
# 9368_left
# 9368_right
# 9370_left
# 9370_right
# 9376_left
# 9376_right
# 9377_left
# 9377_right
# 9379_left
# 9379_right
# 9381_left
# 9381_right
# 9382_left
# 9382_right
# 9383_left
# 9383_right
# 9384_left
# 9384_right
# 9390_left
# 9390_right
# 9391_left
# 9391_right
# 9392_left
# 9392_right
# 9396_left
# 9396_right
# 9398_left
# 9398_right
# 9402_left
# 9402_right
# 9404_left
# 9404_right
# 9411_left
# 9411_right
# 9412_left
# 9412_right
# 9419_left
# 9419_right
# 9423_left
# 9423_right
# 9428_left
# 9428_right
# 9448_left
# 9448_right
# 9450_left
# 9450_right
# 9452_left
# 9452_right
# 9454_left
# 9454_right
# 9456_left
# 9456_right
# 9462_left
# 9462_right
# 9463_left
# 9463_right
# 9464_left
# 9464_right
# 9465_left
# 9465_right
# 9467_left
# 9467_right
# 9469_left
# 9469_right
# 9478_left
# 9478_right
# 9485_left
# 9485_right
# 9487_left
# 9487_right
# 9488_left
# 9488_right
# 9490_left
# 9490_right
# 9497_left
# 9497_right
# 100%|████████████████████████████████████████████████████████████████████████████| 1427/1427 [00:00<00:00, 5457.89it/s]
# 9499_left
# 9499_right
# 9502_left
# 9502_right
# 9503_left
# 9503_right
# 9505_left
# 9505_right
# 9507_left
# 9507_right
# 9509_left
# 9509_right
# 9511_left
# 9511_right
# 9513_left
# 9513_right
# 9516_left
# 9516_right
# 9517_left
# 9517_right
# 9518_left
# 9518_right
# 9521_left
# 9521_right
# 9525_left
# 9525_right
# 9526_left
# 9526_right
# 9528_left
# 9528_right
# 9529_left
# 9529_right
# 9535_left
# 9535_right
# 9536_left
# 9536_right
# 9538_left
# 9538_right
# 9539_left
# 9539_right
# 9540_left
# 9540_right
# 9542_left
# 9542_right
# 9544_left
# 9544_right
# 9545_left
# 9545_right
# 9546_left
# 9546_right
# 9547_left
# 9547_right
# 9549_left
# 9549_right
# 9553_left
# 9553_right
# 9555_left
# 9555_right
# 9560_left
# 9560_right
# 9564_left
# 9564_right
# 9566_left
# 9566_right
# 9569_left
# 9569_right
# 9570_left
# 9570_right
# 9573_left
# 9573_right
# 9578_left
# 9578_right
# 9584_left
# 9584_right
# 9586_left
# 9586_right
# 9587_left
# 9587_right
# 9589_left
# 9589_right
# 9590_left
# 9590_right
# 9592_left
# 9592_right
# 9593_left
# 9593_right
# 9595_left
# 9595_right
# 9598_left
# 9598_right
# 9601_left
# 9601_right
# 9602_left
# 9602_right
# 9603_left
# 9603_right
# 9604_left
# 9604_right
# 9608_left
# 9608_right
# 9613_left
# 9613_right
# 9614_left
# 9614_right
# 9616_left
# 9616_right
# 9619_left
# 9619_right
# 9622_left
# 9622_right
# 9626_left
# 9626_right
# 9628_left
# 9628_right
# 9632_left
# 9632_right
# 9633_left
# 9633_right
# 9636_left
# 9636_right
# 9638_left
# 9638_right
# 9640_left
# 9640_right
# 9642_left
# 9642_right
# 9643_left
# 9643_right
# 9646_left
# 9646_right
# 9647_left
# 9647_right
# 9648_left
# 9648_right
# 9649_left
# 9649_right
# 9651_left
# 9651_right
# 9652_left
# 9652_right
# 9653_left
# 9653_right
# 9657_left
# 9657_right
# 9658_left
# 9658_right
# 9659_left
# 9659_right
# 9661_left
# 9661_right
# 9663_left
# 9663_right
# 9665_left
# 9665_right
# 9667_left
# 9667_right
# 9668_left
# 9668_right
# 9670_left
# 9670_right
# 9672_left
# 9672_right
# 9673_left
# 9673_right
# 9680_left
# 9680_right
# 9682_left
# 9682_right
# 9683_left
# 9683_right
# 9684_left
# 9684_right
# 9688_left
# 9688_right
# 9689_left
# 9689_right
# 9690_left
# 9690_right
# 9691_left
# 9691_right
# 9693_left
# 9693_right
# 9694_left
# 9694_right
# 9696_left
# 9696_right
# 9697_left
# 9697_right
# 9698_left
# 9698_right
# 9699_left
# 9699_right
# 9702_left
# 9702_right
# 9705_left
# 9705_right
# 9708_left
# 9708_right
# 9709_left
# 9709_right
# 9713_left
# 9713_right
# 9714_left
# 9714_right
# 9716_left
# 9716_right
# 9717_left
# 9717_right
# 9721_left
# 9721_right
# 9722_left
# 9722_right
# 9724_left
# 9724_right
# 9728_left
# 9728_right
# 9736_left
# 9736_right
# 9737_left
# 9737_right
# 9739_left
# 9739_right
# 9740_left
# 9740_right
# 9741_left
# 9741_right
# 9742_left
# 9742_right
# 9744_left
# 9744_right
# 9747_left
# 9747_right
# 9750_left
# 9750_right
# 9752_left
# 9752_right
# 9755_left
# 9755_right
# 9759_left
# 9759_right
# 9761_left
# 9761_right
# 9764_left
# 9764_right
# 9767_left
# 9767_right
# 9768_left
# 9768_right
# 9772_left
# 9772_right
# 9775_left
# 9775_right
# 9777_left
# 9777_right
# 9779_left
# 9779_right
# 9781_left
# 9781_right
# 9783_left
# 9783_right
# 9785_left
# 9785_right
# 9788_left
# 9788_right
# 9789_left
# 9789_right
# 9793_left
# 9793_right
# 9794_left
# 9794_right
# 9795_left
# 9795_right
# 9796_left
# 9796_right
# 9797_left
# 9797_right
# 9798_left
# 9798_right
# 9799_left
# 9799_right
# 9800_left
# 9800_right
# 9801_left
# 9801_right
# 9804_left
# 9804_right
# 9807_left
# 9807_right
# 9809_left
# 9809_right
# 9810_left
# 9810_right
# 9811_left
# 9811_right
# 9812_left
# 9812_right
# 9813_left
# 9813_right
# 9817_left
# 9817_right
# 9819_left
# 9819_right
# 9821_left
# 9821_right
# 9826_left
# 9826_right
# 9828_left
# 9828_right
# 9830_left
# 9830_right
# 9831_left
# 9831_right
# 9832_left
# 9832_right
# 9840_left
# 9840_right
# 9844_left
# 9844_right
# 9845_left
# 9845_right
# 9846_left
# 9846_right
# 9848_left
# 9848_right
# 9849_left
# 9849_right
# 9853_left
# 9853_right
# 9854_left
# 9854_right
# 9855_left
# 9855_right
# 9857_left
# 9857_right
# 9863_left
# 9863_right
# 9868_left
# 9868_right
# 9869_left
# 9869_right
# 9871_left
# 9871_right
# 9873_left
# 9873_right
# 9874_left
# 9874_right
# 9875_left
# 9875_right
# 9876_left
# 9876_right
# 9878_left
# 9878_right
# 9879_left
# 9879_right
# 9884_left
# 9884_right
# 9889_left
# 9889_right
# 9893_left
# 9893_right
# 9894_left
# 9894_right
# 9895_left
# 9895_right
# 9896_left
# 9896_right
# 9897_left
# 9897_right
# 9899_left
# 9899_right
# 9900_left
# 9900_right
# 9906_left
# 9906_right
# 9907_left
# 9907_right
# 9913_left
# 9913_right
# 9914_left
# 9914_right
# 9919_left
# 9919_right
# 9925_left
# 9925_right
# 9927_left
# 9927_right
# 9929_left
# 9929_right
# 9930_left
# 9930_right
# 9933_left
# 9933_right
# 9934_left
# 9934_right
# 9937_left
# 9937_right
# 9939_left
# 9939_right
# 9940_left
# 9940_right
# 9942_left
# 9942_right
# 9945_left
# 9945_right
# 9947_left
# 9947_right
# 9948_left
# 9948_right
# 9949_left
# 9949_right
# 9951_left
# 9951_right
# 9952_left
# 9952_right
# 9957_left
# 9957_right
# 9958_left
# 9958_right
# 9959_left
# 9959_right
# 9961_left
# 9961_right
# 9963_left
# 9963_right
# 9964_left
# 9964_right
# 9965_left
# 9965_right
# 9966_left
# 9966_right
# 9967_left
# 9967_right
# 9971_left
# 9971_right
# 9972_left
# 9972_right
# 9975_left
# 9975_right
# 9976_left
# 9976_right
# 9977_left
# 9977_right
# 9979_left
# 9979_right
# 9980_left
# 9980_right
# 9984_left
# 9984_right
# 9992_left
# 9992_right
# 9993_left
# 9993_right
# 9996_left
# 9996_right
# 9998_left
# 9998_right
# 9999_left

# %% [markdown]
# ## Step.3-2  Convert jpeg images to numpay array data

# %%
rows = 128
cols = 128

X2 = []
y2 = []


i = 0 
for f, breed in tqdm(df_train.values):
    if type(cv2.imread('Image_dataset/{}.jpeg'.format(f)))==type(None):
        continue
    else:
        img = cv2.imread('Image_dataset/{}.jpeg'.format(f))
        X2.append(cv2.resize(img, (rows, cols)).flatten())
        label = y1[i]
        y2.append(label)
        i += 1

X2 = np.array(X2)    
    
X3 = np.array(X2, dtype='float32')/255
y3 = np.array(y2)



print("X3-Shape:", X3.shape)
print("Y3-Shape:", y3.shape)


print("\n\n\nAll jpeg images converted to numpy arrays.")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1427/1427 [05:01<00:00,  4.74it/s]
# X3-Shape: (1390, 49152)
# Y3-Shape: (1390,)
#
#
#
# All jpeg images converted to numpy arrays.

# %% [markdown]
# # Step.4    Data split  to train and Split

# %%
x_train, x_test, y_train, y_test = train_test_split( X3, y3, test_size=.05, random_state=10)
print("x_train.shape:", x_train.shape)
print("x_test.shape:",   x_test.shape)

print("y_train.shape:", y_train.shape)
print("y_test.shape:",  y_test.shape)
# Out:
# x_train.shape: (1320, 49152)
# x_test.shape: (70, 49152)
# y_train.shape: (1320,)
# y_test.shape: (70,)

# %% [markdown]
# # Step.5   Deal Unbalanced Data

# %% [markdown]
# ##  Step-5.1    Balance data by Over sampling

# %%
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE

smote=SMOTE(sampling_strategy="minority")

X_Over, y_train  = smote.fit_resample(x_train, y_train)

print("< Balancing the Unbalanced data:>")
print()
print("Data size Prior Oversampling:")
print("x_train.shape:", x_train.shape)
print("y_train.shape:", y3.shape)
print()

print("Data size After Oversampling/Balanced:")
print("X_Over.shape:", X_Over.shape )
print("y_train.shape:", y_train.shape )
# Out:
# < Balancing the Unbalanced data:>
#
# Data size Prior Oversampling:
# x_train.shape: (1320, 49152)
# y_train.shape: (1390,)
#
# Data size After Oversampling/Balanced:
# X_Over.shape: (2238, 49152)
# y_train.shape: (2238,)

# %% [markdown]
# ##  Step-5.2    Reshape Data suitably as required for a CNN Model

# %%
Image_Size        = (rows, cols)
Image_Size_List   = list(Image_Size)
Rank = 3
Image_Size_List.append(Rank)

Image_Shape    = tuple(Image_Size_List)
print("Original Single Image Shape:", Image_Shape)
print()



# Reshape the Images
x_train   = X_Over.reshape(X_Over.shape[0], *Image_Shape)
x_test    = x_test.reshape(x_test.shape[0],   *Image_Shape)




print("< DATA SHAPES AFTER  RESHAPING >")
print("\n\n")
print("x_train.shape:", x_train.shape)
print("x_test.shape:",   x_test.shape)

print("\n")
print("y_train.shape:", y_train.shape)
print("y_test.shape:",  y_test.shape)
# Out:
# Original Single Image Shape: (128, 128, 3)
#
# < DATA SHAPES AFTER  RESHAPING >
#
#
#
# x_train.shape: (2238, 128, 128, 3)
# x_test.shape: (70, 128, 128, 3)
#
#
# y_train.shape: (2238,)
# y_test.shape: (70,)

# %% [markdown]
# # Step.6     Define a CNN Model

# %%
CNN_Model= Sequential([ Conv2D(filters=36, kernel_size=2, activation='relu', input_shape= Image_Shape),
                        MaxPooling2D(pool_size=2),
                        Conv2D(filters=54, kernel_size=2, activation='relu', input_shape= Image_Shape),
                        MaxPooling2D(pool_size=2),
                        Conv2D(filters=100, kernel_size=2, activation='relu', input_shape= Image_Shape),
                        MaxPooling2D(pool_size=2),
                        Flatten(),
                        Dense(2048, activation='relu'),
                        Dropout(0.5),
                        Dense(1024, activation='relu'),
                        Dropout(0.5),
                        Dense(512, activation='relu'),
                        Dropout(0.5),
                        Dense(5, activation='softmax')  
                      ])

CNN_Model.compile( loss='sparse_categorical_crossentropy',
                    optimizer=Adam(lr=0.0001),
                    metrics=['accuracy']
                )



CNN_Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 127, 127, 36)      468
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 36)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 62, 62, 54)        7830
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 54)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 100)       21700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 100)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 22500)             0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              46082048
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 48,737,587
# Trainable params: 48,737,587
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Step.7     Train  the Model

# %%
Training_Start_time = datetime.datetime.now()
print("Traing Start Time :",   Training_Start_time )
print("Model training is in Progress. It will take a few hours..Please be patient.\n")


batch_size = 128
epochs = 200
verbose = 2


Model_Training_history = CNN_Model.fit( np.array(x_train), np.array(y_train), 
                         batch_size = batch_size, 
                         epochs = epochs, 
                         verbose = verbose,
                         validation_data = (np.array(x_test), 
                                            np.array(y_test))     )







Training_End_time = datetime.datetime.now()  
time_delta = (Training_End_time - Training_Start_time )
total_seconds = time_delta.total_seconds()
minutes = total_seconds/60




print("Traing Start Time :",   Training_Start_time )
print("Traing End Time   :",   Training_End_time )
print("Total time taken for Training the model(mins):", int(minutes) )
# Out:
# Traing Start Time : 2021-06-08 11:01:13.512210
# Model training is in Progress. It will take a few hours..Please be patient.
#
# Epoch 1/200
# 18/18 - 49s - loss: 1.2971 - accuracy: 0.4039 - val_loss: 1.4015 - val_accuracy: 0.0429
# Epoch 2/200
# 18/18 - 33s - loss: 1.2132 - accuracy: 0.4669 - val_loss: 1.4190 - val_accuracy: 0.1000
# Epoch 3/200
# 18/18 - 33s - loss: 1.1983 - accuracy: 0.4768 - val_loss: 1.3762 - val_accuracy: 0.3286
# Epoch 4/200
# 18/18 - 33s - loss: 1.1668 - accuracy: 0.5022 - val_loss: 1.3737 - val_accuracy: 0.3429
# Epoch 5/200
# 18/18 - 35s - loss: 1.1387 - accuracy: 0.5340 - val_loss: 1.3288 - val_accuracy: 0.4714
# Epoch 6/200
# 18/18 - 35s - loss: 1.0735 - accuracy: 0.6041 - val_loss: 1.3604 - val_accuracy: 0.4714
# Epoch 7/200
# 18/18 - 36s - loss: 1.0221 - accuracy: 0.6466 - val_loss: 1.2851 - val_accuracy: 0.5000
# Epoch 8/200
# 18/18 - 35s - loss: 0.9640 - accuracy: 0.6586 - val_loss: 1.4376 - val_accuracy: 0.4000
# Epoch 9/200
# 18/18 - 34s - loss: 0.9172 - accuracy: 0.6814 - val_loss: 1.1647 - val_accuracy: 0.5857
# Epoch 10/200
# 18/18 - 34s - loss: 0.8811 - accuracy: 0.7038 - val_loss: 1.2892 - val_accuracy: 0.4857
# Epoch 11/200
# 18/18 - 32s - loss: 0.8230 - accuracy: 0.7230 - val_loss: 1.2477 - val_accuracy: 0.5286
# Epoch 12/200
# 18/18 - 33s - loss: 0.8035 - accuracy: 0.7364 - val_loss: 1.3517 - val_accuracy: 0.4857
# Epoch 13/200
# 18/18 - 33s - loss: 0.7716 - accuracy: 0.7458 - val_loss: 1.1059 - val_accuracy: 0.6286
# Epoch 14/200
# 18/18 - 32s - loss: 0.7198 - accuracy: 0.7757 - val_loss: 1.2172 - val_accuracy: 0.5429
# Epoch 15/200
# 18/18 - 32s - loss: 0.6775 - accuracy: 0.7887 - val_loss: 1.1346 - val_accuracy: 0.6000
# Epoch 16/200
# 18/18 - 33s - loss: 0.6457 - accuracy: 0.7971 - val_loss: 1.1649 - val_accuracy: 0.5857
# Epoch 17/200
# 18/18 - 33s - loss: 0.6333 - accuracy: 0.8070 - val_loss: 1.1403 - val_accuracy: 0.6143
# Epoch 18/200
# 18/18 - 32s - loss: 0.5973 - accuracy: 0.8177 - val_loss: 1.1865 - val_accuracy: 0.5857
# Epoch 19/200
# 18/18 - 32s - loss: 0.5941 - accuracy: 0.8235 - val_loss: 1.1401 - val_accuracy: 0.6286
# Epoch 20/200
# 18/18 - 32s - loss: 0.5694 - accuracy: 0.8266 - val_loss: 1.1304 - val_accuracy: 0.6571
# Epoch 21/200
# 18/18 - 32s - loss: 0.5494 - accuracy: 0.8284 - val_loss: 1.1775 - val_accuracy: 0.6286
# Epoch 22/200
# 18/18 - 34s - loss: 0.5407 - accuracy: 0.8315 - val_loss: 1.1612 - val_accuracy: 0.6286
# Epoch 23/200
# 18/18 - 33s - loss: 0.5482 - accuracy: 0.8298 - val_loss: 1.1426 - val_accuracy: 0.6571
# Epoch 24/200
# 18/18 - 33s - loss: 0.5339 - accuracy: 0.8320 - val_loss: 1.1184 - val_accuracy: 0.6714
# Epoch 25/200
# 18/18 - 33s - loss: 0.5278 - accuracy: 0.8320 - val_loss: 1.1544 - val_accuracy: 0.6571
# Epoch 26/200
# 18/18 - 33s - loss: 0.5236 - accuracy: 0.8378 - val_loss: 1.1296 - val_accuracy: 0.6571
# Epoch 27/200
# 18/18 - 33s - loss: 0.5140 - accuracy: 0.8387 - val_loss: 1.1559 - val_accuracy: 0.6571
# Epoch 28/200
# 18/18 - 34s - loss: 0.5073 - accuracy: 0.8391 - val_loss: 1.1584 - val_accuracy: 0.6571
# Epoch 29/200
# 18/18 - 33s - loss: 0.5111 - accuracy: 0.8378 - val_loss: 1.1539 - val_accuracy: 0.6571
# Epoch 30/200
# 18/18 - 34s - loss: 0.4969 - accuracy: 0.8391 - val_loss: 1.1685 - val_accuracy: 0.6571
# Epoch 31/200
# 18/18 - 33s - loss: 0.5040 - accuracy: 0.8396 - val_loss: 1.1981 - val_accuracy: 0.6571
# Epoch 32/200
# 18/18 - 32s - loss: 0.4904 - accuracy: 0.8414 - val_loss: 1.1636 - val_accuracy: 0.6571
# Epoch 33/200
# 18/18 - 33s - loss: 0.4969 - accuracy: 0.8405 - val_loss: 1.1818 - val_accuracy: 0.6571
# Epoch 34/200
# 18/18 - 32s - loss: 0.4963 - accuracy: 0.8374 - val_loss: 1.1540 - val_accuracy: 0.6571
# Epoch 35/200
# 18/18 - 32s - loss: 0.4884 - accuracy: 0.8405 - val_loss: 1.1971 - val_accuracy: 0.6571
# Epoch 36/200
# 18/18 - 32s - loss: 0.4869 - accuracy: 0.8418 - val_loss: 1.1952 - val_accuracy: 0.6571
# Epoch 37/200
# 18/18 - 32s - loss: 0.4836 - accuracy: 0.8418 - val_loss: 1.1908 - val_accuracy: 0.6571
# Epoch 38/200
# 18/18 - 32s - loss: 0.4740 - accuracy: 0.8414 - val_loss: 1.1550 - val_accuracy: 0.6571
# Epoch 39/200
# 18/18 - 33s - loss: 0.4720 - accuracy: 0.8432 - val_loss: 1.1621 - val_accuracy: 0.6429
# Epoch 40/200
# 18/18 - 33s - loss: 0.4738 - accuracy: 0.8427 - val_loss: 1.1966 - val_accuracy: 0.6571
# Epoch 41/200
# 18/18 - 33s - loss: 0.4690 - accuracy: 0.8427 - val_loss: 1.1692 - val_accuracy: 0.6571
# Epoch 42/200
# 18/18 - 33s - loss: 0.4583 - accuracy: 0.8436 - val_loss: 1.2118 - val_accuracy: 0.6571
# Epoch 43/200
# 18/18 - 32s - loss: 0.4631 - accuracy: 0.8445 - val_loss: 1.1653 - val_accuracy: 0.6571
# Epoch 44/200
# 18/18 - 32s - loss: 0.4649 - accuracy: 0.8414 - val_loss: 1.1790 - val_accuracy: 0.6714
# Epoch 45/200
# 18/18 - 32s - loss: 0.4594 - accuracy: 0.8423 - val_loss: 1.1887 - val_accuracy: 0.6571
# Epoch 46/200
# 18/18 - 33s - loss: 0.4575 - accuracy: 0.8450 - val_loss: 1.1930 - val_accuracy: 0.6571
# Epoch 47/200
# 18/18 - 32s - loss: 0.4530 - accuracy: 0.8445 - val_loss: 1.2472 - val_accuracy: 0.6429
# Epoch 48/200
# 18/18 - 32s - loss: 0.4552 - accuracy: 0.8436 - val_loss: 1.1699 - val_accuracy: 0.6571
# Epoch 49/200
# 18/18 - 32s - loss: 0.4592 - accuracy: 0.8427 - val_loss: 1.2090 - val_accuracy: 0.6429
# Epoch 50/200
# 18/18 - 33s - loss: 0.4492 - accuracy: 0.8450 - val_loss: 1.1620 - val_accuracy: 0.6714
# Epoch 51/200
# 18/18 - 32s - loss: 0.4473 - accuracy: 0.8458 - val_loss: 1.1737 - val_accuracy: 0.6571
# Epoch 52/200
# 18/18 - 33s - loss: 0.4457 - accuracy: 0.8450 - val_loss: 1.1926 - val_accuracy: 0.6571
# Epoch 53/200
# 18/18 - 33s - loss: 0.4444 - accuracy: 0.8445 - val_loss: 1.1942 - val_accuracy: 0.6571
# Epoch 54/200
# 18/18 - 32s - loss: 0.4422 - accuracy: 0.8450 - val_loss: 1.2091 - val_accuracy: 0.6571
# Epoch 55/200
# 18/18 - 32s - loss: 0.4400 - accuracy: 0.8463 - val_loss: 1.3017 - val_accuracy: 0.6286
# Epoch 56/200
# 18/18 - 32s - loss: 0.4447 - accuracy: 0.8436 - val_loss: 1.1997 - val_accuracy: 0.6714
# Epoch 57/200
# 18/18 - 33s - loss: 0.4412 - accuracy: 0.8436 - val_loss: 1.2314 - val_accuracy: 0.6429
# Epoch 58/200
# 18/18 - 34s - loss: 0.4322 - accuracy: 0.8454 - val_loss: 1.2661 - val_accuracy: 0.6429
# Epoch 59/200
# 18/18 - 33s - loss: 0.4268 - accuracy: 0.8463 - val_loss: 1.1985 - val_accuracy: 0.6714
# Epoch 60/200
# 18/18 - 33s - loss: 0.4240 - accuracy: 0.8458 - val_loss: 1.2995 - val_accuracy: 0.6286
# Epoch 61/200
# 18/18 - 32s - loss: 0.4147 - accuracy: 0.8463 - val_loss: 1.2440 - val_accuracy: 0.6429
# Epoch 62/200
# 18/18 - 32s - loss: 0.4238 - accuracy: 0.8454 - val_loss: 1.2885 - val_accuracy: 0.6286
# Epoch 63/200
# 18/18 - 32s - loss: 0.4238 - accuracy: 0.8481 - val_loss: 1.2250 - val_accuracy: 0.6714
# Epoch 64/200
# 18/18 - 33s - loss: 0.4129 - accuracy: 0.8494 - val_loss: 1.2448 - val_accuracy: 0.6429
# Epoch 65/200
# 18/18 - 33s - loss: 0.4074 - accuracy: 0.8521 - val_loss: 1.2487 - val_accuracy: 0.6714
# Epoch 66/200
# 18/18 - 33s - loss: 0.4004 - accuracy: 0.8534 - val_loss: 1.2777 - val_accuracy: 0.6714
# Epoch 67/200
# 18/18 - 32s - loss: 0.4085 - accuracy: 0.8481 - val_loss: 1.2447 - val_accuracy: 0.6429
# Epoch 68/200
# 18/18 - 32s - loss: 0.3961 - accuracy: 0.8508 - val_loss: 1.2333 - val_accuracy: 0.6714
# Epoch 69/200
# 18/18 - 33s - loss: 0.3888 - accuracy: 0.8557 - val_loss: 1.3306 - val_accuracy: 0.6286
# Epoch 70/200
# 18/18 - 32s - loss: 0.3976 - accuracy: 0.8521 - val_loss: 1.2580 - val_accuracy: 0.6714
# Epoch 71/200
# 18/18 - 32s - loss: 0.3915 - accuracy: 0.8552 - val_loss: 1.2551 - val_accuracy: 0.6429
# Epoch 72/200
# 18/18 - 34s - loss: 0.3825 - accuracy: 0.8485 - val_loss: 1.3220 - val_accuracy: 0.6286
# Epoch 73/200
# 18/18 - 32s - loss: 0.3936 - accuracy: 0.8539 - val_loss: 1.3105 - val_accuracy: 0.6286
# Epoch 74/200
# 18/18 - 32s - loss: 0.3910 - accuracy: 0.8525 - val_loss: 1.2701 - val_accuracy: 0.6286
# Epoch 75/200
# 18/18 - 32s - loss: 0.3722 - accuracy: 0.8557 - val_loss: 1.3422 - val_accuracy: 0.6429
# Epoch 76/200
# 18/18 - 32s - loss: 0.3603 - accuracy: 0.8592 - val_loss: 1.3864 - val_accuracy: 0.6286
# Epoch 77/200
# 18/18 - 32s - loss: 0.3633 - accuracy: 0.8606 - val_loss: 1.3918 - val_accuracy: 0.6429
# Epoch 78/200
# 18/18 - 33s - loss: 0.3502 - accuracy: 0.8691 - val_loss: 1.3594 - val_accuracy: 0.6571
# Epoch 79/200
# 18/18 - 32s - loss: 0.3579 - accuracy: 0.8664 - val_loss: 1.3673 - val_accuracy: 0.6429
# Epoch 80/200
# 18/18 - 33s - loss: 0.3428 - accuracy: 0.8691 - val_loss: 1.3446 - val_accuracy: 0.6714
# Epoch 81/200
# 18/18 - 32s - loss: 0.3459 - accuracy: 0.8695 - val_loss: 1.4971 - val_accuracy: 0.6286
# Epoch 82/200
# 18/18 - 33s - loss: 0.3261 - accuracy: 0.8780 - val_loss: 1.3958 - val_accuracy: 0.6286
# Epoch 83/200
# 18/18 - 32s - loss: 0.3292 - accuracy: 0.8744 - val_loss: 1.3275 - val_accuracy: 0.6571
# Epoch 84/200
# 18/18 - 33s - loss: 0.3217 - accuracy: 0.8771 - val_loss: 1.3656 - val_accuracy: 0.6571
# Epoch 85/200
# 18/18 - 32s - loss: 0.3168 - accuracy: 0.8816 - val_loss: 1.3539 - val_accuracy: 0.5857
# Epoch 86/200
# 18/18 - 33s - loss: 0.3234 - accuracy: 0.8718 - val_loss: 1.4897 - val_accuracy: 0.6000
# Epoch 87/200
# 18/18 - 33s - loss: 0.3201 - accuracy: 0.8780 - val_loss: 1.3961 - val_accuracy: 0.6286
# Epoch 88/200
# 18/18 - 32s - loss: 0.3053 - accuracy: 0.8847 - val_loss: 1.4479 - val_accuracy: 0.6286
# Epoch 89/200
# 18/18 - 33s - loss: 0.2777 - accuracy: 0.8999 - val_loss: 1.4002 - val_accuracy: 0.7143
# Epoch 90/200
# 18/18 - 33s - loss: 0.2846 - accuracy: 0.8901 - val_loss: 1.3075 - val_accuracy: 0.6429
# Epoch 91/200
# 18/18 - 33s - loss: 0.2854 - accuracy: 0.8959 - val_loss: 1.3946 - val_accuracy: 0.6429
# Epoch 92/200
# 18/18 - 33s - loss: 0.2778 - accuracy: 0.8977 - val_loss: 1.4951 - val_accuracy: 0.6429
# Epoch 93/200
# 18/18 - 32s - loss: 0.2742 - accuracy: 0.9013 - val_loss: 1.5168 - val_accuracy: 0.6429
# Epoch 94/200
# 18/18 - 33s - loss: 0.2737 - accuracy: 0.8954 - val_loss: 1.7320 - val_accuracy: 0.6000
# Epoch 95/200
# 18/18 - 32s - loss: 0.2484 - accuracy: 0.9102 - val_loss: 1.5902 - val_accuracy: 0.6429
# Epoch 96/200
# 18/18 - 32s - loss: 0.2381 - accuracy: 0.9160 - val_loss: 1.5634 - val_accuracy: 0.6286
# Epoch 97/200
# 18/18 - 33s - loss: 0.2347 - accuracy: 0.9142 - val_loss: 1.5475 - val_accuracy: 0.6714
# Epoch 98/200
# 18/18 - 33s - loss: 0.2224 - accuracy: 0.9236 - val_loss: 1.5631 - val_accuracy: 0.6286
# Epoch 99/200
# 18/18 - 32s - loss: 0.2163 - accuracy: 0.9205 - val_loss: 1.8052 - val_accuracy: 0.5857
# Epoch 100/200
# 18/18 - 32s - loss: 0.2175 - accuracy: 0.9218 - val_loss: 1.7190 - val_accuracy: 0.6286
# Epoch 101/200
# 18/18 - 32s - loss: 0.2032 - accuracy: 0.9245 - val_loss: 1.8016 - val_accuracy: 0.5714
# Epoch 102/200
# 18/18 - 32s - loss: 0.2001 - accuracy: 0.9285 - val_loss: 2.0086 - val_accuracy: 0.6000
# Epoch 103/200
# 18/18 - 32s - loss: 0.1983 - accuracy: 0.9316 - val_loss: 1.7780 - val_accuracy: 0.6143
# Epoch 104/200
# 18/18 - 32s - loss: 0.2024 - accuracy: 0.9267 - val_loss: 1.8023 - val_accuracy: 0.6000
# Epoch 105/200
# 18/18 - 32s - loss: 0.1873 - accuracy: 0.9316 - val_loss: 1.7902 - val_accuracy: 0.6429
# Epoch 106/200
# 18/18 - 33s - loss: 0.1718 - accuracy: 0.9379 - val_loss: 1.7268 - val_accuracy: 0.5857
# Epoch 107/200
# 18/18 - 32s - loss: 0.1684 - accuracy: 0.9374 - val_loss: 1.7021 - val_accuracy: 0.6286
# Epoch 108/200
# 18/18 - 32s - loss: 0.1761 - accuracy: 0.9330 - val_loss: 1.8381 - val_accuracy: 0.6286
# Epoch 109/200
# 18/18 - 33s - loss: 0.1765 - accuracy: 0.9361 - val_loss: 1.9211 - val_accuracy: 0.5571
# Epoch 110/200
# 18/18 - 33s - loss: 0.1574 - accuracy: 0.9464 - val_loss: 2.1167 - val_accuracy: 0.6143
# Epoch 111/200
# 18/18 - 33s - loss: 0.1593 - accuracy: 0.9464 - val_loss: 1.8226 - val_accuracy: 0.6000
# Epoch 112/200
# 18/18 - 32s - loss: 0.1466 - accuracy: 0.9437 - val_loss: 1.8502 - val_accuracy: 0.6000
# Epoch 113/200
# 18/18 - 32s - loss: 0.1425 - accuracy: 0.9531 - val_loss: 1.9894 - val_accuracy: 0.6286
# Epoch 114/200
# 18/18 - 33s - loss: 0.1297 - accuracy: 0.9558 - val_loss: 2.1203 - val_accuracy: 0.6000
# Epoch 115/200
# 18/18 - 34s - loss: 0.1366 - accuracy: 0.9495 - val_loss: 1.9166 - val_accuracy: 0.6286
# Epoch 116/200
# 18/18 - 33s - loss: 0.1346 - accuracy: 0.9535 - val_loss: 1.9628 - val_accuracy: 0.6286
# Epoch 117/200
# 18/18 - 32s - loss: 0.1339 - accuracy: 0.9553 - val_loss: 1.8175 - val_accuracy: 0.6143
# Epoch 118/200
# 18/18 - 32s - loss: 0.1347 - accuracy: 0.9508 - val_loss: 2.1301 - val_accuracy: 0.5714
# Epoch 119/200
# 18/18 - 32s - loss: 0.1119 - accuracy: 0.9638 - val_loss: 2.1449 - val_accuracy: 0.6000
# Epoch 120/200
# 18/18 - 33s - loss: 0.1275 - accuracy: 0.9526 - val_loss: 2.0722 - val_accuracy: 0.6000
# Epoch 121/200
# 18/18 - 32s - loss: 0.1029 - accuracy: 0.9692 - val_loss: 2.2038 - val_accuracy: 0.6000
# Epoch 122/200
# 18/18 - 33s - loss: 0.0944 - accuracy: 0.9705 - val_loss: 2.1488 - val_accuracy: 0.6143
# Epoch 123/200
# 18/18 - 33s - loss: 0.0891 - accuracy: 0.9692 - val_loss: 2.2096 - val_accuracy: 0.6286
# Epoch 124/200
# 18/18 - 33s - loss: 0.0869 - accuracy: 0.9710 - val_loss: 2.3600 - val_accuracy: 0.5857
# Epoch 125/200
# 18/18 - 33s - loss: 0.0829 - accuracy: 0.9736 - val_loss: 2.3511 - val_accuracy: 0.6000
# Epoch 126/200
# 18/18 - 33s - loss: 0.0788 - accuracy: 0.9763 - val_loss: 2.3233 - val_accuracy: 0.5714
# Epoch 127/200
# 18/18 - 33s - loss: 0.0827 - accuracy: 0.9732 - val_loss: 2.4528 - val_accuracy: 0.6429
# Epoch 128/200
# 18/18 - 33s - loss: 0.0970 - accuracy: 0.9665 - val_loss: 2.5164 - val_accuracy: 0.5286
# Epoch 129/200
# 18/18 - 33s - loss: 0.1007 - accuracy: 0.9714 - val_loss: 2.3920 - val_accuracy: 0.5857
# Epoch 130/200
# 18/18 - 33s - loss: 0.0695 - accuracy: 0.9786 - val_loss: 2.3146 - val_accuracy: 0.6143
# Epoch 131/200
# 18/18 - 33s - loss: 0.0681 - accuracy: 0.9799 - val_loss: 2.4423 - val_accuracy: 0.6429
# Epoch 132/200
# 18/18 - 33s - loss: 0.0800 - accuracy: 0.9727 - val_loss: 2.5821 - val_accuracy: 0.5571
# Epoch 133/200
# 18/18 - 32s - loss: 0.0757 - accuracy: 0.9768 - val_loss: 2.3823 - val_accuracy: 0.5429
# Epoch 134/200
# 18/18 - 32s - loss: 0.0656 - accuracy: 0.9772 - val_loss: 2.2139 - val_accuracy: 0.6143
# Epoch 135/200
# 18/18 - 33s - loss: 0.0662 - accuracy: 0.9759 - val_loss: 2.2882 - val_accuracy: 0.5857
# Epoch 136/200
# 18/18 - 33s - loss: 0.0551 - accuracy: 0.9848 - val_loss: 2.5219 - val_accuracy: 0.5857
# Epoch 137/200
# 18/18 - 33s - loss: 0.0643 - accuracy: 0.9786 - val_loss: 2.5929 - val_accuracy: 0.6000
# Epoch 138/200
# 18/18 - 33s - loss: 0.0610 - accuracy: 0.9817 - val_loss: 2.5420 - val_accuracy: 0.6143
# Epoch 139/200
# 18/18 - 33s - loss: 0.0526 - accuracy: 0.9844 - val_loss: 2.5381 - val_accuracy: 0.6286
# Epoch 140/200
# 18/18 - 33s - loss: 0.0529 - accuracy: 0.9794 - val_loss: 2.5537 - val_accuracy: 0.5857
# Epoch 141/200
# 18/18 - 33s - loss: 0.0428 - accuracy: 0.9866 - val_loss: 2.5473 - val_accuracy: 0.6143
# Epoch 142/200
# 18/18 - 32s - loss: 0.0460 - accuracy: 0.9839 - val_loss: 2.5847 - val_accuracy: 0.6286
# Epoch 143/200
# 18/18 - 33s - loss: 0.0472 - accuracy: 0.9861 - val_loss: 2.6724 - val_accuracy: 0.5714
# Epoch 144/200
# 18/18 - 32s - loss: 0.0457 - accuracy: 0.9888 - val_loss: 2.5852 - val_accuracy: 0.6143
# Epoch 145/200
# 18/18 - 32s - loss: 0.0470 - accuracy: 0.9848 - val_loss: 2.5783 - val_accuracy: 0.5714
# Epoch 146/200
# 18/18 - 33s - loss: 0.0435 - accuracy: 0.9875 - val_loss: 2.7809 - val_accuracy: 0.5857
# Epoch 147/200
# 18/18 - 32s - loss: 0.0383 - accuracy: 0.9902 - val_loss: 2.6664 - val_accuracy: 0.6429
# Epoch 148/200
# 18/18 - 32s - loss: 0.0388 - accuracy: 0.9906 - val_loss: 2.6871 - val_accuracy: 0.5429
# Epoch 149/200
# 18/18 - 33s - loss: 0.0480 - accuracy: 0.9879 - val_loss: 2.5752 - val_accuracy: 0.5714
# Epoch 150/200
# 18/18 - 32s - loss: 0.0439 - accuracy: 0.9870 - val_loss: 2.6343 - val_accuracy: 0.6571
# Epoch 151/200
# 18/18 - 33s - loss: 0.0446 - accuracy: 0.9861 - val_loss: 2.5833 - val_accuracy: 0.5714
# Epoch 152/200
# 18/18 - 32s - loss: 0.0456 - accuracy: 0.9879 - val_loss: 2.5738 - val_accuracy: 0.6000
# Epoch 153/200
# 18/18 - 33s - loss: 0.0443 - accuracy: 0.9853 - val_loss: 2.6538 - val_accuracy: 0.6000
# Epoch 154/200
# 18/18 - 33s - loss: 0.0440 - accuracy: 0.9888 - val_loss: 2.9116 - val_accuracy: 0.6000
# Epoch 155/200
# 18/18 - 33s - loss: 0.0297 - accuracy: 0.9906 - val_loss: 2.5460 - val_accuracy: 0.6000
# Epoch 156/200
# 18/18 - 32s - loss: 0.0322 - accuracy: 0.9902 - val_loss: 2.7384 - val_accuracy: 0.5857
# Epoch 157/200
# 18/18 - 32s - loss: 0.0319 - accuracy: 0.9911 - val_loss: 2.9070 - val_accuracy: 0.5714
# Epoch 158/200
# 18/18 - 32s - loss: 0.0225 - accuracy: 0.9955 - val_loss: 2.4800 - val_accuracy: 0.6286
# Epoch 159/200
# 18/18 - 32s - loss: 0.0255 - accuracy: 0.9933 - val_loss: 2.6846 - val_accuracy: 0.5714
# Epoch 160/200
# 18/18 - 32s - loss: 0.0282 - accuracy: 0.9906 - val_loss: 2.9009 - val_accuracy: 0.6429
# Epoch 161/200
# 18/18 - 32s - loss: 0.0292 - accuracy: 0.9906 - val_loss: 2.7788 - val_accuracy: 0.5714
# Epoch 162/200
# 18/18 - 33s - loss: 0.0248 - accuracy: 0.9942 - val_loss: 2.7673 - val_accuracy: 0.5714
# Epoch 163/200
# 18/18 - 33s - loss: 0.0202 - accuracy: 0.9969 - val_loss: 2.7714 - val_accuracy: 0.5714
# Epoch 164/200
# 18/18 - 33s - loss: 0.0143 - accuracy: 0.9969 - val_loss: 2.9518 - val_accuracy: 0.5714
# Epoch 165/200
# 18/18 - 32s - loss: 0.0133 - accuracy: 0.9973 - val_loss: 3.0679 - val_accuracy: 0.6143
# Epoch 166/200
# 18/18 - 32s - loss: 0.0148 - accuracy: 0.9978 - val_loss: 3.0110 - val_accuracy: 0.6143
# Epoch 167/200
# 18/18 - 32s - loss: 0.0152 - accuracy: 0.9969 - val_loss: 3.2916 - val_accuracy: 0.5857
# Epoch 168/200
# 18/18 - 33s - loss: 0.0251 - accuracy: 0.9920 - val_loss: 2.8051 - val_accuracy: 0.6571
# Epoch 169/200
# 18/18 - 32s - loss: 0.0181 - accuracy: 0.9937 - val_loss: 2.9747 - val_accuracy: 0.6000
# Epoch 170/200
# 18/18 - 32s - loss: 0.0226 - accuracy: 0.9942 - val_loss: 2.9653 - val_accuracy: 0.6286
# Epoch 171/200
# 18/18 - 33s - loss: 0.0226 - accuracy: 0.9933 - val_loss: 3.1304 - val_accuracy: 0.5857
# Epoch 172/200
# 18/18 - 32s - loss: 0.0199 - accuracy: 0.9960 - val_loss: 2.9694 - val_accuracy: 0.5857
# Epoch 173/200
# 18/18 - 32s - loss: 0.0232 - accuracy: 0.9942 - val_loss: 3.4146 - val_accuracy: 0.6143
# Epoch 174/200
# 18/18 - 33s - loss: 0.0291 - accuracy: 0.9906 - val_loss: 3.0802 - val_accuracy: 0.6000
# Epoch 175/200
# 18/18 - 33s - loss: 0.0343 - accuracy: 0.9866 - val_loss: 3.2951 - val_accuracy: 0.5143
# Epoch 176/200
# 18/18 - 32s - loss: 0.0318 - accuracy: 0.9879 - val_loss: 2.8294 - val_accuracy: 0.6000
# Epoch 177/200
# 18/18 - 33s - loss: 0.0322 - accuracy: 0.9902 - val_loss: 2.9434 - val_accuracy: 0.6000
# Epoch 178/200
# 18/18 - 33s - loss: 0.0267 - accuracy: 0.9915 - val_loss: 2.9842 - val_accuracy: 0.6000
# Epoch 179/200
# 18/18 - 34s - loss: 0.0192 - accuracy: 0.9964 - val_loss: 3.2350 - val_accuracy: 0.5857
# Epoch 180/200
# 18/18 - 33s - loss: 0.0182 - accuracy: 0.9942 - val_loss: 3.2151 - val_accuracy: 0.5857
# Epoch 181/200
# 18/18 - 33s - loss: 0.0149 - accuracy: 0.9973 - val_loss: 3.3701 - val_accuracy: 0.6000
# Epoch 182/200
# 18/18 - 32s - loss: 0.0215 - accuracy: 0.9933 - val_loss: 3.2458 - val_accuracy: 0.5857
# Epoch 183/200
# 18/18 - 32s - loss: 0.0217 - accuracy: 0.9937 - val_loss: 2.9775 - val_accuracy: 0.6000
# Epoch 184/200
# 18/18 - 32s - loss: 0.0248 - accuracy: 0.9942 - val_loss: 2.9103 - val_accuracy: 0.5571
# Epoch 185/200
# 18/18 - 32s - loss: 0.0206 - accuracy: 0.9929 - val_loss: 3.1786 - val_accuracy: 0.6000
# Epoch 186/200
# 18/18 - 32s - loss: 0.0195 - accuracy: 0.9933 - val_loss: 3.4712 - val_accuracy: 0.6143
# Epoch 187/200
# 18/18 - 32s - loss: 0.0269 - accuracy: 0.9915 - val_loss: 3.1433 - val_accuracy: 0.5857
# Epoch 188/200
# 18/18 - 32s - loss: 0.0165 - accuracy: 0.9951 - val_loss: 3.0846 - val_accuracy: 0.6143
# Epoch 189/200
# 18/18 - 32s - loss: 0.0144 - accuracy: 0.9973 - val_loss: 3.1549 - val_accuracy: 0.5286
# Epoch 190/200
# 18/18 - 32s - loss: 0.0147 - accuracy: 0.9978 - val_loss: 3.1093 - val_accuracy: 0.6000
# Epoch 191/200
# 18/18 - 32s - loss: 0.0115 - accuracy: 0.9973 - val_loss: 3.0678 - val_accuracy: 0.6000
# Epoch 192/200
# 18/18 - 32s - loss: 0.0104 - accuracy: 0.9982 - val_loss: 3.4267 - val_accuracy: 0.5857
# Epoch 193/200
# 18/18 - 34s - loss: 0.0102 - accuracy: 0.9978 - val_loss: 3.1560 - val_accuracy: 0.5714
# Epoch 194/200
# 18/18 - 34s - loss: 0.0170 - accuracy: 0.9964 - val_loss: 3.4013 - val_accuracy: 0.4857
# Epoch 195/200
# 18/18 - 34s - loss: 0.0230 - accuracy: 0.9937 - val_loss: 3.1423 - val_accuracy: 0.5714
# Epoch 196/200
# 18/18 - 32s - loss: 0.0170 - accuracy: 0.9951 - val_loss: 3.0981 - val_accuracy: 0.6143
# Epoch 197/200
# 18/18 - 32s - loss: 0.0134 - accuracy: 0.9960 - val_loss: 3.2177 - val_accuracy: 0.6143
# Epoch 198/200
# 18/18 - 33s - loss: 0.0111 - accuracy: 0.9964 - val_loss: 3.1549 - val_accuracy: 0.6000
# Epoch 199/200
# 18/18 - 33s - loss: 0.0150 - accuracy: 0.9973 - val_loss: 2.9648 - val_accuracy: 0.5714
# Epoch 200/200
# 18/18 - 32s - loss: 0.0093 - accuracy: 0.9982 - val_loss: 3.1887 - val_accuracy: 0.6286
# Traing Start Time : 2021-06-08 11:01:13.512210
# Traing End Time   : 2021-06-08 12:50:23.075169
# Total time taken for Training the model(mins): 109

# %% [markdown]
# # Step.8     Test  various metrices

# %% [markdown]
# ##  Step.8-1   Accuracy

# %%
Score = CNN_Model.evaluate( np.array(x_test),  
                            np.array(y_test), 
                            verbose=0
                          )

Loss      =  Score[0] * 100
Accuracy  =  Score[1] * 100


print("< Model Evalaution Results  >")
print('   Loss     :   {:.2f} %'.format(Loss))
print('   Accuracy :   {:.2f} %'.format(Accuracy))
# Out:
# < Model Evalaution Results  >
#    Test accuracy :   62.86 %

# %%
print(Model_Training_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ####      Parametrs   required   for  graphical  plot    of accuracy and loss

# %%
# PARAMEETRS  FOR  GRAPHICAL PLOT
accuracy     =  Model_Training_history.history['accuracy']
val_accuracy =  Model_Training_history.history['val_accuracy']

loss         =  Model_Training_history.history['loss']
val_loss     =  Model_Training_history.history['val_loss']

# %% [markdown]
# ##  Step.8-2     Plot Model  Accuracy

# %%
# PLOT  MODEL  ACCURACY
plt.figure(figsize=(15,6))
plt.plot(accuracy)
plt.plot(val_accuracy )
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'vlidate'], loc='upper left')
plt.savefig('Model Accuracy.png', dpi=300, bbox_inches='tight')
plt.show()
print()

# %% [markdown]
# ##  Step.8-2     Plot Model  Loss

# %%
# PLOT  MODEL  LOSS
plt.figure(figsize=(15,6))
plt.plot(loss)
plt.plot(val_loss)
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validate'], loc='upper left')
plt.savefig('Model Loss.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ##  Step.8-3     Confusion Matrix

# %%
y_predicted = CNN_Model.predict_classes(x_test)
print("< Confusion matrix  >\n%s" % confusion_matrix(np.array(y_test), y_predicted))
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# < Confusion matrix  >
# [[41  1  4  2  0]
#  [ 5  1  2  0  0]
#  [ 8  0  2  0  0]
#  [ 3  0  0  0  0]
#  [ 1  0  0  0  0]]

# %% [markdown]
# ###    View Confusion Matrix in a Cross Table

# %%
pd.crosstab(y_test, y_predicted, rownames = ['Actual'], colnames =['Predicted'], margins = True)
# Out:
# Predicted   0  1  2  3  All
# Actual
# 0          41  1  4  2   48
# 1           5  1  2  0    8
# 2           8  0  2  0   10
# 3           3  0  0  0    3
# 4           1  0  0  0    1
# All        58  2  8  2   70

# %% [markdown]
# ###   View Confusion Matrix Results  in a graphical representation

# %%
def plot_cm(y_true, y_pred, figsize=(20,10)):
    cm = confusion_matrix(y_true, y_pred, labels=np.unique(y_true))
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=np.unique(y_true), columns=np.unique(y_true))
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, cmap= "YlGnBu", annot=annot, fmt='', ax=ax)
    
plot_cm(y_test, y_predicted)

# %%
y_predicted = CNN_Model.predict_classes(x_test)
# print("y_predicted :", y_predicted )
Accuracy = accuracy_score(y_test, y_predicted)
print(" Model accuracy: %.1f %%" % (Accuracy*100))
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#  Model accuracy: 62.9 %

# %% [markdown]
# ##  Step.8-     Classification Report

# %%
print("< Classification Report >\n")
print(classification_report(np.array(y_test), y_predicted))
# Out:
# < Classification Report >
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77        48
#            1       0.50      0.12      0.20         8
#            2       0.25      0.20      0.22        10
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.63        70
#    macro avg       0.29      0.24      0.24        70
# weighted avg       0.58      0.63      0.59        70
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #  9.   Save Model and Deploy to

# %% [markdown]
# ##  9.1   Save model

# %%
CNN_Model.save("Diabetic_Retinopathy_Model.h5")

print("Model Saved to Disk.")
# Out:
# Model Saved to Disk.

# %% [markdown]
# ##  9.2   Load Model from disk

# %%
from keras.models import load_model


# Load Model
model = load_model('Diabetic_Retinopathy_Model.h5')

# Summarize model.
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 127, 127, 36)      468
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 36)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 62, 62, 54)        7830
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 54)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 100)       21700
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 100)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 22500)             0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              46082048
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 48,737,587
# Trainable params: 48,737,587
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##  9.3   Test Loaded Model with Unseen Data

# %%
i = 0
j = i+1
sample = x_test[i:i+1]
target = y_test[j]

y_predicted = CNN_Model.predict_classes(sample)


print("<SAVED MODEL DEPLOYED TO PREDICT AN UNSEEN DATA :>")
print("y_predicted  : ", *y_predicted)
print("Actual class : ", target)
# Out:
# <SAVED MODEL DEPLOYED TO PREDICT AN UNSEEN DATA :>
# y_predicted  :  0
# Actual class :  0
# C:\Users\USER\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
i = 10
j = i+1
sample = x_test[i:j]
target = y_test[j]

y_predicted = CNN_Model.predict_classes(sample)


print("<SAVED MODEL DEPLOYED TO PREDICT AN UNSEEN DATA :>")
print("y_predicted  : ", *y_predicted)
print("Actual class : ", target)
# Out:
# <SAVED MODEL DEPLOYED TO PREDICT AN UNSEEN DATA :>
# y_predicted  :  0
# Actual class :  0

# %%
i = 50
j = i+1
sample = x_test[i:j]
target = y_test[j]

y_predicted = CNN_Model.predict_classes(sample)


print("<SAVED MODEL DEPLOYED TO PREDICT AN UNSEEN DATA :>")
print("y_predicted  : ", *y_predicted)
print("Actual class : ", target)
# Out:
# <SAVED MODEL DEPLOYED TO PREDICT AN UNSEEN DATA :>
# y_predicted  :  0
# Actual class :  0

# %%
i = 60
j = i+1
sample = x_test[i:j]
target = y_test[j]

y_predicted = CNN_Model.predict_classes(sample)


print("<SAVED MODEL DEPLOYED TO PREDICT AN UNSEEN DATA :>")
print("y_predicted  : ", *y_predicted)
print("Actual class : ", target)
# Out:
# <SAVED MODEL DEPLOYED TO PREDICT AN UNSEEN DATA :>
# y_predicted  :  0
# Actual class :  0

# %% [markdown]
# # 10.    Learners Comments:
#
# 1]  Very delighted to find a consistent peak accuracy of almost 100% during training phase.
#
#
# 2] But, the accuracy drops to as lows as about   % during valdation phase.
#
#
# 3] I beleive the model needs to be improved futher. Will endever to improve it by applying various other techniques that are taught during the course.

# %% [markdown]
# # End Of The Project

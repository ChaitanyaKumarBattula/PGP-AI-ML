# %% [markdown]
# # COURSE:   PGP [AI&ML]
#
# ## Learner :  Chaitanya Kumar Battula
# ## Module  : Advanced Deep Learning
# ## Topic   : Intro to open Cv

# %%
import cv2

# %% [markdown]
# # Read Image and its attributes

# %%
img = cv2.imread("balloon.jpg")
print("Image Type:", type(img))
print("Image Shape:", img.shape)
# Out:
# Image Type: <class 'numpy.ndarray'>
# Image Shape: (400, 400, 3)

# %%
height, width = img.shape[:2]
print("width:", width)
print("Height:", height)
# Out:
# width: 400
# Height: 400

# %%
img[0]
# Out:
# array([[ 97,  89,   0],
#        [ 98,  90,   0],
#        [ 98,  90,   0],
#        ...,
#        [126, 115,   1],
#        [127, 116,   2],
#        [130, 119,   5]], dtype=uint8)

# %%
img[0][0]
# Out:
# array([97, 89,  0], dtype=uint8)

# %%
img[0][0][0]
# Out:
# 97

# %% [markdown]
# # Read and Display image in colour

# %%
import cv2
img = cv2.imread("balloon.jpg")

cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Read Image in GreyScale

# %%
# Load an color image in grayscale
import cv2
img = cv2.imread('balloon.jpg',0)

print("Grey Image Shape:", img.shape)
height, width = img.shape[:2]
print("width:", width)
print("Height:", height)


cv2.imshow('Grey image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Grey Image Shape: (400, 400)
# width: 400
# Height: 400

# %% [markdown]
# # Convert  Colour Image to Grey

# %%
import cv2

image = cv2.imread('balloon.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  
cv2.imshow('Grayscale', gray_image)
cv2.waitKey(0)  
  
# window shown waits for any key pressing event
cv2.destroyAllWindows()

# %% [markdown]
# # Rotate Image

# %% [markdown]
# ## Method-1
# ##  User can choose any angle

# %%
# Has freedom of choosing any angle from 0 to 360
import cv2

img = cv2.imread("balloon.jpg")

(h1, w1) = img.shape[:2]
center = (w1/2, h1/2)
angle = 180
factor = 1

Matrix = cv2.getRotationMatrix2D(center, angle, factor)
rotated_image = cv2.warpAffine(img, Matrix, (w1, h1))

cv2.imshow("rotated", rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Method-2
#
#
# ###  Has no freedom of choosing various angles.
# ###  Can choose 90 : clockwise +  counterclockwise
# ###  Can choose 180

# %%
# 90 : Clockwise 
import cv2

img = cv2.imread("balloon.jpg")
rotatedImage = cv2.rotate(img, cv2.cv2.ROTATE_90_CLOCKWISE)
  
# Displaying the image
cv2.imshow('rotatedImage', rotatedImage)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Choose 90 :  Counterclockwise
import cv2

img = cv2.imread("balloon.jpg")
rotatedImage = cv2.rotate(img, cv2.cv2.ROTATE_90_COUNTERCLOCKWISE)
  
# Displaying the image
cv2.imshow('rotatedImage', rotatedImage)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Rotate by 180
import cv2

img = cv2.imread("balloon.jpg")
rotatedImage = cv2.rotate(img, cv2.cv2.ROTATE_180)
  
# Displaying the image
cv2.imshow('rotatedImage', rotatedImage)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Crop the image

# %% [markdown]
# ## Crop the image: Method-1

# %%
import cv2
img = cv2.imread("balloon.jpg")
height, width = img.shape[0:2]

startRow = int(height*.15)
startCol = int(width*.15)
endRow   = int(height*.85)
endCol   = int(width*.85)


croppedImage = img[startRow:endRow, startCol:endCol]

cv2.imshow('croppedImage', croppedImage)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Crop the image: Method-2

# %%
import cv2

img = cv2.imread("balloon.jpg")

cropped_image = img[50:170, 150:250]



cv2.imshow('cropped_image', cropped_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Resize Image

# %% [markdown]
# ## Resize Image: Method-1

# %%
import cv2
img = cv2.imread("balloon.jpg")

resized_img = cv2.resize(img, (0,0), fx=0.25, fy=0.25)



cv2.imshow('Resized_image', resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Resize Image: Method-2

# %%
import cv2
img = cv2.imread("balloon.jpg")

h1=100
w1=100
dimension = (w1, h1) 

resized_image = cv2.resize(img, dimension, interpolation = cv2.INTER_AREA)
cv2.imshow("resized", resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Saving Image

# %%
import cv2
img = cv2.imread("balloon.jpg")
#saving image
cv2.imwrite('test_write.jpg',img)


# Load the saved Image for testing
img = cv2.imread("test_write.jpg")

cv2.imshow('test_write.jpg',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt 
# %matplotlib inline 

img = cv2.imread("balloon.jpg")

#converting image to HSV format
hsv_image = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#plotting the HSV image
cv2.imshow('hsv_image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

#plotting the HSV image
plt.imshow(hsv_image)

# %% [markdown]
# # Blur the image

# %%
import cv2
img = cv2.imread("balloon.jpg")

gaussian_blur_image = cv2.GaussianBlur(img, (7,7), 0) #gaussian blur



cv2.imshow('gaussian_blur_image', gaussian_blur_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
img = cv2.imread("balloon.jpg")

median_blur_image = cv2.medianBlur(img, 5)



cv2.imshow('median_blur_image', median_blur_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Detect edges in the image

# %%
import cv2
img = cv2.imread("balloon.jpg")

edge_img = cv2.Canny(img,100,200) #canny edge detection



cv2.imshow('edge_img ', edge_img )
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Translation

# %%
#importing the required libraries 
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline 

#reading the image
image = cv2.imread("balloon.jpg")

rows,cols = image.shape[:2] 

#shifting the image 100 pixels in both dimensions
M = np.float32([[1,0,-50],[0,1,-50]]) 
dst = cv2.warpAffine(image,M,(cols,rows)) 
plt.imshow(dst)

# %% [markdown]
# # Simple Image Thresholding

# %%
#importing the required libraries 
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline 

#here 0 means that the image is loaded in gray scale format
gray_image = cv2.imread('balloon.jpg',0)

ret,thresh_binary = cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY)
ret,thresh_binary_inv = cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY_INV)
ret,thresh_trunc = cv2.threshold(gray_image,127,255,cv2.THRESH_TRUNC)
ret,thresh_tozero = cv2.threshold(gray_image,127,255,cv2.THRESH_TOZERO)
ret,thresh_tozero_inv = cv2.threshold(gray_image,127,255,cv2.THRESH_TOZERO_INV)

#DISPLAYING THE DIFFERENT THRESHOLDING STYLES
names = ['Oiriginal Image','BINARY','THRESH_BINARY_INV','THRESH_TRUNC','THRESH_TOZERO','THRESH_TOZERO_INV']
images = gray_image,thresh_binary,thresh_binary_inv,thresh_trunc,thresh_tozero,thresh_tozero_inv

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(names[i])
    plt.xticks([]),plt.yticks([])
    
plt.show()

# %% [markdown]
# # Adaptive Thresholding

# %%
#import the libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

#ADAPTIVE THRESHOLDING
gray_image = cv2.imread('balloon.jpg',0)

ret,thresh_global = cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY)
#here 11 is the pixel neighbourhood that is used to calculate the threshold value
thresh_mean = cv2.adaptiveThreshold(gray_image,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)

thresh_gaussian = cv2.adaptiveThreshold(gray_image,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)

names = ['Original Image','Global Thresholding','Adaptive Mean Threshold','Adaptive Gaussian Thresholding']
images = [gray_image,thresh_global,thresh_mean,thresh_gaussian]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(names[i])
    plt.xticks([]),plt.yticks([])
    
plt.show()

# %% [markdown]
# # Image Segmentation (Watershed Algorithm)

# %%
#importing required libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt

#reading the image
image = cv2.imread('balloon.jpg')
#converting image to grayscale format
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

#apply thresholding
ret,thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
#get a kernel
kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel,iterations = 2)
#extract the background from image
sure_bg = cv2.dilate(opening,kernel,iterations = 3)

dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,5)
ret,sure_fg = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,0)

sure_fg = np.uint8(sure_fg)
unknown = cv2.subtract(sure_bg,sure_bg)

ret,markers = cv2.connectedComponents(sure_fg)

markers = markers+1

markers[unknown==255] = 0

markers = cv2.watershed(image,markers)
image[markers==-1] = [255,0,0]

plt.imshow(sure_fg)

# %% [markdown]
# # Bitwise Operations - Masking

# %%
#import required libraries
import numpy as np 
import matplotlib.pyplot as plt 
import cv2 
# %matplotlib inline 
#read the image
image = cv2.imread('balloon.jpg')
#apply thresholdin 
ret,mask = cv2.threshold(sure_fg,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU) 
#apply AND operation on image and mask generated by thrresholding
final = cv2.bitwise_and(image,image,mask = mask) 
#plot the result
plt.imshow(final)

# %%
img = cv2.imread("balloon.jpg")

x = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)



cv2.imshow('x', x)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("balloon.jpg")

x = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)



cv2.imshow('x', x)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("balloon.jpg")

x = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)



cv2.imshow('x', x)
cv2.waitKey(0)
cv2.destroyAllWindows()

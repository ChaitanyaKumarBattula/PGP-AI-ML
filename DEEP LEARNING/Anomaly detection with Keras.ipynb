# %% [markdown]
# # # COURSE:   PGP [AI&ML]
#
# ## Learner :  Chaitanya Kumar Battula
# ## Module  : Deep Learning
# ## Topic   : Practice Project_Anomaly detection with Keras

# %% [markdown]
# ### Installed Version

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.14.0'

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.3.1'

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 16, 10

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %% [markdown]
# ### Loading the data

# %%
df = pd.read_csv("data/creditcard.csv")

# %% [markdown]
# ### Exploring Shape

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# ### Checking for missing values:

# %%
df.isnull().values.any()
# Out:
# False

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %% [markdown]
# ### It can be observed that the data is higly imbalanced

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]

# %%
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %% [markdown]
# ### Statistical information of the fraudualnt transaction

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# ### Statistical information of the non fradulent transaction

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# Let's have a more graphical representation:

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %% [markdown]
# Do fraudulent transactions occur more often during certain time?

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# # Preparing the data

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %% [markdown]
# ### Training Autoencoder

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %%
X_train.shape
# Out:
# (227451, 29)

# %% [markdown]
# # Building the model
#
# Our Autoencoder uses 4 fully connected layers with 14, 7, 7 and 29 neurons respectively.  The first two layers are used for our encoder, the last two go for the decoder. Additionally, L1 regularization will be used during training:

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

# %% [markdown]
# Let's train our model for 100 epochs with a batch size of 32 samples and save the best performing model to a file. The ModelCheckpoint provided by Keras is really handy for such tasks. Additionally,  the training progress will be exported in a format that TensorBoard understands.

# %%
nb_epoch = 100
batch_size = 32

autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# WARNING:tensorflow:From C:\Users\pranjal.taye\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 227451 samples, validate on 56962 samples
# WARNING:tensorflow:From C:\Users\pranjal.taye\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\callbacks\tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From C:\Users\pranjal.taye\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\callbacks\tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/100
# 227451/227451 [==============================] - 11s 49us/step - loss: 0.8175 - accuracy: 0.5883 - val_loss: 0.7856 - val_accuracy: 0.6333
# WARNING:tensorflow:From C:\Users\pranjal.taye\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\callbacks\tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7425 - accuracy: 0.6452 - val_loss: 0.7668 - val_accuracy: 0.6489
# Epoch 3/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7311 - accuracy: 0.6541 - val_loss: 0.7589 - val_accuracy: 0.6623
# Epoch 4/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7250 - accuracy: 0.6598 - val_loss: 0.7564 - val_accuracy: 0.6669
# Epoch 5/100
# 227451/227451 [==============================] - 10s 44us/step - loss: 0.7216 - accuracy: 0.6643 - val_loss: 0.7594 - val_accuracy: 0.6561
# Epoch 6/100
# 227451/227451 [==============================] - 10s 44us/step - loss: 0.7186 - accuracy: 0.6666 - val_loss: 0.7503 - val_accuracy: 0.6697
# Epoch 7/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7169 - accuracy: 0.6709 - val_loss: 0.7507 - val_accuracy: 0.6651
# Epoch 8/100
# 227451/227451 [==============================] - 10s 42us/step - loss: 0.7146 - accuracy: 0.6769 - val_loss: 0.7477 - val_accuracy: 0.6813
# Epoch 9/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7129 - accuracy: 0.6809 - val_loss: 0.7482 - val_accuracy: 0.6852
# Epoch 10/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7119 - accuracy: 0.6813 - val_loss: 0.7429 - val_accuracy: 0.6749
# Epoch 11/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7111 - accuracy: 0.6820 - val_loss: 0.7432 - val_accuracy: 0.6894
# Epoch 12/100
# 227451/227451 [==============================] - 10s 42us/step - loss: 0.7107 - accuracy: 0.6834 - val_loss: 0.7468 - val_accuracy: 0.6769
# Epoch 13/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7104 - accuracy: 0.6830 - val_loss: 0.7417 - val_accuracy: 0.6840
# Epoch 14/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7099 - accuracy: 0.6833 - val_loss: 0.7554 - val_accuracy: 0.6739
# Epoch 15/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7093 - accuracy: 0.6828 - val_loss: 0.7414 - val_accuracy: 0.6816
# Epoch 16/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7090 - accuracy: 0.6833 - val_loss: 0.7398 - val_accuracy: 0.6786
# Epoch 17/100
# 227451/227451 [==============================] - 10s 44us/step - loss: 0.7083 - accuracy: 0.6855 - val_loss: 0.7429 - val_accuracy: 0.6854
# Epoch 18/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7074 - accuracy: 0.6862 - val_loss: 0.7394 - val_accuracy: 0.6792
# Epoch 19/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7069 - accuracy: 0.6867 - val_loss: 0.7398 - val_accuracy: 0.6880
# Epoch 20/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7060 - accuracy: 0.6888 - val_loss: 0.7405 - val_accuracy: 0.6804
# Epoch 21/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7059 - accuracy: 0.6886 - val_loss: 0.7377 - val_accuracy: 0.6876
# Epoch 22/100
# 227451/227451 [==============================] - 10s 45us/step - loss: 0.7064 - accuracy: 0.6884 - val_loss: 0.7385 - val_accuracy: 0.6877
# Epoch 23/100
# 227451/227451 [==============================] - 10s 45us/step - loss: 0.7057 - accuracy: 0.6892 - val_loss: 0.7366 - val_accuracy: 0.6927
# Epoch 24/100
# 227451/227451 [==============================] - 10s 45us/step - loss: 0.7058 - accuracy: 0.6891 - val_loss: 0.7400 - val_accuracy: 0.6848
# Epoch 25/100
# 227451/227451 [==============================] - 10s 44us/step - loss: 0.7055 - accuracy: 0.6895 - val_loss: 0.7363 - val_accuracy: 0.6894
# Epoch 26/100
# 227451/227451 [==============================] - 10s 45us/step - loss: 0.7053 - accuracy: 0.6897 - val_loss: 0.7370 - val_accuracy: 0.6956
# Epoch 27/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7051 - accuracy: 0.6909 - val_loss: 0.7381 - val_accuracy: 0.6934
# Epoch 28/100
# 227451/227451 [==============================] - 10s 44us/step - loss: 0.7048 - accuracy: 0.6903 - val_loss: 0.7366 - val_accuracy: 0.6892
# Epoch 29/100
# 227451/227451 [==============================] - 10s 44us/step - loss: 0.7050 - accuracy: 0.6904 - val_loss: 0.7405 - val_accuracy: 0.6823
# Epoch 30/100
# 227451/227451 [==============================] - 10s 44us/step - loss: 0.7048 - accuracy: 0.6906 - val_loss: 0.7366 - val_accuracy: 0.6861
# Epoch 31/100
# 227451/227451 [==============================] - 10s 45us/step - loss: 0.7047 - accuracy: 0.6917 - val_loss: 0.7361 - val_accuracy: 0.6939
# Epoch 32/100
# 227451/227451 [==============================] - 11s 47us/step - loss: 0.7047 - accuracy: 0.6916 - val_loss: 0.7399 - val_accuracy: 0.6932
# Epoch 33/100
# 227451/227451 [==============================] - 15s 65us/step - loss: 0.7045 - accuracy: 0.6912 - val_loss: 0.7356 - val_accuracy: 0.6928
# Epoch 34/100
# 227451/227451 [==============================] - 12s 53us/step - loss: 0.7041 - accuracy: 0.6909 - val_loss: 0.7369 - val_accuracy: 0.6941
# Epoch 35/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7041 - accuracy: 0.6918 - val_loss: 0.7391 - val_accuracy: 0.6927
# Epoch 36/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7041 - accuracy: 0.6910 - val_loss: 0.7357 - val_accuracy: 0.6975
# Epoch 37/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7044 - accuracy: 0.6910 - val_loss: 0.7479 - val_accuracy: 0.6797
# Epoch 38/100
# 227451/227451 [==============================] - 9s 41us/step - loss: 0.7044 - accuracy: 0.6917 - val_loss: 0.7368 - val_accuracy: 0.6921
# Epoch 39/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7038 - accuracy: 0.6920 - val_loss: 0.7425 - val_accuracy: 0.6782
# Epoch 40/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7037 - accuracy: 0.6907 - val_loss: 0.7354 - val_accuracy: 0.6940
# Epoch 41/100
# 227451/227451 [==============================] - 9s 41us/step - loss: 0.7039 - accuracy: 0.6919 - val_loss: 0.7416 - val_accuracy: 0.6837
# Epoch 42/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7042 - accuracy: 0.6913 - val_loss: 0.7424 - val_accuracy: 0.6943
# Epoch 43/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7038 - accuracy: 0.6922 - val_loss: 0.7449 - val_accuracy: 0.6871
# Epoch 44/100
# 227451/227451 [==============================] - 10s 44us/step - loss: 0.7037 - accuracy: 0.6915 - val_loss: 0.7381 - val_accuracy: 0.6837
# Epoch 45/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7038 - accuracy: 0.6921 - val_loss: 0.7382 - val_accuracy: 0.6988
# Epoch 46/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7035 - accuracy: 0.6923 - val_loss: 0.7358 - val_accuracy: 0.6991
# Epoch 47/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7034 - accuracy: 0.6929 - val_loss: 0.7363 - val_accuracy: 0.6928
# Epoch 48/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7040 - accuracy: 0.6921 - val_loss: 0.7371 - val_accuracy: 0.6934
# Epoch 49/100
# 227451/227451 [==============================] - 9s 41us/step - loss: 0.7036 - accuracy: 0.6932 - val_loss: 0.7351 - val_accuracy: 0.6955
# Epoch 50/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7033 - accuracy: 0.6927 - val_loss: 0.7358 - val_accuracy: 0.7010
# Epoch 51/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7033 - accuracy: 0.6930 - val_loss: 0.7404 - val_accuracy: 0.6866
# Epoch 52/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7033 - accuracy: 0.6936 - val_loss: 0.7359 - val_accuracy: 0.6923
# Epoch 53/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7029 - accuracy: 0.6935 - val_loss: 0.7366 - val_accuracy: 0.6861
# Epoch 54/100
# 227451/227451 [==============================] - 9s 41us/step - loss: 0.7031 - accuracy: 0.6938 - val_loss: 0.7353 - val_accuracy: 0.6960
# Epoch 55/100
# 227451/227451 [==============================] - 10s 44us/step - loss: 0.7036 - accuracy: 0.6940 - val_loss: 0.7338 - val_accuracy: 0.6908
# Epoch 56/100
# 227451/227451 [==============================] - 10s 42us/step - loss: 0.7028 - accuracy: 0.6933 - val_loss: 0.7368 - val_accuracy: 0.6991
# Epoch 57/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7036 - accuracy: 0.6940 - val_loss: 0.7357 - val_accuracy: 0.6943
# Epoch 58/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7026 - accuracy: 0.6934 - val_loss: 0.7416 - val_accuracy: 0.6946
# Epoch 59/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7027 - accuracy: 0.6937 - val_loss: 0.7358 - val_accuracy: 0.6873
# Epoch 60/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7035 - accuracy: 0.6936 - val_loss: 0.7350 - val_accuracy: 0.6878
# Epoch 61/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7032 - accuracy: 0.6937 - val_loss: 0.7356 - val_accuracy: 0.6911
# Epoch 62/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7025 - accuracy: 0.6938 - val_loss: 0.7362 - val_accuracy: 0.6936
# Epoch 63/100
# 227451/227451 [==============================] - 10s 43us/step - loss: 0.7028 - accuracy: 0.6934 - val_loss: 0.7355 - val_accuracy: 0.6898
# Epoch 64/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7027 - accuracy: 0.6940 - val_loss: 0.7383 - val_accuracy: 0.6817
# Epoch 65/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7026 - accuracy: 0.6941 - val_loss: 0.7355 - val_accuracy: 0.6919
# Epoch 66/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7030 - accuracy: 0.6933 - val_loss: 0.7339 - val_accuracy: 0.7007
# Epoch 67/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7028 - accuracy: 0.6939 - val_loss: 0.7360 - val_accuracy: 0.7070
# Epoch 68/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7026 - accuracy: 0.6941 - val_loss: 0.7350 - val_accuracy: 0.7043
# Epoch 69/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7025 - accuracy: 0.6940 - val_loss: 0.7343 - val_accuracy: 0.7034
# Epoch 70/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7020 - accuracy: 0.6940 - val_loss: 0.7350 - val_accuracy: 0.6912
# Epoch 71/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7023 - accuracy: 0.6939 - val_loss: 0.7388 - val_accuracy: 0.6887
# Epoch 72/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7021 - accuracy: 0.6945 - val_loss: 0.7418 - val_accuracy: 0.6983
# Epoch 73/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7023 - accuracy: 0.6948 - val_loss: 0.7403 - val_accuracy: 0.6796
# Epoch 74/100
# 227451/227451 [==============================] - 9s 41us/step - loss: 0.7021 - accuracy: 0.6943 - val_loss: 0.7417 - val_accuracy: 0.6872
# Epoch 75/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7024 - accuracy: 0.6948 - val_loss: 0.7612 - val_accuracy: 0.6716
# Epoch 76/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7020 - accuracy: 0.6952 - val_loss: 0.7345 - val_accuracy: 0.6947
# Epoch 77/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7024 - accuracy: 0.6952 - val_loss: 0.7339 - val_accuracy: 0.6997
# Epoch 78/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7019 - accuracy: 0.6951 - val_loss: 0.7373 - val_accuracy: 0.6928
# Epoch 79/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7018 - accuracy: 0.6949 - val_loss: 0.7352 - val_accuracy: 0.6919
# Epoch 80/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7020 - accuracy: 0.6947 - val_loss: 0.7344 - val_accuracy: 0.6984
# Epoch 81/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7021 - accuracy: 0.6957 - val_loss: 0.7370 - val_accuracy: 0.6913
# Epoch 82/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7017 - accuracy: 0.6951 - val_loss: 0.7360 - val_accuracy: 0.6914
# Epoch 83/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7016 - accuracy: 0.6949 - val_loss: 0.7341 - val_accuracy: 0.6904
# Epoch 84/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7019 - accuracy: 0.6948 - val_loss: 0.7392 - val_accuracy: 0.6898
# Epoch 85/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7020 - accuracy: 0.6946 - val_loss: 0.7365 - val_accuracy: 0.6946
# Epoch 86/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7022 - accuracy: 0.6951 - val_loss: 0.7373 - val_accuracy: 0.6976
# Epoch 87/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7019 - accuracy: 0.6946 - val_loss: 0.7361 - val_accuracy: 0.7057
# Epoch 88/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7017 - accuracy: 0.6955 - val_loss: 0.7341 - val_accuracy: 0.6919
# Epoch 89/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7015 - accuracy: 0.6950 - val_loss: 0.7384 - val_accuracy: 0.6923
# Epoch 90/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7016 - accuracy: 0.6955 - val_loss: 0.7380 - val_accuracy: 0.6957
# Epoch 91/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7013 - accuracy: 0.6957 - val_loss: 0.7352 - val_accuracy: 0.6857
# Epoch 92/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7019 - accuracy: 0.6949 - val_loss: 0.7404 - val_accuracy: 0.6971
# Epoch 93/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7014 - accuracy: 0.6959 - val_loss: 0.7341 - val_accuracy: 0.6994
# Epoch 94/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7014 - accuracy: 0.6950 - val_loss: 0.7359 - val_accuracy: 0.6975
# Epoch 95/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7011 - accuracy: 0.6953 - val_loss: 0.7347 - val_accuracy: 0.7030
# Epoch 96/100
# 227451/227451 [==============================] - 9s 40us/step - loss: 0.7017 - accuracy: 0.6954 - val_loss: 0.7339 - val_accuracy: 0.7005
# Epoch 97/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7010 - accuracy: 0.6960 - val_loss: 0.7342 - val_accuracy: 0.6972
# Epoch 98/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7014 - accuracy: 0.6953 - val_loss: 0.7361 - val_accuracy: 0.6959
# Epoch 99/100
# 227451/227451 [==============================] - 9s 39us/step - loss: 0.7012 - accuracy: 0.6955 - val_loss: 0.7362 - val_accuracy: 0.6985
# Epoch 100/100
# 227451/227451 [==============================] - 9s 41us/step - loss: 0.7010 - accuracy: 0.6952 - val_loss: 0.7345 - val_accuracy: 0.6978

# %%
autoencoder = load_model('model.h5')

# %% [markdown]
# # Evaluation

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %% [markdown]
# The reconstruction error on our training and test data seems to converge nicely. Is it low enough? Let's have a closer look at the error distribution:

# %%
predictions = autoencoder.predict(X_test)

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.724451      0.001720
# std                3.392188      0.041443
# min                0.053184      0.000000
# 25%                0.240623      0.000000
# 50%                0.385671      0.000000
# 75%                0.621369      0.000000
# max              258.195512      1.000000

# %% [markdown]
# ## Reconstruction error without fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %% [markdown]
# ## Reconstruction error with fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %% [markdown]
# ROC curves are very useful tool for understanding the performance of binary classifiers. However, our case is a bit out of the ordinary. We have a very imbalanced dataset. Nonetheless, let's have a look at our ROC curve:

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# A high area under the curve represents both high recall and high precision, where high precision relates to a low false positive rate, and high recall relates to a low false negative rate. High scores for both show that the classifier is returning accurate results (high precision), as well as returning a majority of all positive results (high recall).

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# You can see that as the reconstruction error increases our precision rises as well. Let's have a look at the recall:

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %% [markdown]
# Here, we have the exact opposite situation. As the reconstruction error increases the recall decreases.

# %% [markdown]
# # Prediction

# %%
threshold = 2.9

# %% [markdown]
# And see how well we're dividing the two types of transactions:

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %% [markdown]
# I know, that chart might be a bit deceiving. Let's have a look at the confusion matrix:

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %% [markdown]
# # End Of Practice Project

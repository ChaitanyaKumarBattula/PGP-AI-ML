# %% [markdown]
# #  Customers Modeling Analysis

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp
import warnings
import string
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # LOADING THE DATASET

# %%
data = pd.read_csv('./DataSets/Churn Modeling.csv')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# **So our dataset contains different data types like int , object ,float.**

# %%
data.mean()
# Out:
# RowNumber          5.000500e+03
# CustomerId         1.569094e+07
# CreditScore        6.505288e+02
# Age                3.892180e+01
# Tenure             5.012800e+00
# Balance            7.648589e+04
# NumOfProducts      1.530200e+00
# HasCrCard          7.055000e-01
# IsActiveMember     5.151000e-01
# EstimatedSalary    1.000902e+05
# Exited             2.037000e-01
# dtype: float64

# %%
data.value_counts()
# Out:
# RowNumber  CustomerId  Surname     CreditScore  Geography  Gender  Age  Tenure  Balance    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 1          15634602    Hargrave    619          France     Female  42   2       0.00       1              1          1               101348.88        1         1
# 6671       15667932    Bellucci    758          Spain      Female  43   10      0.00       2              1          1               55313.44         0         1
# 6664       15766185    She         850          Germany    Male    31   4       146587.30  1              1          1               89874.82         0         1
# 6665       15667632    Birdseye    703          France     Female  42   7       0.00       2              0          1               72500.68         0         1
# 6666       15599024    Hope        506          Spain      Male    32   8       0.00       2              0          1               182692.80        0         1
#                                                                                                                                                                ..
# 3334       15599078    Yang        619          Germany    Female  41   5       92467.58   1              1          0               38270.47         0         1
# 3335       15702300    Walker      671          France     Male    27   5       0.00       2              0          0               120893.07        0         1
# 3336       15660735    T'ang       581          Spain      Female  31   6       0.00       2              1          0               188377.21        0         1
# 3337       15671390    Chukwukere  690          Spain      Male    36   10      0.00       2              1          0               55902.93         0         1
# 10000      15628319    Walker      792          France     Female  28   4       130142.79  1              1          0               38190.78         0         1
# Length: 10000, dtype: int64

# %% [markdown]
# **Checking Null Values**

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
data.shape
# Out:
# (10000, 14)

# %% [markdown]
# **So our dataset contains 10000 rows and 14 columns**

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber       -0.009067       0.007246   0.000599        0.012044
# CustomerId      -0.012419       0.016972  -0.014025        0.001665
# CreditScore      0.006268       0.012238  -0.005458        0.025651
# Age              0.028308      -0.030680  -0.011721        0.085472
# Tenure          -0.012254       0.013444   0.022583       -0.028362
# Balance          1.000000      -0.304180  -0.014858       -0.010084
# NumOfProducts   -0.304180       1.000000   0.003183        0.009612
# HasCrCard       -0.014858       0.003183   1.000000       -0.011866
# IsActiveMember  -0.010084       0.009612  -0.011866        1.000000
# EstimatedSalary  0.012797       0.014204  -0.009933       -0.011421
# Exited           0.118533      -0.047820  -0.007138       -0.156128
#
#                  EstimatedSalary    Exited
# RowNumber              -0.005988 -0.016571
# CustomerId              0.015271 -0.006248
# CreditScore            -0.001384 -0.027094
# Age                    -0.007201  0.285323
# Tenure                  0.007784 -0.014001
# Balance                 0.012797  0.118533
# NumOfProducts           0.014204 -0.047820
# HasCrCard              -0.009933 -0.007138
# IsActiveMember         -0.011421 -0.156128
# EstimatedSalary         1.000000  0.012097
# Exited                  0.012097  1.000000

# %% [markdown]
# **HEATMAP**
#
# **A heatmap is a graphical representation of data that uses a system of color-coding to represent different values. Heatmaps are used in various forms of analytics but are most commonly used to show user behaviour on specific webpages or webpage templates.**

# %%
plt.figure(figsize = (16,10))

sns.heatmap(data.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **HISTOGRAM**
#
# **A histogram is basically used to represent data provided in a form of some groups.It is accurate method for the graphical representation of numerical data distribution.It is a type of bar plot where X-axis represents the bin ranges while Y-axis gives information about frequency.**

# %%
data.hist(figsize=(18,12))
plt.show()

# %% [markdown]
# **SCATTER PLOT**
#
# **A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables.**

# %%
sns.scatterplot(x='Balance', y= 'CreditScore', data=data)
# Out:
# <AxesSubplot:xlabel='Balance', ylabel='CreditScore'>

# %% [markdown]
# **PAIRPLOT**
#
# **A pairplot plot a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.**

# %%
sns.set_style("whitegrid") 
mean_col = ['RowNumber','Gender','Age','Tenure','Balance','Exited']

sns.pairplot(data[mean_col],palette='Accent')

# %% [markdown]
# **RELPLOT**
#
# **This is a figure-level function for visualizing statistical relationships using two common approaches: scatter plots and line plots. ... relplot() combines a FacetGrid with one of two axes-level functions: scatterplot() (with kind="scatter" ; the default)**

# %%
sns.relplot(x='Age', y= 'CreditScore', data=data)

# %% [markdown]
# **JOINTPLOT**
#
# **Seaborn's jointplot displays a relationship between 2 variables (bivariate) as well as 1D profiles (univariate) in the margins. This plot is a convenience class that wraps JointGrid.**

# %%
sns.jointplot(x='Balance', y= 'CreditScore', data=data)

# %% [markdown]
# **KDE PLOT (DENSITY PLOT)**
#
# **KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable. We can also plot a single graph for multiple samples which helps in more efficient data visualization.**

# %%
plt.style.use("ggplot")
plt.figure(figsize=(14,8))
plt.xlabel('Balance')
plt.ylabel('CreditScore')
sns.kdeplot(data['Balance'],shade=True,color='blue')
plt.show()

# %% [markdown]
# **BARPLOT**
#
# **A barplot (or barchart) is one of the most common types of graphic. It shows the relationship between a numeric and a categoric variable. Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value.**

# %%
plt.style.use("default")
sns.barplot(x="Balance", y="CreditScore",data=data[179:190])
plt.title("Balance vs CreditScore",fontsize=15)
plt.xlabel("Balance")
plt.ylabel("CreditScore")
plt.show()

# %%
plt.style.use("default")
sns.barplot(x="EstimatedSalary", y="CreditScore",data=data[183:190])
plt.title("EstimatedSalary vs CreditScore",fontsize=15)
plt.xlabel("EstimatedSalary")
plt.ylabel("CreditScore")
plt.show()

# %%
plt.style.use("default")
sns.barplot(x="Tenure", y="Balance",data=data[170:190])
plt.title("Tenure vs Balance",fontsize=15)
plt.xlabel("Tenure")
plt.ylabel("Balance")
plt.show()

# %%
plt.style.use("default")
sns.barplot(x="HasCrCard", y="NumOfProducts",data=data[160:190])
plt.title("HasCrCard vs NumOfProducts",fontsize=15)
plt.xlabel("HasCrCard")
plt.ylabel("NumOfProducts")
plt.show()

# %%
#lets find the categorialfeatures
list_1=list(data.columns)

# %%
list_cate=[]
for i in list_1:
    if data[i].dtype=='object':
        list_cate.append(i)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_cate:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15634602     1115          619          0       0   42
# 1             2    15647311     1177          608          2       0   41
# 2             3    15619304     2040          502          0       0   42
# 3             4    15701354      289          699          0       0   39
# 4             5    15737888     1822          850          2       0   43
# ...         ...         ...      ...          ...        ...     ...  ...
# 9995       9996    15606229     1999          771          0       1   39
# 9996       9997    15569892     1336          516          0       1   35
# 9997       9998    15584532     1570          709          0       0   36
# 9998       9999    15682355     2345          772          1       1   42
# 9999      10000    15628319     2751          792          0       0   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
#drop the columns as it is no longer required
X = data.drop('Geography',axis=1)
y = data['Geography']

# %% [markdown]
# # TRAINING AND TESTING DATA

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(len(X_test))
print(len(X_train))
print(len(y_test))
print(len(y_train))
# Out:
# 2000
# 8000
# 2000
# 8000

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # ANN

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(activation="relu", units=6, kernel_initializer="uniform"))

# Adding the second hidden layer
classifier.add(Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform"))

# Adding the output layer
classifier.add(Dense(activation="sigmoid", units=1, kernel_initializer="uniform"))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train,y_train,batch_size = 10,
    epochs=200,
)
# Out:
# Epoch 1/200
# 800/800 [==============================] - 2s 958us/step - loss: 0.6057 - accuracy: 0.2460
# Epoch 2/200
# 800/800 [==============================] - 1s 914us/step - loss: 0.5612 - accuracy: 0.2451
# Epoch 3/200
# 800/800 [==============================] - 1s 924us/step - loss: 0.5600 - accuracy: 0.2451
# Epoch 4/200
# 800/800 [==============================] - 1s 993us/step - loss: 0.5591 - accuracy: 0.2451
# Epoch 5/200
# 800/800 [==============================] - 1s 944us/step - loss: 0.5588 - accuracy: 0.2451
# Epoch 6/200
# 800/800 [==============================] - 1s 978us/step - loss: 0.5586 - accuracy: 0.2451
# Epoch 7/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5585 - accuracy: 0.2451
# Epoch 8/200
# 800/800 [==============================] - 1s 943us/step - loss: 0.5583 - accuracy: 0.2451
# Epoch 9/200
# 800/800 [==============================] - 1s 980us/step - loss: 0.5582 - accuracy: 0.2451
# Epoch 10/200
# 800/800 [==============================] - 1s 979us/step - loss: 0.5580 - accuracy: 0.2451
# Epoch 11/200
# 800/800 [==============================] - 1s 942us/step - loss: 0.5573 - accuracy: 0.2451
# Epoch 12/200
# 800/800 [==============================] - 1s 946us/step - loss: 0.5580 - accuracy: 0.2451
# Epoch 13/200
# 800/800 [==============================] - 1s 917us/step - loss: 0.5575 - accuracy: 0.2451
# Epoch 14/200
# 800/800 [==============================] - 1s 935us/step - loss: 0.5574 - accuracy: 0.2451
# Epoch 15/200
# 800/800 [==============================] - 1s 919us/step - loss: 0.5570 - accuracy: 0.2451
# Epoch 16/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5569 - accuracy: 0.2451
# Epoch 17/200
# 800/800 [==============================] - 1s 938us/step - loss: 0.5568 - accuracy: 0.2451
# Epoch 18/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5567 - accuracy: 0.2451
# Epoch 19/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5565 - accuracy: 0.2451
# Epoch 20/200
# 800/800 [==============================] - 1s 923us/step - loss: 0.5561 - accuracy: 0.2451
# Epoch 21/200
# 800/800 [==============================] - 1s 925us/step - loss: 0.5557 - accuracy: 0.2451
# Epoch 22/200
# 800/800 [==============================] - 1s 928us/step - loss: 0.5554 - accuracy: 0.2451
# Epoch 23/200
# 800/800 [==============================] - 1s 917us/step - loss: 0.5554 - accuracy: 0.2451
# Epoch 24/200
# 800/800 [==============================] - 1s 939us/step - loss: 0.5553 - accuracy: 0.2451
# Epoch 25/200
# 800/800 [==============================] - 1s 942us/step - loss: 0.5549 - accuracy: 0.2451
# Epoch 26/200
# 800/800 [==============================] - 1s 886us/step - loss: 0.5546 - accuracy: 0.2451
# Epoch 27/200
# 800/800 [==============================] - 1s 955us/step - loss: 0.5542 - accuracy: 0.2451
# Epoch 28/200
# 800/800 [==============================] - 1s 961us/step - loss: 0.5542 - accuracy: 0.2451
# Epoch 29/200
# 800/800 [==============================] - 1s 918us/step - loss: 0.5541 - accuracy: 0.2451
# Epoch 30/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5536 - accuracy: 0.2451
# Epoch 31/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5528 - accuracy: 0.2451
# Epoch 32/200
# 800/800 [==============================] - 1s 964us/step - loss: 0.5524 - accuracy: 0.2451
# Epoch 33/200
# 800/800 [==============================] - 1s 960us/step - loss: 0.5530 - accuracy: 0.2451
# Epoch 34/200
# 800/800 [==============================] - 1s 942us/step - loss: 0.5524 - accuracy: 0.2451
# Epoch 35/200
# 800/800 [==============================] - 1s 928us/step - loss: 0.5521 - accuracy: 0.2451
# Epoch 36/200
# 800/800 [==============================] - 1s 920us/step - loss: 0.5521 - accuracy: 0.2451
# Epoch 37/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5519 - accuracy: 0.2451
# Epoch 38/200
# 800/800 [==============================] - 1s 970us/step - loss: 0.5518 - accuracy: 0.2451
# Epoch 39/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5516 - accuracy: 0.2451
# Epoch 40/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5512 - accuracy: 0.2451
# Epoch 41/200
# 800/800 [==============================] - 1s 965us/step - loss: 0.5512 - accuracy: 0.2451
# Epoch 42/200
# 800/800 [==============================] - 1s 927us/step - loss: 0.5507 - accuracy: 0.2451
# Epoch 43/200
# 800/800 [==============================] - 1s 961us/step - loss: 0.5506 - accuracy: 0.2451
# Epoch 44/200
# 800/800 [==============================] - 1s 928us/step - loss: 0.5506 - accuracy: 0.2451
# Epoch 45/200
# 800/800 [==============================] - 1s 980us/step - loss: 0.5503 - accuracy: 0.2451
# Epoch 46/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5501 - accuracy: 0.2451
# Epoch 47/200
# 800/800 [==============================] - 1s 912us/step - loss: 0.5493 - accuracy: 0.2451
# Epoch 48/200
# 800/800 [==============================] - 1s 908us/step - loss: 0.5507 - accuracy: 0.2451
# Epoch 49/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5502 - accuracy: 0.2451
# Epoch 50/200
# 800/800 [==============================] - 1s 995us/step - loss: 0.5499 - accuracy: 0.2451
# Epoch 51/200
# 800/800 [==============================] - 1s 897us/step - loss: 0.5494 - accuracy: 0.2451
# Epoch 52/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5497 - accuracy: 0.2451
# Epoch 53/200
# 800/800 [==============================] - 1s 956us/step - loss: 0.5494 - accuracy: 0.2451
# Epoch 54/200
# 800/800 [==============================] - 1s 905us/step - loss: 0.5494 - accuracy: 0.2451
# Epoch 55/200
# 800/800 [==============================] - 1s 979us/step - loss: 0.5495 - accuracy: 0.2451
# Epoch 56/200
# 800/800 [==============================] - 1s 942us/step - loss: 0.5496 - accuracy: 0.2451
# Epoch 57/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5493 - accuracy: 0.2451
# Epoch 58/200
# 800/800 [==============================] - 1s 978us/step - loss: 0.5494 - accuracy: 0.2451
# Epoch 59/200
# 800/800 [==============================] - 1s 957us/step - loss: 0.5494 - accuracy: 0.2451
# Epoch 60/200
# 800/800 [==============================] - 1s 939us/step - loss: 0.5492 - accuracy: 0.2451
# Epoch 61/200
# 800/800 [==============================] - 1s 978us/step - loss: 0.5495 - accuracy: 0.2451
# Epoch 62/200
# 800/800 [==============================] - 1s 948us/step - loss: 0.5488 - accuracy: 0.2451
# Epoch 63/200
# 800/800 [==============================] - 1s 996us/step - loss: 0.5486 - accuracy: 0.2453
# Epoch 64/200
# 800/800 [==============================] - 1s 947us/step - loss: 0.5490 - accuracy: 0.2453
# Epoch 65/200
# 800/800 [==============================] - 1s 964us/step - loss: 0.5479 - accuracy: 0.2457
# Epoch 66/200
# 800/800 [==============================] - 1s 920us/step - loss: 0.5490 - accuracy: 0.2454
# Epoch 67/200
# 800/800 [==============================] - 1s 956us/step - loss: 0.5482 - accuracy: 0.2455
# Epoch 68/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5488 - accuracy: 0.2457
# Epoch 69/200
# 800/800 [==============================] - 1s 912us/step - loss: 0.5483 - accuracy: 0.2455
# Epoch 70/200
# 800/800 [==============================] - 1s 914us/step - loss: 0.5485 - accuracy: 0.2454
# Epoch 71/200
# 800/800 [==============================] - 1s 908us/step - loss: 0.5484 - accuracy: 0.2455
# Epoch 72/200
# 800/800 [==============================] - 1s 975us/step - loss: 0.5482 - accuracy: 0.2459
# Epoch 73/200
# 800/800 [==============================] - 1s 912us/step - loss: 0.5485 - accuracy: 0.2455
# Epoch 74/200
# 800/800 [==============================] - 1s 933us/step - loss: 0.5482 - accuracy: 0.2456
# Epoch 75/200
# 800/800 [==============================] - 1s 981us/step - loss: 0.5480 - accuracy: 0.2459
# Epoch 76/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5482 - accuracy: 0.2460
# Epoch 77/200
# 800/800 [==============================] - 1s 897us/step - loss: 0.5481 - accuracy: 0.2456
# Epoch 78/200
# 800/800 [==============================] - 1s 888us/step - loss: 0.5481 - accuracy: 0.2461
# Epoch 79/200
# 800/800 [==============================] - 1s 903us/step - loss: 0.5478 - accuracy: 0.2460
# Epoch 80/200
# 800/800 [==============================] - 1s 905us/step - loss: 0.5476 - accuracy: 0.2460
# Epoch 81/200
# 800/800 [==============================] - 1s 904us/step - loss: 0.5477 - accuracy: 0.2471
# Epoch 82/200
# 800/800 [==============================] - 1s 931us/step - loss: 0.5473 - accuracy: 0.2463
# Epoch 83/200
# 800/800 [==============================] - 1s 936us/step - loss: 0.5478 - accuracy: 0.2464
# Epoch 84/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5474 - accuracy: 0.2460
# Epoch 85/200
# 800/800 [==============================] - 1s 976us/step - loss: 0.5474 - accuracy: 0.2469
# Epoch 86/200
# 800/800 [==============================] - 1s 951us/step - loss: 0.5475 - accuracy: 0.2466
# Epoch 87/200
# 800/800 [==============================] - 1s 913us/step - loss: 0.5468 - accuracy: 0.2474
# Epoch 88/200
# 800/800 [==============================] - 1s 904us/step - loss: 0.5477 - accuracy: 0.2474
# Epoch 89/200
# 800/800 [==============================] - 1s 885us/step - loss: 0.5467 - accuracy: 0.2467
# Epoch 90/200
# 800/800 [==============================] - 1s 897us/step - loss: 0.5473 - accuracy: 0.2470
# Epoch 91/200
# 800/800 [==============================] - 1s 909us/step - loss: 0.5470 - accuracy: 0.2467
# Epoch 92/200
# 800/800 [==============================] - 1s 910us/step - loss: 0.5471 - accuracy: 0.2474
# Epoch 93/200
# 800/800 [==============================] - 1s 910us/step - loss: 0.5467 - accuracy: 0.2473
# Epoch 94/200
# 800/800 [==============================] - 1s 892us/step - loss: 0.5467 - accuracy: 0.2471
# Epoch 95/200
# 800/800 [==============================] - 1s 911us/step - loss: 0.5466 - accuracy: 0.2473
# Epoch 96/200
# 800/800 [==============================] - 1s 912us/step - loss: 0.5464 - accuracy: 0.2481
# Epoch 97/200
# 800/800 [==============================] - 1s 900us/step - loss: 0.5467 - accuracy: 0.2470
# Epoch 98/200
# 800/800 [==============================] - 1s 901us/step - loss: 0.5466 - accuracy: 0.2471
# Epoch 99/200
# 800/800 [==============================] - 1s 902us/step - loss: 0.5467 - accuracy: 0.2474
# Epoch 100/200
# 800/800 [==============================] - 1s 912us/step - loss: 0.5463 - accuracy: 0.2486
# Epoch 101/200
# 800/800 [==============================] - 1s 928us/step - loss: 0.5465 - accuracy: 0.2479
# Epoch 102/200
# 800/800 [==============================] - 1s 923us/step - loss: 0.5460 - accuracy: 0.2484
# Epoch 103/200
# 800/800 [==============================] - 1s 915us/step - loss: 0.5465 - accuracy: 0.2471
# Epoch 104/200
# 800/800 [==============================] - 1s 909us/step - loss: 0.5462 - accuracy: 0.2486
# Epoch 105/200
# 800/800 [==============================] - 1s 920us/step - loss: 0.5462 - accuracy: 0.2474
# Epoch 106/200
# 800/800 [==============================] - 1s 907us/step - loss: 0.5461 - accuracy: 0.2484
# Epoch 107/200
# 800/800 [==============================] - 1s 902us/step - loss: 0.5462 - accuracy: 0.2482
# Epoch 108/200
# 800/800 [==============================] - 1s 908us/step - loss: 0.5457 - accuracy: 0.2491
# Epoch 109/200
# 800/800 [==============================] - 1s 915us/step - loss: 0.5459 - accuracy: 0.2494
# Epoch 110/200
# 800/800 [==============================] - 1s 945us/step - loss: 0.5459 - accuracy: 0.2479
# Epoch 111/200
# 800/800 [==============================] - 1s 896us/step - loss: 0.5455 - accuracy: 0.2480
# Epoch 112/200
# 800/800 [==============================] - 1s 928us/step - loss: 0.5456 - accuracy: 0.2484
# Epoch 113/200
# 800/800 [==============================] - 1s 944us/step - loss: 0.5451 - accuracy: 0.2499
# Epoch 114/200
# 800/800 [==============================] - 1s 909us/step - loss: 0.5452 - accuracy: 0.2485
# Epoch 115/200
# 800/800 [==============================] - 1s 922us/step - loss: 0.5453 - accuracy: 0.2488
# Epoch 116/200
# 800/800 [==============================] - 1s 898us/step - loss: 0.5448 - accuracy: 0.2488
# Epoch 117/200
# 800/800 [==============================] - 1s 915us/step - loss: 0.5447 - accuracy: 0.2489
# Epoch 118/200
# 800/800 [==============================] - 1s 901us/step - loss: 0.5445 - accuracy: 0.2490
# Epoch 119/200
# 800/800 [==============================] - 1s 898us/step - loss: 0.5444 - accuracy: 0.2495
# Epoch 120/200
# 800/800 [==============================] - 1s 894us/step - loss: 0.5442 - accuracy: 0.2499
# Epoch 121/200
# 800/800 [==============================] - 1s 901us/step - loss: 0.5442 - accuracy: 0.2491
# Epoch 122/200
# 800/800 [==============================] - 1s 944us/step - loss: 0.5439 - accuracy: 0.2488
# Epoch 123/200
# 800/800 [==============================] - 1s 889us/step - loss: 0.5441 - accuracy: 0.2495
# Epoch 124/200
# 800/800 [==============================] - 1s 898us/step - loss: 0.5436 - accuracy: 0.2494
# Epoch 125/200
# 800/800 [==============================] - 1s 891us/step - loss: 0.5437 - accuracy: 0.2496
# Epoch 126/200
# 800/800 [==============================] - 1s 951us/step - loss: 0.5434 - accuracy: 0.2491
# Epoch 127/200
# 800/800 [==============================] - 1s 923us/step - loss: 0.5434 - accuracy: 0.2499
# Epoch 128/200
# 800/800 [==============================] - 1s 936us/step - loss: 0.5433 - accuracy: 0.2511
# Epoch 129/200
# 800/800 [==============================] - 1s 925us/step - loss: 0.5430 - accuracy: 0.2505
# Epoch 130/200
# 800/800 [==============================] - 1s 911us/step - loss: 0.5429 - accuracy: 0.2504
# Epoch 131/200
# 800/800 [==============================] - 1s 962us/step - loss: 0.5427 - accuracy: 0.2492
# Epoch 132/200
# 800/800 [==============================] - 1s 895us/step - loss: 0.5425 - accuracy: 0.2514
# Epoch 133/200
# 800/800 [==============================] - 1s 899us/step - loss: 0.5420 - accuracy: 0.2508
# Epoch 134/200
# 800/800 [==============================] - 1s 914us/step - loss: 0.5427 - accuracy: 0.2506
# Epoch 135/200
# 800/800 [==============================] - 1s 915us/step - loss: 0.5424 - accuracy: 0.2499
# Epoch 136/200
# 800/800 [==============================] - 1s 907us/step - loss: 0.5422 - accuracy: 0.2511
# Epoch 137/200
# 800/800 [==============================] - 1s 908us/step - loss: 0.5422 - accuracy: 0.2504
# Epoch 138/200
# 800/800 [==============================] - 1s 907us/step - loss: 0.5419 - accuracy: 0.2521
# Epoch 139/200
# 800/800 [==============================] - 1s 939us/step - loss: 0.5424 - accuracy: 0.2505
# Epoch 140/200
# 800/800 [==============================] - 1s 940us/step - loss: 0.5419 - accuracy: 0.2515
# Epoch 141/200
# 800/800 [==============================] - 1s 889us/step - loss: 0.5416 - accuracy: 0.2516
# Epoch 142/200
# 800/800 [==============================] - 1s 923us/step - loss: 0.5417 - accuracy: 0.2510
# Epoch 143/200
# 800/800 [==============================] - 1s 940us/step - loss: 0.5413 - accuracy: 0.2511
# Epoch 144/200
# 800/800 [==============================] - 1s 979us/step - loss: 0.5416 - accuracy: 0.2522
# Epoch 145/200
# 800/800 [==============================] - 1s 910us/step - loss: 0.5417 - accuracy: 0.2514
# Epoch 146/200
# 800/800 [==============================] - 1s 948us/step - loss: 0.5416 - accuracy: 0.2519
# Epoch 147/200
# 800/800 [==============================] - 1s 987us/step - loss: 0.5412 - accuracy: 0.2511
# Epoch 148/200
# 800/800 [==============================] - 1s 905us/step - loss: 0.5411 - accuracy: 0.2525
# Epoch 149/200
# 800/800 [==============================] - 1s 925us/step - loss: 0.5411 - accuracy: 0.2508
# Epoch 150/200
# 800/800 [==============================] - 1s 917us/step - loss: 0.5409 - accuracy: 0.2533
# Epoch 151/200
# 800/800 [==============================] - 1s 900us/step - loss: 0.5412 - accuracy: 0.2512
# Epoch 152/200
# 800/800 [==============================] - 1s 984us/step - loss: 0.5407 - accuracy: 0.2514
# Epoch 153/200
# 800/800 [==============================] - 1s 928us/step - loss: 0.5407 - accuracy: 0.2533
# Epoch 154/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5404 - accuracy: 0.2536
# Epoch 155/200
# 800/800 [==============================] - 1s 893us/step - loss: 0.5405 - accuracy: 0.2530
# Epoch 156/200
# 800/800 [==============================] - 1s 970us/step - loss: 0.5405 - accuracy: 0.2530
# Epoch 157/200
# 800/800 [==============================] - 1s 932us/step - loss: 0.5402 - accuracy: 0.2525
# Epoch 158/200
# 800/800 [==============================] - 1s 984us/step - loss: 0.5401 - accuracy: 0.2520
# Epoch 159/200
# 800/800 [==============================] - 1s 913us/step - loss: 0.5398 - accuracy: 0.2519
# Epoch 160/200
# 800/800 [==============================] - 1s 948us/step - loss: 0.5406 - accuracy: 0.2529
# Epoch 161/200
# 800/800 [==============================] - 1s 931us/step - loss: 0.5399 - accuracy: 0.2526
# Epoch 162/200
# 800/800 [==============================] - 1s 916us/step - loss: 0.5393 - accuracy: 0.2542
# Epoch 163/200
# 800/800 [==============================] - 1s 923us/step - loss: 0.5395 - accuracy: 0.2526
# Epoch 164/200
# 800/800 [==============================] - 1s 899us/step - loss: 0.5397 - accuracy: 0.2534
# Epoch 165/200
# 800/800 [==============================] - 1s 902us/step - loss: 0.5398 - accuracy: 0.2530
# Epoch 166/200
# 800/800 [==============================] - 1s 911us/step - loss: 0.5393 - accuracy: 0.2535
# Epoch 167/200
# 800/800 [==============================] - 1s 899us/step - loss: 0.5395 - accuracy: 0.2540
# Epoch 168/200
# 800/800 [==============================] - 1s 892us/step - loss: 0.5397 - accuracy: 0.2531
# Epoch 169/200
# 800/800 [==============================] - 1s 973us/step - loss: 0.5395 - accuracy: 0.2533
# Epoch 170/200
# 800/800 [==============================] - 1s 947us/step - loss: 0.5392 - accuracy: 0.2546
# Epoch 171/200
# 800/800 [==============================] - 1s 958us/step - loss: 0.5395 - accuracy: 0.2540
# Epoch 172/200
# 800/800 [==============================] - 1s 933us/step - loss: 0.5391 - accuracy: 0.2549
# Epoch 173/200
# 800/800 [==============================] - 1s 935us/step - loss: 0.5394 - accuracy: 0.2540
# Epoch 174/200
# 800/800 [==============================] - 1s 930us/step - loss: 0.5394 - accuracy: 0.2536
# Epoch 175/200
# 800/800 [==============================] - 1s 916us/step - loss: 0.5388 - accuracy: 0.2551
# Epoch 176/200
# 800/800 [==============================] - 1s 936us/step - loss: 0.5390 - accuracy: 0.2530
# Epoch 177/200
# 800/800 [==============================] - 1s 935us/step - loss: 0.5377 - accuracy: 0.2544
# Epoch 178/200
# 800/800 [==============================] - 1s 932us/step - loss: 0.5390 - accuracy: 0.2553
# Epoch 179/200
# 800/800 [==============================] - 1s 920us/step - loss: 0.5389 - accuracy: 0.2550
# Epoch 180/200
# 800/800 [==============================] - 1s 938us/step - loss: 0.5386 - accuracy: 0.2546
# Epoch 181/200
# 800/800 [==============================] - 1s 925us/step - loss: 0.5391 - accuracy: 0.2545
# Epoch 182/200
# 800/800 [==============================] - 1s 918us/step - loss: 0.5385 - accuracy: 0.2551
# Epoch 183/200
# 800/800 [==============================] - 1s 923us/step - loss: 0.5386 - accuracy: 0.2560
# Epoch 184/200
# 800/800 [==============================] - 1s 963us/step - loss: 0.5380 - accuracy: 0.2544
# Epoch 185/200
# 800/800 [==============================] - 1s 935us/step - loss: 0.5381 - accuracy: 0.2566
# Epoch 186/200
# 800/800 [==============================] - 1s 927us/step - loss: 0.5385 - accuracy: 0.2548
# Epoch 187/200
# 800/800 [==============================] - 1s 940us/step - loss: 0.5383 - accuracy: 0.2545
# Epoch 188/200
# 800/800 [==============================] - 1s 935us/step - loss: 0.5379 - accuracy: 0.2545
# Epoch 189/200
# 800/800 [==============================] - 1s 930us/step - loss: 0.5377 - accuracy: 0.2564
# Epoch 190/200
# 800/800 [==============================] - 1s 921us/step - loss: 0.5381 - accuracy: 0.2560
# Epoch 191/200
# 800/800 [==============================] - 1s 921us/step - loss: 0.5377 - accuracy: 0.2555
# Epoch 192/200
# 800/800 [==============================] - 1s 927us/step - loss: 0.5378 - accuracy: 0.2559
# Epoch 193/200
# 800/800 [==============================] - 1s 916us/step - loss: 0.5379 - accuracy: 0.2560
# Epoch 194/200
# 800/800 [==============================] - 1s 928us/step - loss: 0.5378 - accuracy: 0.2571
# Epoch 195/200
# 800/800 [==============================] - 1s 983us/step - loss: 0.5378 - accuracy: 0.2561
# Epoch 196/200
# 800/800 [==============================] - 1s 929us/step - loss: 0.5377 - accuracy: 0.2556
# Epoch 197/200
# 800/800 [==============================] - 1s 939us/step - loss: 0.5376 - accuracy: 0.2559
# Epoch 198/200
# 800/800 [==============================] - 1s 924us/step - loss: 0.5376 - accuracy: 0.2564
# Epoch 199/200
# 800/800 [==============================] - 1s 932us/step - loss: 0.5379 - accuracy: 0.2551
# Epoch 200/200
# 800/800 [==============================] - 1s 930us/step - loss: 0.5375 - accuracy: 0.2570

# %%
y_pred = classifier.predict(X_test)
y_pred
# Out:
# 63/63 [==============================] - 0s 850us/step
# array([[0.8371795 ],
#        [0.8852232 ],
#        [0.6310291 ],
#        ...,
#        [0.73717934],
#        [0.8561007 ],
#        [0.6375882 ]], dtype=float32)

# %%
print((y_pred > 0.5))
# Out:
# [[ True]
#  [ True]
#  [ True]
#  ...
#  [ True]
#  [ True]
#  [ True]]

# %%
from tensorflow.keras.utils import plot_model
plot_model(classifier, show_shapes = True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_cate:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15634602     1115          619          0       0   42
# 1             2    15647311     1177          608          2       0   41
# 2             3    15619304     2040          502          0       0   42
# 3             4    15701354      289          699          0       0   39
# 4             5    15737888     1822          850          2       0   43
# ...         ...         ...      ...          ...        ...     ...  ...
# 9995       9996    15606229     1999          771          0       1   39
# 9996       9997    15569892     1336          516          0       1   35
# 9997       9998    15584532     1570          709          0       0   36
# 9998       9999    15682355     2345          772          1       1   42
# 9999      10000    15628319     2751          792          0       0   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 84
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dense_2 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 133
# Trainable params: 133
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error,mean_absolute_error
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("Mean Absolute Error:\n",mean_absolute_error(y_test,y_pred))
# Out:
# Mean Squared Error:
#  0.6847676841289879
# Mean Absolute Error:
#  0.7238549488186836

# %%
classifier.evaluate(X_test,y_test)
# Out:
# 63/63 [==============================] - 0s 926us/step - loss: 0.5754 - accuracy: 0.2825
# [0.5753723382949829, 0.2824999988079071]

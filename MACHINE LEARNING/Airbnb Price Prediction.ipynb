# %% [markdown]
# # Airbnb Price Prediction

# %% [markdown]
# ### Contents
# 1. Abstract
# 2. Dataset
# 3. Goal
# 4. Importing required libraries and Dataset
# 5. Exploratory Data Analysis
# 6. Data Processing
# 7. Prediction Models
#     - Linear Regression
#     - Random Forest Regression
#     - Gradient Boosting Regression
#     - Dense Neural Networks
#     - Model Comparison
# 8. tf-idf Transformer
# 9. Stacked Regression
# 10. Validation Process
# 11. Conclusion
#
# ********************************

# %% [markdown]
# ### Abstract
# Pricing a rental property on Airbnb is a challenging task for the owner as it determines the number of customers for the place. On the other hand, customers have to evaluate an offered price with minimal knowledge of an optimal value for the property. This paper aims to develop a reliable price prediction model using machine learning, deep learning, and natural language processing techniques to aid both the property owners and the customers with price evaluation given minimal available information about the property. Features of the rentals, owner characteristics, and the customer reviews will comprise the predictors, and a range of methods from linear regression to tree-based models, support-vector regression (SVR), K-means Clustering (KMC), and neural networks (NNs) will be used for creating the prediction model.
#
# ### Dataset
# The dataset which is used here, is collected from Kaggle website. Here is the link of the dataset : https://www.kaggle.com/stevezhenghp/airbnb-price-prediction.
#
# ### Goal
# The goal of this project is to make a prediction model which will predict the prices of the Airbnb hotels using different parameters.
# ***************************************

# %% [markdown]
# ### Importing required libraries and Dataset

# %%
import re
import nltk
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import ipywidgets as widgets
from plotly.offline import init_notebook_mode
from ipywidgets import interact, interactive, fixed, interact_manual
from datetime import datetime
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from statsmodels.graphics.gofplots import qqplot
from scipy import stats
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
from tensorflow.keras.callbacks import EarlyStopping
pd.set_option('display.max_columns', None)

init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('./DataSets/airbnb-prices.csv')
data.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee city  \
# 0  Real Bed              strict          True  NYC
# 1  Real Bed              strict          True  NYC
# 2  Real Bed            moderate          True  NYC
# 3  Real Bed            flexible          True   SF
# 4  Real Bed            moderate          True   DC
#
#                                          description first_review  \
# 0  Beautiful, sunlit brownstone 1-bedroom in the ...   2016-06-18
# 1  Enjoy travelling during your stay in Manhattan...   2017-08-05
# 2  The Oasis comes complete with a full backyard ...   2017-04-30
# 3  This light-filled home-away-from-home is super...          NaN
# 4  Cool, cozy, and comfortable studio located in ...   2015-05-12
#
#   host_has_profile_pic host_identity_verified host_response_rate  host_since  \
# 0                    t                      t                NaN  2012-03-26
# 1                    t                      f               100%  2017-06-19
# 2                    t                      t               100%  2016-10-25
# 3                    t                      t                NaN  2015-04-19
# 4                    t                      t               100%  2015-03-01
#
#   instant_bookable last_review   latitude   longitude  \
# 0                f  2016-07-18  40.696524  -73.991617
# 1                t  2017-09-23  40.766115  -73.989040
# 2                t  2017-09-14  40.808110  -73.943756
# 3                f         NaN  37.772004 -122.431619
# 4                t  2017-01-22  38.925627  -77.034596
#
#                                        name     neighbourhood  \
# 0            Beautiful brownstone 1-bedroom  Brooklyn Heights
# 1  Superb 3BR Apt Located Near Times Square    Hell's Kitchen
# 2                          The Garden Oasis            Harlem
# 3        Beautiful Flat in the Heart of SF!      Lower Haight
# 4                Great studio in midtown DC  Columbia Heights
#
#    number_of_reviews  review_scores_rating  \
# 0                  2                 100.0
# 1                  6                  93.0
# 2                 10                  92.0
# 3                  0                   NaN
# 4                  4                  40.0
#
#                                        thumbnail_url  zipcode  bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/6d7cbbf7-c...    11201       1.0   1.0
# 1  https://a0.muscache.com/im/pictures/348a55fe-4...    10019       3.0   3.0
# 2  https://a0.muscache.com/im/pictures/6fae5362-9...    10027       1.0   3.0
# 3  https://a0.muscache.com/im/pictures/72208dad-9...  94117.0       2.0   2.0
# 4                                                NaN    20009       0.0   1.0

# %% [markdown]
# ### Spliting the Dataset
# * Split the dataset into 75:25 ratio
# * Name the training set as x_train and y_train.
# * Name the testing set as x_test and y_test.
# * Using the random state here as, 101

# %%
df, validation_df  = train_test_split(data,
                                test_size=0.25,
                                random_state = 101)

# %%
df_train, df_test  = train_test_split(df,
                                test_size=0.25,
                                random_state = 101)

# %% [markdown]
# ## Exploratory Data Analysis - EDA
# Sometimes even the things we see with our naked eyes is not the “naked” truth. It needs time,conviction and certainty to get behind the truth. EDA — Exploratory Data Analysis - does this for Machine Learning enthusiast. It is a way of visualizing, summarizing and interpreting the information that is hidden in rows and column format. EDA is one of the crucial step in data science that allows us to achieve certain insights and statistical measure that is essential for the business continuity, stockholders and data scientists. It performs to define and refine our important features variable selection, that will be used in our model.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41687 entries, 17236 to 68913
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      41687 non-null  int64
#  1   log_price               41687 non-null  float64
#  2   property_type           41687 non-null  object
#  3   room_type               41687 non-null  object
#  4   amenities               41687 non-null  object
#  5   accommodates            41687 non-null  int64
#  6   bathrooms               41571 non-null  float64
#  7   bed_type                41687 non-null  object
#  8   cancellation_policy     41687 non-null  object
#  9   cleaning_fee            41687 non-null  bool
#  10  city                    41687 non-null  object
#  11  description             41687 non-null  object
#  12  first_review            32697 non-null  object
#  13  host_has_profile_pic    41573 non-null  object
#  14  host_identity_verified  41573 non-null  object
#  15  host_response_rate      31392 non-null  object
#  16  host_since              41573 non-null  object
#  17  instant_bookable        41687 non-null  object
#  18  last_review             32717 non-null  object
#  19  latitude                41687 non-null  float64
#  20  longitude               41687 non-null  float64
#  21  name                    41687 non-null  object
#  22  neighbourhood           37798 non-null  object
#  23  number_of_reviews       41687 non-null  int64
#  24  review_scores_rating    32248 non-null  float64
#  25  thumbnail_url           37128 non-null  object
#  26  zipcode                 41160 non-null  object
#  27  bedrooms                41644 non-null  float64
#  28  beds                    41620 non-null  float64
# dtypes: bool(1), float64(7), int64(3), object(18)
# memory usage: 9.3+ MB

# %%
df_train.describe()
# Out:
#                  id     log_price  accommodates     bathrooms      latitude  \
# count  4.168700e+04  41687.000000  41687.000000  41571.000000  41687.000000
# mean   1.126008e+07      4.781785      3.143642      1.232554     38.462137
# std    6.083368e+06      0.717077      2.134425      0.574109      3.078110
# min    3.440000e+02      0.000000      1.000000      0.000000     33.340916
# 25%    6.268097e+06      4.317488      2.000000      1.000000     34.129931
# 50%    1.223036e+07      4.700480      2.000000      1.000000     40.664508
# 75%    1.641251e+07      5.220356      4.000000      1.000000     40.746488
# max    2.123090e+07      7.600402     16.000000      8.000000     42.390437
#
#           longitude  number_of_reviews  review_scores_rating      bedrooms  \
# count  41687.000000       41687.000000          32248.000000  41644.000000
# mean     -92.280070          20.812963             94.114953      1.264792
# std       21.685129          37.785910              7.741383      0.847086
# min     -122.511500           0.000000             20.000000      0.000000
# 25%     -118.341316           1.000000             92.000000      1.000000
# 50%      -76.992899           6.000000             96.000000      1.000000
# 75%      -73.954371          23.000000            100.000000      1.000000
# max      -70.985047         530.000000            100.000000     10.000000
#
#                beds
# count  41620.000000
# mean       1.706007
# std        1.242858
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       16.000000

# %% [markdown]
# **Price Distribution Converted to z - Plotting**

# %%
plt.figure(figsize = (15, 8))
sns.distplot(df_train['log_price'])
plt.title('Price distribution')
plt.show()


plt.figure(figsize = (15, 8))
sns.distplot((df_train['log_price']-np.mean(df_train['log_price'])) / np.std(df_train['log_price']))
plt.title('Price distribution converted to z')
plt.show()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# **Log price**

# %%
#qqplot
qqplot(df_train['log_price'])

# %% [markdown]
# Looks like price distribution is roughly Gaussian

# %%
df_train[df_train['bedrooms'] == 0].head()
# Out:
#              id  log_price property_type        room_type  \
# 34202   6292490   6.214608          Loft  Entire home/apt
# 2941    9158651   4.820282          Loft  Entire home/apt
# 33759  17367369   4.553877     Apartment  Entire home/apt
# 67348   2183423   4.521789     Apartment  Entire home/apt
# 19001  16029649   4.174387     Apartment  Entire home/apt
#
#                                                amenities  accommodates  \
# 34202  {"Wireless Internet","Air conditioning","Wheel...            16
# 2941   {TV,"Wireless Internet","Air conditioning",Kit...             3
# 33759  {Internet,"Wireless Internet","Air conditionin...             2
# 67348  {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# 19001  {Internet,"Wireless Internet","Air conditionin...             2
#
#        bathrooms  bed_type cancellation_policy  cleaning_fee city  \
# 34202        1.0  Real Bed              strict          True   LA
# 2941         1.0  Real Bed              strict          True   LA
# 33759        1.0  Real Bed              strict         False   DC
# 67348        1.0  Real Bed              strict          True   LA
# 19001        1.0  Real Bed            moderate          True   LA
#
#                                              description first_review  \
# 34202  The studio features 35' ceilings, 3 skylights,...   2016-07-24
# 2941   Close to LA Live and numerous Downtown enterta...   2016-10-30
# 33759  My peaceful abode is close to Columbia Heights...   2016-07-29
# 67348  King Sized Bed, Plasma TV, Cable, Internet Bat...   2014-06-22
# 19001  My apartment is amazing.  The building is extr...   2015-10-15
#
#       host_has_profile_pic host_identity_verified host_response_rate  \
# 34202                    t                      t                95%
# 2941                     t                      t               100%
# 33759                    t                      f                NaN
# 67348                    t                      t                60%
# 19001                    t                      t               100%
#
#        host_since instant_bookable last_review   latitude   longitude  \
# 34202  2016-05-24                t  2017-04-09  34.069558 -118.227982
# 2941   2014-06-16                t  2017-04-18  34.044590 -118.254967
# 33759  2016-07-23                f  2016-10-23  38.930792  -77.034696
# 67348  2014-06-09                f  2017-04-09  34.104367 -118.339982
# 19001  2015-09-03                f  2016-10-17  34.046298 -118.312926
#
#                                                     name     neighbourhood  \
# 34202  Event Space w/ FREE Parking, No Noise Restrict...               NaN
# 2941           Downtown Luxury Loft in Historic Building          Downtown
# 33759         Peaceful, Sunny Studio in Columbia Heights  Columbia Heights
# 67348                        Studio in Hollywood,Parking         Hollywood
# 19001                 Huge Studio with Extra Dining room          Mid-City
#
#        number_of_reviews  review_scores_rating  \
# 34202                 28                  93.0
# 2941                  27                  97.0
# 33759                  7                  94.0
# 67348                 87                  86.0
# 19001                  9                  91.0
#
#                                            thumbnail_url zipcode  bedrooms  \
# 34202  https://a0.muscache.com/im/pictures/9e64020e-2...   90012       0.0
# 2941   https://a0.muscache.com/im/pictures/dbb37a1c-c...   90014       0.0
# 33759  https://a0.muscache.com/im/pictures/b4b71f63-3...   20010       0.0
# 67348                                                NaN   90028       0.0
# 19001  https://a0.muscache.com/im/pictures/108460096/...   90019       0.0
#
#        beds
# 34202   1.0
# 2941    1.0
# 33759   1.0
# 67348   1.0
# 19001   1.0

# %% [markdown]
# **HeatMap Plotting**

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df_train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Columns with a lot of missing data:

# %% [markdown]
# **Plotting two different parameters**
# - Row count
# - Years of first review and Price

# %%
years_of_first_review = pd.DataFrame({
    'year of first review':pd.to_datetime(df_train['first_review'], format='%Y-%m-%d', errors='coerce').dt.year.fillna(0),
    'log_price': df_train['log_price']
})
plt.figure(figsize=(12,4))

sns.countplot(x="year of first review", data=years_of_first_review)
plt.title('Row count')
plt.show()

plt.figure(figsize=(12,8))
sns.boxplot(data=years_of_first_review,orient='v', x = 'year of first review', y = 'log_price')
plt.title('Years of first review and price')
plt.show()

# %% [markdown]
# **Plotting two different parameters**
# - Row count
# * Price distribution for na and notna values in first_review column

# %%
na_or_not = lambda x: 'na' if x else 'value'

first_review_error_status= pd.DataFrame({
    'first review error status':df_train['first_review'].isna().apply(na_or_not),
    'log_price': df_train['log_price']
})

plt.figure(figsize=(12,3))
sns.countplot(y='first review error status', data=first_review_error_status, orient='h')
plt.title('Row count')
plt.show()

plt.figure(figsize=(12,3))
sns.boxplot(data=first_review_error_status,orient='h', y = 'first review error status', x = 'log_price')
plt.title('Price distribution for na and notna values in first_review column')
plt.show()

# %% [markdown]
# **Price distribution for na and notna values in first_review column**

# %%
plt.figure(figsize=(10,5))
g = sns.FacetGrid(first_review_error_status, hue="first review error status", height = 5, aspect = 2)
g.map(sns.kdeplot, "log_price")
plt.legend()
plt.title('Price distribution for na and notna values in first_review column')
plt.show()

# %% [markdown]
# **Plotting two different parameters**
# - Row count
# - Years of last review and price

# %%
years_of_last_review = pd.DataFrame({
    'year of last review':pd.to_datetime(df_train['last_review'], format='%Y-%m-%d', errors='coerce').dt.year.fillna(0),
    'log_price': df_train['log_price']
})

plt.figure(figsize=(12,4))
sns.countplot(x="year of last review", data=years_of_last_review)
plt.title('Row count')
plt.show()

plt.figure(figsize=(12,8))
sns.boxplot(data=years_of_last_review,orient='v', x = 'year of last review', y = 'log_price')
plt.title('Years of last review and price')
plt.show()

# %% [markdown]
# **Popular property types**

# %%
popular_property_types = list(df_train['property_type'].value_counts()[df_train['property_type'].value_counts() > 50].index)
popular_property_types
# Out:
# ['Apartment',
#  'House',
#  'Condominium',
#  'Townhouse',
#  'Loft',
#  'Other',
#  'Guesthouse',
#  'Bed & Breakfast',
#  'Bungalow',
#  'Villa',
#  'Dorm',
#  'Guest suite',
#  'Camper/RV']

# %%
df_train['room_type'].value_counts()
# Out:
# Entire home/apt    23233
# Private room       17235
# Shared room         1219
# Name: room_type, dtype: int64

# %%
df_train['bed_type'].value_counts()
# Out:
# Real Bed         40461
# Futon              453
# Pull-out Sofa      343
# Airbed             263
# Couch              167
# Name: bed_type, dtype: int64

# %%
df_train['cancellation_policy'].value_counts()
popular_cancellation_policy = list(df_train['cancellation_policy'].value_counts()[df_train['cancellation_policy'].value_counts() > 100].index)
popular_cancellation_policy
# Out:
# ['strict', 'flexible', 'moderate']

# %%
df_train['city'].value_counts()
# Out:
# NYC        18296
# LA         12554
# SF          3590
# DC          3176
# Chicago     2093
# Boston      1978
# Name: city, dtype: int64

# %%
df_train['host_response_rate'].value_counts()
# Out:
# 100%    24387
# 90%      1286
# 80%       647
# 0%        506
# 50%       327
#         ...
# 21%         1
# 22%         1
# 41%         1
# 23%         1
# 27%         1
# Name: host_response_rate, Length: 76, dtype: int64

# %%
df_train['review_scores_rating'].value_counts()
# Out:
# 100.0    9093
# 98.0     2498
# 96.0     2336
# 97.0     2292
# 95.0     2124
# 93.0     2027
# 90.0     1568
# 99.0     1486
# 94.0     1463
# 80.0     1225
# 92.0     1182
# 91.0      887
# 87.0      624
# 89.0      623
# 88.0      598
# 85.0      341
# 86.0      298
# 84.0      239
# 60.0      234
# 83.0      223
# 70.0      118
# 82.0      111
# 73.0       82
# 81.0       80
# 78.0       56
# 75.0       51
# 20.0       51
# 40.0       46
# 77.0       44
# 79.0       44
# 67.0       37
# 76.0       30
# 74.0       22
# 72.0       22
# 50.0       19
# 65.0       12
# 68.0        9
# 71.0        9
# 69.0        9
# 64.0        7
# 63.0        7
# 53.0        6
# 30.0        2
# 47.0        2
# 55.0        2
# 27.0        2
# 57.0        2
# 56.0        1
# 66.0        1
# 35.0        1
# 54.0        1
# 62.0        1
# Name: review_scores_rating, dtype: int64

# %%
df_train[df_train['bathrooms'].isna()].head()
# Out:
#              id  log_price property_type        room_type  \
# 22225  16384358   4.077537     Apartment     Private room
# 10556   7682094   3.871201     Apartment     Private room
# 2842   12130093   4.382027     Apartment  Entire home/apt
# 61508   8668115   4.025352         House     Private room
# 24116   7309611   3.784190     Apartment     Private room
#
#                                                amenities  accommodates  \
# 22225  {TV,"Wireless Internet","Air conditioning",Kit...             2
# 10556                                                 {}             1
# 2842   {TV,Internet,"Wireless Internet","Air conditio...             2
# 61508  {Internet,"Wireless Internet",Kitchen,"transla...             2
# 24116                     {Internet,"Wireless Internet"}             2
#
#        bathrooms  bed_type cancellation_policy  cleaning_fee     city  \
# 22225        NaN  Real Bed              strict         False      NYC
# 10556        NaN  Real Bed            flexible          True      NYC
# 2842         NaN     Futon            moderate         False  Chicago
# 61508        NaN  Real Bed              strict         False       LA
# 24116        NaN  Real Bed              strict         False       LA
#
#                                              description first_review  \
# 22225  15 min from the city!!! nice loft space apartm...   2013-09-28
# 10556  Massive 400 sq ft Bedroom in beautifully renov...   2015-03-31
# 2842   This is a very small  studio apartment with a ...   2009-07-03
# 61508  Private Room for rent in Los Angeles. Short-te...   2013-09-07
# 24116  Small Private Room with shared bathroom in Los...   2012-12-31
#
#       host_has_profile_pic host_identity_verified host_response_rate  \
# 22225                    t                      f               100%
# 10556                    t                      f                NaN
# 2842                     t                      f               100%
# 61508                    t                      t                96%
# 24116                    t                      t                96%
#
#        host_since instant_bookable last_review   latitude   longitude  \
# 22225  2012-06-14                f  2015-12-02  40.701396  -73.913335
# 10556  2012-07-10                f  2015-03-31  40.710993  -73.952170
# 2842   2009-05-19                f  2017-05-02  41.902845  -87.681830
# 61508  2012-05-08                f  2017-02-27  34.032356 -118.299849
# 24116  2012-05-08                f  2017-03-20  34.042585 -118.346622
#
#                                          name      neighbourhood  \
# 22225       Nice private space in Bklyn loft!           Bushwick
# 10556     Huge Bdrm in New Wilibrg 3 Bed Loft       Williamsburg
# 2842      Tiny Studio Apartment 94 Walk Score  Ukrainian Village
# 61508          Private Room for Rent near USC         West Adams
# 24116  LA Boardinghouse - Simple Private Room           Mid-City
#
#        number_of_reviews  review_scores_rating  \
# 22225                 12                  92.0
# 10556                  1                  80.0
# 2842                 242                  91.0
# 61508                 20                  86.0
# 24116                 30                  83.0
#
#                                            thumbnail_url zipcode  bedrooms  \
# 22225  https://a0.muscache.com/im/pictures/6499936/af...   11237       1.0
# 10556  https://a0.muscache.com/im/pictures/7324290/50...   11211       1.0
# 2842   https://a0.muscache.com/im/pictures/51073/16c8...   60622       NaN
# 61508  https://a0.muscache.com/im/pictures/7c98009f-9...   90007       1.0
# 24116  https://a0.muscache.com/im/pictures/39736169/e...   90019       1.0
#
#        beds
# 22225   1.0
# 10556   NaN
# 2842    1.0
# 61508   1.0
# 24116   1.0

# %%
df_train['bathrooms'].value_counts()
# Out:
# 1.0    32751
# 2.0     4437
# 1.5     2131
# 2.5      920
# 3.0      553
# 3.5      235
# 4.0      156
# 0.5      113
# 0.0      100
# 4.5       64
# 5.0       39
# 5.5       22
# 8.0       16
# 6.0       12
# 6.5       10
# 7.0        8
# 7.5        4
# Name: bathrooms, dtype: int64

# %%
df_train['host_has_profile_pic'].value_counts()
# Out:
# t    41448
# f      125
# Name: host_has_profile_pic, dtype: int64

# %% [markdown]
# **Plotting two different parameters**
# - Row count
# - years of host_price and price

# %%
years_of_host_since = pd.DataFrame({
    'year of host_since':pd.to_datetime(df_train['host_since'], format='%Y-%m-%d', errors='coerce').dt.year.fillna(0),
    'log_price': df_train['log_price']
})

plt.figure(figsize=(12,4))
sns.countplot(x="year of host_since", data=years_of_host_since)
plt.title('Row count')
plt.show()

plt.figure(figsize=(12,8))
sns.boxplot(data=years_of_host_since,orient='v', x = 'year of host_since', y = 'log_price')
plt.title('Years of host_since and price')
plt.show()

# %% [markdown]
# Price distribution of na values looks like one for 2008 values. I think, best of worst is to use 2008 value to fill na in this situation.

# %% [markdown]
# **Mapping the whole distribution of Airbnbs**

# %%
#map

def create_map(city):
    price_view = lambda x: 'price: ' + str(round(x, 2))

    if city in {'NYC', 'LA'}:
        fraction = 0.2
    else:
        fraction = 0.6
        
    df_temp = df_train[df_train['city'] == city].sample(frac=fraction,random_state=101)
    df_temp['log_price'] = np.round(df_temp['log_price'], 2)
    
    fig = px.scatter_mapbox(df_temp, 
                            lat="latitude", 
                            lon="longitude", 
                            hover_data=["log_price"],
                            color='log_price', 
                            zoom=10)
    
    fig.update_layout(
            title = f'Airbnb prices in {city}',
            geo_scope='usa',
            width=1000, 
            height=600,
            mapbox_style="white-bg",
            mapbox_layers=[{
                 "below": 'traces',
                 "sourcetype": "raster",
                 "sourceattribution": "United States Geological Survey",
                 "source": ["https://basemap.nationalmap.gov/arcgis/rest/services/USGSImageryOnly/MapServer/tile/{z}/{y}/{x}"]
              }]
    )
    #fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.update_geos(fitbounds="locations")
    fig.show()
    
#city = interact(lambda x: create_map(x), x=['NYC', 'LA', 'SF', 'DC', 'Chicago', 'Boston'])  #widget
create_map('NYC')
# Out:
# <div>                            <div id="78df54ec-bc07-45b1-8a58-2b7219e6c338" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78df54ec-bc07-45b1-8a58-2b7219e6c338")) {                    Plotly.newPlot(                        "78df54ec-bc07-45b1-8a58-2b7219e6c338",                        [{"customdata":[[4.81],[4.78],[5.33],[4.94],[4.94],[4.84],[5.46],[5.42],[3.56],[4.38],[4.44],[4.49],[3.81],[4.55],[5.01],[4.7],[5.27],[4.25],[3.64],[4.09],[5.19],[5.86],[3.91],[4.55],[4.61],[3.81],[4.7],[4.42],[4.44],[3.91],[4.61],[5.01],[5.29],[5.63],[5.29],[4.09],[3.91],[4.09],[4.8],[4.32],[4.7],[5.3],[4.57],[4.44],[4.94],[5.3],[4.38],[5.3],[5.62],[4.61],[5.22],[4.55],[4.17],[5.3],[5.52],[4.38],[4.09],[4.38],[5.44],[4.01],[4.61],[5.08],[4.17],[5.18],[4.08],[4.38],[5.42],[4.32],[3.64],[3.91],[5.01],[4.16],[4.08],[6.21],[4.44],[5.01],[4.01],[3.81],[4.94],[4.96],[5.01],[5.42],[3.97],[4.23],[5.12],[4.61],[3.95],[5.08],[6.62],[4.09],[5.0],[5.3],[4.83],[4.17],[3.99],[5.04],[5.86],[4.32],[4.83],[5.16],[4.25],[4.79],[5.11],[4.01],[5.04],[4.01],[5.0],[3.76],[5.19],[4.44],[4.38],[3.22],[3.61],[4.47],[4.01],[5.08],[5.01],[4.79],[5.3],[5.16],[3.69],[4.44],[4.79],[4.7],[3.91],[4.61],[4.79],[3.83],[5.22],[4.38],[4.32],[4.91],[4.17],[5.08],[4.08],[5.08],[4.87],[3.81],[5.89],[4.38],[4.61],[4.06],[5.01],[4.17],[4.09],[3.81],[4.09],[5.39],[4.17],[4.41],[5.52],[5.19],[3.66],[4.38],[5.86],[5.19],[4.8],[4.98],[5.52],[5.38],[4.7],[4.01],[5.3],[3.53],[4.25],[4.57],[5.16],[5.13],[4.96],[4.7],[4.83],[4.19],[4.36],[4.37],[4.09],[3.56],[5.08],[4.25],[3.81],[4.87],[4.83],[4.25],[4.61],[3.47],[4.61],[4.83],[5.52],[4.38],[4.2],[5.16],[5.42],[5.8],[3.93],[3.78],[4.91],[5.08],[4.17],[4.32],[5.04],[4.38],[3.91],[4.08],[4.61],[4.25],[4.84],[4.61],[4.29],[5.03],[4.55],[5.7],[4.25],[3.91],[4.25],[5.25],[5.54],[4.01],[4.34],[5.63],[4.32],[4.68],[5.01],[4.74],[4.2],[6.75],[4.61],[4.55],[3.91],[4.83],[3.74],[4.91],[3.89],[4.17],[4.5],[5.39],[4.61],[4.86],[4.38],[3.56],[4.01],[5.74],[4.44],[4.32],[4.61],[3.5],[4.92],[5.07],[5.01],[4.67],[4.17],[5.25],[4.61],[4.08],[4.5],[4.08],[5.27],[4.49],[4.09],[5.01],[5.27],[3.69],[5.7],[3.4],[5.37],[4.44],[5.21],[4.7],[5.56],[5.52],[4.74],[4.5],[4.91],[3.81],[5.01],[4.61],[4.44],[4.09],[3.91],[3.81],[4.38],[4.61],[4.83],[5.42],[4.98],[3.66],[4.74],[4.83],[6.03],[4.79],[5.19],[5.12],[5.01],[5.7],[4.94],[3.81],[4.61],[5.52],[4.06],[5.08],[4.43],[6.35],[4.01],[4.61],[4.38],[4.32],[5.86],[4.17],[5.3],[5.01],[5.52],[4.83],[4.38],[4.09],[4.49],[4.61],[5.48],[6.11],[4.09],[4.32],[5.38],[5.3],[4.17],[5.26],[3.69],[3.91],[3.91],[3.69],[4.17],[5.29],[4.56],[4.97],[3.81],[5.16],[6.68],[5.23],[4.51],[4.39],[4.09],[5.44],[4.7],[4.5],[3.4],[4.44],[4.87],[4.61],[4.5],[4.58],[3.95],[5.01],[4.61],[5.16],[5.42],[4.61],[5.52],[4.69],[4.6],[3.91],[4.37],[4.79],[4.17],[5.18],[5.58],[5.42],[5.62],[3.81],[4.08],[4.22],[5.68],[4.7],[4.61],[4.23],[3.89],[4.5],[4.83],[4.25],[4.61],[4.94],[4.61],[5.08],[3.81],[4.86],[4.98],[4.38],[4.61],[3.37],[5.39],[5.86],[5.7],[4.61],[5.14],[6.75],[4.6],[4.65],[4.78],[4.32],[4.94],[3.85],[3.85],[5.9],[4.26],[4.79],[4.22],[5.19],[5.16],[5.22],[3.99],[4.91],[3.93],[4.38],[4.25],[3.91],[4.74],[3.56],[4.61],[5.52],[5.3],[4.38],[4.97],[4.61],[5.17],[5.01],[4.09],[5.39],[4.38],[5.01],[4.44],[4.38],[5.52],[3.69],[5.95],[4.6],[4.54],[5.39],[4.32],[4.09],[4.38],[3.74],[4.61],[5.04],[3.69],[4.97],[4.55],[5.52],[4.38],[4.37],[4.65],[3.3],[6.91],[6.16],[5.3],[5.14],[4.61],[4.25],[4.5],[4.06],[4.44],[4.19],[4.23],[3.91],[4.61],[4.61],[4.61],[4.17],[3.81],[4.5],[4.37],[4.7],[4.7],[5.86],[5.7],[4.38],[5.52],[5.01],[5.55],[4.32],[5.07],[5.16],[4.25],[5.7],[5.01],[4.5],[4.38],[3.58],[5.35],[4.09],[5.46],[5.7],[4.43],[3.91],[4.01],[5.43],[4.87],[3.64],[3.89],[5.52],[5.22],[4.5],[3.91],[4.67],[4.32],[4.23],[3.91] ...

# %% [markdown]
# ### Outliers handling
# An outlier is an object that deviates significantly from the rest of the objects. They can be caused by measurement or execution error. The analysis of outlier data is referred to as outlier analysis or outlier mining.

# %%
price_distr = pd.DataFrame(np.histogram(df_train['log_price'], bins = 50)).T
price_distr.columns = ['#', 'border']
price_distr.dropna(inplace = True)
price_distr.astype({'#': 'int32'})
price_distr
# Out:
#          #    border
# 0      1.0  0.000000
# 1      0.0  0.152008
# 2      0.0  0.304016
# 3      0.0  0.456024
# 4      0.0  0.608032
# 5      0.0  0.760040
# 6      0.0  0.912048
# 7      0.0  1.064056
# 8      0.0  1.216064
# 9      0.0  1.368072
# 10     0.0  1.520080
# 11     0.0  1.672089
# 12     0.0  1.824097
# 13     0.0  1.976105
# 14     0.0  2.128113
# 15    20.0  2.280121
# 16     3.0  2.432129
# 17    25.0  2.584137
# 18    12.0  2.736145
# 19    66.0  2.888153
# 20    59.0  3.040161
# 21   199.0  3.192169
# 22   372.0  3.344177
# 23   655.0  3.496185
# 24  1013.0  3.648193
# 25  2529.0  3.800201
# 26  2421.0  3.952209
# 27  2727.0  4.104217
# 28  3188.0  4.256225
# 29  3375.0  4.408233
# 30  4221.0  4.560241
# 31  3280.0  4.712249
# 32  4075.0  4.864257
# 33  2282.0  5.016266
# 34  3253.0  5.168274
# 35  1305.0  5.320282
# 36  1858.0  5.472290
# 37  1202.0  5.624298
# 38   861.0  5.776306
# 39   628.0  5.928314
# 40   692.0  6.080322
# 41   204.0  6.232330
# 42   273.0  6.384338
# 43   323.0  6.536346
# 44   106.0  6.688354
# 45   198.0  6.840362
# 46    95.0  6.992370
# 47    51.0  7.144378
# 48    81.0  7.296386
# 49    34.0  7.448394

# %%
df_train[(df_train['log_price'] < 2.5) | (df_train['log_price'] > 7.5)].sort_values(by = 'log_price')
# Out:
#              id  log_price property_type        room_type  \
# 11632  17972519   0.000000   Condominium      Shared room
# 25239    635662   2.302585     Apartment      Shared room
# 19806  14933982   2.302585     Apartment     Private room
# 27021   4868466   2.302585     Apartment  Entire home/apt
# 37651  10500033   2.302585         House      Shared room
# 66762  16555985   2.302585     Apartment  Entire home/apt
# 60206   6357564   2.302585     Apartment  Entire home/apt
# 25655   7091102   2.302585     Townhouse  Entire home/apt
# 69004  15464274   2.302585         House  Entire home/apt
# 53289  17284334   2.302585     Apartment  Entire home/apt
# 48734  10056245   2.302585     Apartment  Entire home/apt
# 6515   19364229   2.302585     Apartment     Private room
# 53742   9937558   2.302585     Apartment  Entire home/apt
# 4466    9117980   2.302585     Apartment     Private room
# 43269  10288459   2.302585         House      Shared room
# 53916   8886036   2.302585     Apartment     Private room
# 70293   7717877   2.302585   Condominium  Entire home/apt
# 65588  16324410   2.302585     Apartment  Entire home/apt
# 50577  11968056   2.302585     Apartment  Entire home/apt
# 23917   8191540   2.302585     Apartment      Shared room
# 58173   7864877   2.397895         House      Shared room
# 34330  10011509   2.484907           Hut      Shared room
# 70246   1012454   2.484907     Apartment      Shared room
# 19445   1906804   2.484907     Apartment     Private room
# 7168     815879   7.506592         House  Entire home/apt
# 25436   3954385   7.522941         House  Entire home/apt
# 64955  17448630   7.536364         House  Entire home/apt
# 7832   10153794   7.546974         House  Entire home/apt
# 71168  16285789   7.549609         House  Entire home/apt
# 68844  15771318   7.549609         House  Entire home/apt
# 32298   4100790   7.549609         House  Entire home/apt
# 61435   4396985   7.549609         House  Entire home/apt
# 23121  19602101   7.549609         House  Entire home/apt
# 21155  11974572   7.575585         House  Entire home/apt
# 9349   11777292   7.575585         House  Entire home/apt
# 37424   1301321   7.575585         House  Entire home/apt
# 2362    7545274   7.588324     Apartment  Entire home/apt
# 20722   7397916   7.598399         House  Entire home/apt
# 61826  20230917   7.598399         Villa  Entire home/apt
# 9390   16383008   7.598399         House     Private room
# 54994  13751426   7.598399         House  Entire home/apt
# 3063    3962389   7.598399         Villa  Entire home/apt
# 60071  11895042   7.600402     Apartment  Entire home/apt
# 42672  16755372   7.600402     Apartment  Entire home/apt
# 72609  17943829   7.600402         House  Entire home/apt
#
#                                                amenities  accommodates  \
# 11632  {TV,"Wireless Internet","Air conditioning",Kit...             1
# 25239  {TV,"Cable TV",Internet,"Wireless Internet","A...             4
# 19806  {TV,Washer,Dryer,Internet,"Wireless Internet",...             2
# 27021          {"Family/kid friendly","Hair dryer",Iron}             5
# 37651  {"translation missing: en.hosting_amenity_49",...             1
# 66762  {"Wireless Internet","Air conditioning",Kitche...             4
# 60206  {TV,Internet,"Wireless Internet","Air conditio...             2
# 25655  {TV,"Wireless Internet","Air conditioning",Kit...             6
# 69004                                                 {}             1
# 53289  {TV,"Cable TV","Wireless Internet","Air condit...             6
# 48734  {TV,Internet,"Wireless Internet","Air conditio...             2
# 6515   {Internet,"Wireless Internet","Air conditionin...             1
# 53742  {TV,"Wireless Internet","Air conditioning",Kit...             3
# 4466   {"Family/kid friendly",Washer,Dryer,"translati...             1
# 43269  {"Wireless Internet","Air conditioning",Heatin...             1
# 53916  {"Wireless Internet","Air conditioning",Kitche...             1
# 70293  {TV,"Wireless Internet",Kitchen,Breakfast,Heat...             4
# 65588  {TV,Internet,"Wireless Internet","Air conditio...             2
# 50577  {TV,"Wireless Internet","Air conditioning",Kit...             2
# 23917  {TV,"Cable TV","Wireless Internet","Air condit...             1
# 58173  {TV,"Wireless Internet","Air conditioning",Kit...             1
# 34330  {"Wireless Internet","Air conditioning",Pool,K...            10
# 70246  {TV,Internet,"Wireless Internet",Heating,Washe...             1
# 19445               {"Free parking on premises",Shampoo}             1
# 7168   {TV,"Wireless Internet","Air conditioning",Poo...            14
# 25436  {TV,"Cable TV",Internet,"Wireless Internet","A...            10
# 64955  {TV,"Cable TV",Internet,"Wireless Internet","A...             5
# 7832   {TV,"Cable TV",Internet,"Wireless Internet","A...             8
# 71168  {TV,"Cable TV","Wireless Internet","Air condit...             8
# 68844  {TV,"Cable TV",Internet,"Wireless Internet","A...            16
# 32298  {TV,"Wireless Internet","Air conditioning",Kit...             6
# 61435  {TV,"Cable TV",Internet,"Wireless Internet","A...             5
# 23121  {TV,"Cable TV",Internet,"Wireless Internet","A...            16
# 21155  {"Cable TV",Internet,"Wireless Internet","Air ...             6
# 9349   {TV,"Wireless Internet","Air conditioning",Poo...             6
# 37424  {TV,"Wireless Internet","Air conditioning",Kit...             8
# 2362   {"Smoking allowed","Pets allowed","Family/kid ...            10
# 20722  {Internet,"Wireless Internet","Air conditionin...            16
# 61826  {TV,"Cable TV",Internet,"Wireless Internet","A...            16
# 9390   {"Wireless Internet","Free parking on premises...             2
# 54994  {TV,"Cable TV",Internet,"Wireless Internet","A...             7
# 3063   {TV,"Cable TV",Internet,"Wireless Internet","A...            16
# 60071  {TV,Internet,"Wireless Internet","Air conditio...             6
# 42672  {Internet,"Wireless Internet","Air conditionin...             2
# 72609  {TV,"Wireless Internet","Air conditioning",Kit...             6
#
#        bathrooms  bed_type cancellation_policy  cleaning_fee     city  \
# 11632        1.0  Real Bed              strict          True      NYC
# 25239        2.0  Real Bed            flexible         False       DC
# 19806        1.0  Real Bed            flexible         False       SF
# 27021        1.0  Real Bed            flexible         False       LA
# 37651        0.0  Real Bed              strict         False       LA
# 66762        1.0  Real Bed              strict          True      NYC
# 60206        1.0  Real Bed            moderate         False       DC
# 25655        2.5  Real Bed            flexible          True       DC
# 69004        0.5  Real Bed            flexible         False       SF
# 53289        4.0  Real Bed            flexible         False      NYC
# 48734        1.0  Real Bed            moderate          True      NYC
# 6515         1.0  Real Bed            flexible          True  Chicago
# 53742        1.0  Real Bed            flexible          True      NYC
# 4466         1.0  Real Bed            flexible         False       LA
# 43269        1.0     Couch            flexible         False       LA
# 53916        1.0  Real Bed            flexible         False      NYC
# 70293        1.0  Real Bed              strict          True       SF
# 65588        1.0  Real Bed            moderate          True       DC
# 50577        1.0  Real Bed              strict         False      NYC
# 23917        1.0  Real Bed            flexible         False      NYC
# 58173        1.0     Futon            flexible         False      NYC
# 34330        0.0  Real Bed            flexible         False       LA
# 70246        1.0  Real Bed              strict          True       LA
# 19445        1.5  Real Bed            flexible         False       LA
# 7168         6.5  Real Bed            flexible          True       LA
# 25436        8.0  Real Bed              strict          True       LA
# 64955        4.5  Real Bed              strict          True       LA
# 7832         5.0  Real Bed            moderate         False       LA
# 71168        2.5  Real Bed              strict         False       DC
# 68844        6.0  Real Bed              strict          True       LA
# 32298        2.0  Real Bed            flexible         False       LA
# 61435        3.0  Real Bed            flexible         False       LA
# 23121        6.5  Real Bed              strict          True       LA
# 21155        6.0  Real Bed            flexible          True       LA
# 9349         3.0  Real Bed            flexible          True       LA
# 37424        4.5  Real Bed              strict         False       DC
# 2362         3.5  Real Bed              strict          True      NYC
# 20722        5.5  Real Bed              strict         False       LA
# 61826        7.5  Real Bed              strict          True       LA
# 9390         1.0  Real Bed              strict         False       SF
# 54994        4.0  Real Bed            flexible          True       LA
# 3063         7.5  Real Bed              strict          True       LA
# 60071        1.0  Real Bed              strict         False       DC
# 42672        1.0  Real Bed            moderate          True      NYC
# 72609        2.5  Real Bed            flexible         False       DC
#
#                                              description first_review  \
# 11632  Comfortable dwellings .. My comfy home is for ...   2017-08-17
# 25239  If the dates that you want to book are not ava...   2016-05-31
# 19806  Bright, comfy and spacious private bed and bat...   2017-09-23
# 27021                                             TEST!!          NaN
# 37651  Perfect place to store your luggage while you ...          NaN
# 66762  Upscale, gorgeous 2-bedroom apartment has tons...   2017-09-23
# 60206  Please do NOT send a request unless you are a ...   2016-01-02
# 25655  Historic Anacostia 3 level Townhouse with 2 be...          NaN
# 69004    This is a wonderful place to stay with rebecca!          NaN
# 53289  Hey dudes! Looking for a dojo where you can pr...   2016-05-16
# 48734  A mere block from the 2nd avenue Q line, enjoy...   2017-09-26
# 6515   Private, cozy room in the heart of Little Ital...   2016-07-19
# 53742  The Building is in the heart of Manhattan, nex...   2017-06-28
# 4466                                           beautiful          NaN
# 43269  We are pleased to welcome you in our warm plac...          NaN
# 53916                   Room in 3-bed apartment for rent   2017-03-30
# 70293  You'll love staying in Hayes Valley in this be...   2017-07-10
# 65588  Light-filled airy studio in the historic Mount...   2017-01-22
# 50577  I am looking for a dog/house sitter, someone e...          NaN
# 23917  ATTENTION! READ ALL LISTING DESCRIPTION! If yo...   2017-06-21
# 58173  My roommate is leaving for one day (she just l...          NaN
# 34330  NO SLEEPING ROOM, LUGGAGE STORAGE ONLY  Only c...          NaN
# 70246  You will share the bunkbed with 1 japanese fem...   2016-06-10
# 19445                                                  s          NaN
# 7168   Fully Furnished, spectacular gated, Mediterran...   2017-02-26
# 25436  BEVERLY HILLS ESTATE. My place is good for cou...          NaN
# 64955  Sleep to the sound of the surf in this one-of-...          NaN
# 7832   Conveniently located 5 minutes from Beverly Hi...   2012-12-11
# 71168  Our Capitol Hill home is very conveniently loc...          NaN
# 68844  Our 7 bedroom Family Home is located in the mo...   2016-08-04
# 32298  Beautiful contemporary home in the hills, open...          NaN
# 61435  SOARING VIEWS!! Artfully positioned upon its o...          NaN
# 23121  A historical neighborhood of stunning architec...   2015-06-19
# 21155  My place is close to nightlife, Beverly hills,...          NaN
# 9349   Midcentury hilltop masterpiece designed by cel...          NaN
# 37424  5 bed/4.5 bath corner home in Woodley Park has...   2017-01-22
# 2362   Ultimate Soho Loft - Unique 5000 SqFt Events S...   2017-07-05
# 20722  Near Rodeo Drive in the heart of Beverly Hills...          NaN
# 61826  Villa Tramonto is available for long term rent...   2015-01-09
# 9390   The penthouse suite at Casa al Mare is a dream...          NaN
# 54994  Sited in a quiet street in the heart of West H...          NaN
# 3063   A Serene Sanctuary for the Soul!  A world away...          NaN
# 60071  Our cozy and very clean one bedroom, one bathr...          NaN
# 42672  1st Floor Loft with your own private entrance....   2015-04-10
# 72609  Spacious Trinidad rowhouse located just two mi...          NaN
#
#       host_has_profile_pic host_identity_verified host_response_rate  \
# 11632                    t                      f               100%
# 25239                    t                      t               100%
# 19806                    t                      t                NaN
# 27021                    t                      t               100%
# 37651                    t                      f                98%
# 66762                    t                      t               100%
# 60206                    t                      t                75%
# 25655                    t                      t               100%
# 69004                    t                      t                NaN
# 53289                    t                      f                NaN
# 48734                    t                      f               100%
# 6515                     t                      t               100%
# 53742                    t                      t                60%
# 4466                     t                      f                NaN
# 43269                    t                      f                NaN
# 53916                    t                      f                NaN
# 70293                    t                      f               100%
# 65588                    t                      t                67%
# 50577                    t                      t                67%
# 23917                    t                      t                80%
# 58173                    t                      f                NaN
# 34330                    t                      t                95%
# 70246                    t                      t               100%
# 19445                    f                      f                NaN
# 7168                     t                      t                91%
# 25436                    t                      t               100%
# 64955                    t                      t                91%
# 7832                     t                      t               100%
# 71168                    t                      f                NaN
# 68844                    t                      t                90%
# 32298                    t                      f                40%
# 61435                    t                      f                NaN
# 23121                    t                      t                NaN
# 21155                    t                      f               100%
# 9349                     t                      f               100%
# 37424                    t                      t               100%
# 2362                     t                      t               100%
# 20722                    t                      t               100%
# 61826                    t                      t                91%
# 9390                     t                      t               100%
# 54994                    t                      t                NaN
# 3063                     t                      t               100%
# 60071                    t                      t                NaN
# 42672                    t                      f                NaN
# 72609                    t                      t                NaN
#
#        host_since instant_bookable last_review   latitude   longitude  \
# 11632  2017-07-20                t  2017-10-01  40.838054  -73.858665
# 25239  2016-03-03                t  2017-05-09  38.912090  -77.003552
# 19806  2014-10-21                f  2017-09-23  37.782833 -122.390453
# 27021  2016-03-21                f         NaN  34.097784 -118.325798
# 37651  2015-11-18                t         NaN  33.997256 -118.297677
# 66762  2014-07-16                f  2017-09-23  40.732239  -73.952745
# 60206  2013-09-19                f  2016-10-03  38.901436  -77.047139
# 25655  2017-05-01                f         NaN  38.859710  -76.980877
# 69004  2011-07-27                f         NaN  37.777460 -122.409477
# 53289  2016-05-05                f  2016-06-01  40.715156  -74.007073
# 48734  2013-10-20                f  2017-09-26  40.768362  -73.955718
# 6515   2016-01-24                t  2017-04-23  41.877105  -87.649178
# 53742  2017-06-05                f  2017-09-01  40.753809  -73.985142
# 4466   2016-04-14                f         NaN  34.199755 -118.449201
# 43269  2015-12-11                f         NaN  33.956903 -117.971333
# 53916  2016-07-18                f  2017-04-15  40.722366  -73.998174
# 70293  2014-12-09                t  2017-09-06  37.774175 -122.426574
# 65588  2013-10-10                f  2017-02-09  38.935479  -77.036649
# 50577  2011-08-09                f         NaN  40.867241  -73.918442
# 23917  2015-10-24                f  2017-06-24  40.758122  -73.989347
# 58173  2017-05-04                t         NaN  40.608473  -73.996821
# 34330  2012-09-26                f         NaN  34.091232 -118.382460
# 70246  2013-06-29                f  2016-07-24  34.088587 -118.295350
# 19445  2016-08-29                t         NaN  34.070585 -118.344717
# 7168   2015-08-22                f  2017-04-30  34.168157 -118.444575
# 25436  2016-03-23                f         NaN  34.092470 -118.404075
# 64955  2013-04-18                f         NaN  34.042655 -118.558684
# 7832   2012-12-03                f  2016-07-17  34.111815 -118.439056
# 71168  2014-07-24                f         NaN  38.886599  -76.989425
# 68844  2012-08-05                f  2016-08-04  34.038965 -118.487041
# 32298  2016-01-31                f         NaN  34.152249 -118.621110
# 61435  2014-01-21                f         NaN  34.101980 -118.369025
# 23121  2010-06-29                f  2015-08-03  34.071251 -118.321745
# 21155  2016-01-01                f         NaN  34.132164 -118.448221
# 9349   2017-02-21                f         NaN  34.088505 -118.471134
# 37424  2013-02-01                f  2017-03-14  38.928557  -77.057291
# 2362   2017-03-11                t  2017-09-20  40.722068  -74.002320
# 20722  2015-03-30                f         NaN  34.069205 -118.389548
# 61826  2013-04-18                t  2017-04-30  34.042871 -118.556838
# 9390   2015-02-23                f         NaN  37.787035 -122.493215
# 54994  2015-07-18                f         NaN  34.079099 -118.377806
# 3063   2012-09-28                f         NaN  34.123808 -118.628714
# 60071  2016-10-08                f         NaN  38.947020  -77.066699
# 42672  2013-05-23                f  2015-08-20  40.728233  -73.989335
# 72609  2016-06-20                t         NaN  38.904998  -76.986020
#
#                                                     name  \
# 11632                                     Esteem's Place
# 25239                  Center of The Washington DC-BUNKS
# 19806                   Private bed/bath in lux building
# 27021                                           TEST!!!!
# 37651                    Store UR Luggage in Los Angeles
# 66762  Gorgeous upscale 2bdrm apt w/ HUGE private ter...
# 60206                 Free for Refugees & Bernie Sanders
# 25655      Beautiful 3 level townhouse w/ garage parking
# 69004                  Incredible, bright Dogpatch loft!
# 53289                                        Turtle Lair
# 48734                   Romantic nest on upper east side
# 6515   LOW BUDGET + FREE PARKING & WIFI 5 MIN TO DOWN...
# 53742                       Lux Apartment @ Times Square
# 4466                                           apartment
# 43269                 Nice couch and extra comfort chair
# 53916                                            Jen Apt
# 70293                   2-Bed Condo Oasis in SF downtown
# 65588        Light-filled airy studio in the heart of DC
# 50577                                       $10 a night!
# 23917  Shared funny cozy room one block from Times Sq...
# 58173                 420! Place to crash for the night.
# 34330  Private SuitcaseSpace Sunset Strip, Beverly Hills
# 70246            Shared (w3) Bunk-Bed room with 1 female
# 19445                                                 12
# 7168         Luxurious Indoor/Outdoor Entertainment Home
# 25436                               BEVERLY HILLS ESTATE
# 64955                Coastline View Villa,  6,200 sq.ft.
# 7832     Bev Hills lux resort with Cinema +LAX transfers
# 71168                 Comfortable Capitol Hill Row House
# 68844                    Santa Monica Beach Contemporary
# 32298                    Remodeled home! Great backyard!
# 61435                THE HOLLYWOOD LIFESTYLE! 1MONTH MIN
# 23121                  Gorgeous Hollywood Home- Walkable
# 21155                          Private Gated View Estate
# 9349            Midcentury Hilltop Masterpiece in Belair
# 37424                  Spacious Woodley Park family home
# 2362   Ultimate Soho Luxury Loft with 5000SqFt of space.
# 20722                              Beverly Hills Mansion
# 61826                  Ocean View Villa,  12,000 sq.ft.
# 9390         Golden Gate Penthouse Suite at Casa al Mare
# 54994                GORGEOUS MANSION TRENDY WEST HOLLYW
# 3063                                      Tara Sanctuary
# 60071                Cozy apartment in Van Ness on metro
# 42672                    Huge Loft with Private Entrance
# 72609           Spacious Three-bedroom Trinidad Rowhouse
#
#                neighbourhood  number_of_reviews  review_scores_rating  \
# 11632            Parkchester                  3                  87.0
# 25239              Eckington                 41                  96.0
# 19806            South Beach                  1                 100.0
# 27021                    NaN                  0                   NaN
# 37651               South LA                  0                   NaN
# 66762             Greenpoint                  1                  80.0
# 60206                    NaN                  5                 100.0
# 25655              Anacostia                  0                   NaN
# 69004                   SoMa                  0                   NaN
# 53289                Tribeca                  8                 100.0
# 48734        Upper East Side                  1                 100.0
# 6515     West Loop/Greektown                 78                  89.0
# 53742                Midtown                  4                  95.0
# 4466                Van Nuys                  0                   NaN
# 43269                    NaN                  0                   NaN
# 53916                   Soho                  1                   NaN
# 70293           Hayes Valley                  2                 100.0
# 65588         Mount Pleasant                  3                  87.0
# 50577                 Inwood                  0                   NaN
# 23917         Hell's Kitchen                  2                 100.0
# 58173            Bensonhurst                  0                   NaN
# 34330                    NaN                  0                   NaN
# 70246         East Hollywood                  5                  96.0
# 19445           Mid-Wilshire                  0                   NaN
# 7168            Sherman Oaks                  2                 100.0
# 25436                    NaN                  0                   NaN
# 64955      Pacific Palisades                  0                   NaN
# 7832   Bel Air/Beverly Crest                 55                  96.0
# 71168           Capitol Hill                  0                   NaN
# 68844           Santa Monica                  1                 100.0
# 32298                    NaN                  0                   NaN
# 61435          Laurel Canyon                  0                   NaN
# 23121           Mid-Wilshire                  2                 100.0
# 21155           Sherman Oaks                  0                   NaN
# 9349   Bel Air/Beverly Crest                  0                   NaN
# 37424           Woodley Park                  2                 100.0
# 2362                    Soho                  2                 100.0
# 20722                    NaN                  0                   NaN
# 61826      Pacific Palisades                 15                  98.0
# 9390               Sea Cliff                  0                   NaN
# 54994         West Hollywood                  0                   NaN
# 3063                 Topanga                  0                   NaN
# 60071                    NaN                  0                   NaN
# 42672           East Village                 20                  85.0
# 72609               Trinidad                  0                   NaN
#
#                                            thumbnail_url zipcode  bedrooms  \
# 11632  https://a0.muscache.com/im/pictures/71bc085f-b...   10462       1.0
# 25239  https://a0.muscache.com/im/pictures/2a11e401-c...   20002       1.0
# 19806  https://a0.muscache.com/im/pictures/4b51f35c-e...   94107       1.0
# 27021                                                NaN     NaN       1.0
# 37651  https://a0.muscache.com/im/pictures/32941e7e-0...   90037       1.0
# 66762  https://a0.muscache.com/im/pictures/d5aaa512-a...   11222       2.0
# 60206                                                NaN   20037       0.0
# 25655  https://a0.muscache.com/im/pictures/733d6719-7...   20020       2.0
# 69004  https://a0.muscache.com/im/pictures/111366014/...   94103       0.0
# 53289  https://a0.muscache.com/im/pictures/f623d520-7...   10013       3.0
# 48734  https://a0.muscache.com/im/pictures/eba39fff-9...   10021       1.0
# 6515   https://a0.muscache.com/im/pictures/ca957f28-9...   60607       1.0
# 53742  https://a0.muscache.com/im/pictures/5331c3fe-6...   10001       0.0
# 4466   https://a0.muscache.com/im/pictures/28679947-5...   91405       1.0
# 43269  https://a0.muscache.com/im/pictures/24b2d7a4-8...   90631       1.0
# 53916  https://a0.muscache.com/im/pictures/40886339-4...   10012       1.0
# 70293  https://a0.muscache.com/im/pictures/30df7075-9...   94102       2.0
# 65588  https://a0.muscache.com/im/pictures/fd5c0b87-c...   20010       0.0
# 50577  https://a0.muscache.com/im/pictures/e82f51c9-7...   10034       1.0
# 23917  https://a0.muscache.com/im/pictures/9d86979e-9...   10036       1.0
# 58173  https://a0.muscache.com/im/pictures/41b1cfda-9...   11214       1.0
# 34330                                                NaN   90069       1.0
# 70246  https://a0.muscache.com/im/pictures/8755edf2-b...   90029       1.0
# 19445  https://a0.muscache.com/im/pictures/d264b9e7-8...   90036       0.0
# 7168   https://a0.muscache.com/im/pictures/d899aeb0-6...   91401       6.0
# 25436                                                NaN   90210       7.0
# 64955  https://a0.muscache.com/im/pictures/17705951/5...   90272       4.0
# 7832                                                 NaN   90210       4.0
# 71168                                                NaN   20003       3.0
# 68844                                                NaN   90402       7.0
# 32298  https://a0.muscache.com/im/pictures/9f61dfcb-9...     NaN       3.0
# 61435                                                NaN   90069       3.0
# 23121  https://a0.muscache.com/im/pictures/59823771/4...   90004       5.0
# 21155                                                NaN   90077       6.0
# 9349   https://a0.muscache.com/im/pictures/a6e889e2-b...   90049       3.0
# 37424  https://a0.muscache.com/im/pictures/c1fc4524-6...   20008       5.0
# 2362   https://a0.muscache.com/im/pictures/1a1520ab-8...     NaN       3.0
# 20722                                                NaN   90211       5.0
# 61826  https://a0.muscache.com/im/pictures/51059902/7...   90272       7.0
# 9390   https://a0.muscache.com/im/pictures/7fcedfed-c...   94121       1.0
# 54994                                                NaN   90048       4.0
# 3063   https://a0.muscache.com/im/pictures/6bda210b-a...   90290       8.0
# 60071                                                NaN   20008       1.0
# 42672  https://a0.muscache.com/im/pictures/27238343/0...   10003       1.0
# 72609                                                NaN   20002       3.0
#
#        beds
# 11632   1.0
# 25239   4.0
# 19806   1.0
# 27021   4.0
# 37651   1.0
# 66762   2.0
# 60206   1.0
# 25655   2.0
# 69004   1.0
# 53289   5.0
# 48734   1.0
# 6515    1.0
# 53742   1.0
# 4466    1.0
# 43269   1.0
# 53916   1.0
# 70293   2.0
# 65588   1.0
# 50577   1.0
# 23917   1.0
# 58173   1.0
# 34330  10.0
# 70246   2.0
# 19445   1.0
# 7168    6.0
# 25436  10.0
# 64955   4.0
# 7832    4.0
# 71168   4.0
# 68844   7.0
# 32298   3.0
# 61435   2.0
# 23121  11.0
# 21155   6.0
# 9349    3.0
# 37424   6.0
# 2362    5.0
# 20722  10.0
# 61826  16.0
# 9390    1.0
# 54994   7.0
# 3063   11.0
# 60071   2.0
# 42672   1.0
# 72609   3.0

# %%
df_train.drop(df_train[df_train['log_price']==0].index, inplace = True)

# %% [markdown]
# For modelling purposes it would be enough to detele just 0 price record

# %%
df_train[df_train['log_price']< 2]
# Out:
# Empty DataFrame
# Columns: [id, log_price, property_type, room_type, amenities, accommodates, bathrooms, bed_type, cancellation_policy, cleaning_fee, city, description, first_review, host_has_profile_pic, host_identity_verified, host_response_rate, host_since, instant_bookable, last_review, latitude, longitude, name, neighbourhood, number_of_reviews, review_scores_rating, thumbnail_url, zipcode, bedrooms, beds]
# Index: []

# %% [markdown]
# ### Data preparation

# %%
amenities_set = set()
for amenitie in df_train['amenities']:
    amenitie_set = set(re.sub(r'(\"|\{|\})', '', amenitie).split(','))
    for piece in amenitie_set:
        if "translation missing" not in piece and piece:
            amenities_set.add(piece.strip())
            
amenities_set
# Out:
# {'24-hour check-in',
#  'Accessible-height bed',
#  'Accessible-height toilet',
#  'Air conditioning',
#  'Air purifier',
#  'BBQ grill',
#  'Baby bath',
#  'Baby monitor',
#  'Babysitter recommendations',
#  'Bathtub',
#  'Bathtub with shower chair',
#  'Beach essentials',
#  'Beachfront',
#  'Bed linens',
#  'Breakfast',
#  'Buzzer/wireless intercom',
#  'Cable TV',
#  'Carbon monoxide detector',
#  'Cat(s)',
#  'Changing table',
#  'Children’s books and toys',
#  'Children’s dinnerware',
#  'Cleaning before checkout',
#  'Coffee maker',
#  'Cooking basics',
#  'Crib',
#  'Disabled parking spot',
#  'Dishes and silverware',
#  'Dishwasher',
#  'Dog(s)',
#  'Doorman',
#  'Doorman Entry',
#  'Dryer',
#  'EV charger',
#  'Elevator',
#  'Elevator in building',
#  'Essentials',
#  'Ethernet connection',
#  'Extra pillows and blankets',
#  'Family/kid friendly',
#  'Fire extinguisher',
#  'Fireplace guards',
#  'Firm matress',
#  'Firm mattress',
#  'First aid kit',
#  'Fixed grab bars for shower & toilet',
#  'Flat',
#  'Flat smooth pathway to front door',
#  'Free parking on premises',
#  'Free parking on street',
#  'Game console',
#  'Garden or backyard',
#  'Ground floor access',
#  'Gym',
#  'Hair dryer',
#  'Handheld shower head',
#  'Hangers',
#  'Heating',
#  'High chair',
#  'Host greets you',
#  'Hot tub',
#  'Hot water',
#  'Hot water kettle',
#  'Indoor fireplace',
#  'Internet',
#  'Iron',
#  'Keypad',
#  'Kitchen',
#  'Lake access',
#  'Laptop friendly workspace',
#  'Lock on bedroom door',
#  'Lockbox',
#  'Long term stays allowed',
#  'Luggage dropoff allowed',
#  'Microwave',
#  'Other',
#  'Other pet(s)',
#  'Outlet covers',
#  'Oven',
#  'Pack ’n Play/travel crib',
#  'Paid parking off premises',
#  'Path to entrance lit at night',
#  'Patio or balcony',
#  'Pets allowed',
#  'Pets live on this property',
#  'Pocket wifi',
#  'Pool',
#  'Private bathroom',
#  'Private entrance',
#  'Private living room',
#  'Refrigerator',
#  'Roll-in shower with chair',
#  'Room-darkening shades',
#  'Safety card',
#  'Self Check-In',
#  'Shampoo',
#  'Single level home',
#  'Ski in/Ski out',
#  'Smart lock',
#  'Smartlock',
#  'Smoke detector',
#  'Smoking allowed',
#  'Stair gates',
#  'Step-free access',
#  'Stove',
#  'Suitable for events',
#  'TV',
#  'Table corner guards',
#  'Washer',
#  'Washer / Dryer',
#  'Waterfront',
#  'Well-lit path to entrance',
#  'Wheelchair accessible',
#  'Wide clearance to bed',
#  'Wide clearance to shower & toilet',
#  'Wide doorway',
#  'Wide entryway',
#  'Wide hallway clearance',
#  'Window guards',
#  'Wireless Internet',
#  'smooth pathway to front door'}

# %% [markdown]
# **Creating Dummy datasets and dataframes**

# %%
def dummification(df):
    dummy_df = pd.DataFrame()
    object_cols = ['property_type', 'room_type', 'bed_type', 'cancellation_policy', 'city', 'first_review', 'neighbourhood']
    for col in object_cols:
        dummy_df = pd.concat([dummy_df, create_dummy(col, df)], axis = 1)
    
    return pd.concat([df.drop(columns = object_cols), dummy_df], axis = 1)
        
def create_dummy(col, df):
    df_dummy = pd.get_dummies(df[col], drop_first = True)
    df_dummy.columns = ['dum: ' + col + ': ' + name for name in df_dummy.columns]
    return df_dummy

def dum_col_filling(main_col_val, dum_col_name, main_col_name):
    if dum_col_name.replace(main_col_name + ': ', '') in main_col_val:
        return 1
    else:
        return 0

def set_to_dummies(df, column_name):
    all_values_of_sets = amenities_set
    dummy_columns_name = [column_name + ': ' + dum_col for dum_col in all_values_of_sets if dum_col]
    dummy_df = pd.DataFrame(0, index=df.index, columns=dummy_columns_name)
    df = pd.concat([dummy_df, df], axis = 1)
    for dum_col_name in dummy_columns_name:
        for i in df.index:
            df[dum_col_name][i] = dum_col_filling(df[column_name][i], dum_col_name, column_name)
    return df

def property_type_proc(val):
    if val in popular_property_types:
        return val
    else:
        return 'other'
    
def cancellation_policy_proc(val):
    if val in popular_cancellation_policy:
        return val
    else:
        return 'other'
    
def host_response_rate_proc(val):
    if pd.isna(val):
        return -100
    else:
        return float(val.replace('%', ''))

def first_review_poc(val):
    if pd.isna(val):
        return 'no data'
    elif datetime.strptime(val,'%Y-%m-%d').year < 2014:
        return ' < 2014'
    else:
        return str(int(datetime.strptime(val,'%Y-%m-%d').year))
    
def unknown_filling(val):
    if pd.isna(val):
        return 'no data'
    else:
        return val

def host_since_proc(val):
    if pd.isna(val):
        return 2008
    else:
        return int(datetime.strptime(val,'%Y-%m-%d').year)

def true_to_1(val):
    if val in {'True', True, 't'}:
        return 1
    else:
        return 0
    
def processing(df):
    df = df.copy()
    df['property_type'] = df['property_type'].apply(property_type_proc)
    df['cancellation_policy'] = df['cancellation_policy'].apply(cancellation_policy_proc)
    df['host_response_rate'] = df['host_response_rate'].apply(host_response_rate_proc)
    df['first_review'] = df['first_review'].apply(first_review_poc)
    df['neighbourhood'] = df['neighbourhood'].apply(unknown_filling)
    df['review_scores_rating'] = df['review_scores_rating'].fillna(0)
    df['bathrooms'] = df['bathrooms'].fillna(-1)
    df['bedrooms'] = df['bedrooms'].fillna(-1)
    df['beds'] = df['beds'].fillna(-1)
    df['host_has_profile_pic'] = df['host_has_profile_pic'].fillna('f')
    df['host_identity_verified'] = df['host_identity_verified'].fillna('f')
    df['host_since'] = df['host_since'].apply(host_since_proc)
    df['cleaning_fee'] = df['cleaning_fee'].apply(true_to_1)
    df['host_has_profile_pic'] = df['host_has_profile_pic'].apply(true_to_1)
    df['host_identity_verified'] = df['host_identity_verified'].apply(true_to_1)
    df['instant_bookable'] = df['instant_bookable'].apply(true_to_1)
    df = set_to_dummies(df, 'amenities')
    df = dummification(df)
    df.drop(['amenities', 'thumbnail_url', 'description', 'id', 'last_review', 'zipcode', 'name'], axis = 1, inplace = True)
    return df.sort_index(ascending=False, axis=1)

#df_d = processing(df.sample(frac=0.01,random_state=101))
df_d = processing(df_train)
df_d.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24128\675453541.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        review_scores_rating  number_of_reviews   longitude  log_price  \
# 17236                   0.0                  0  -71.110867   4.941642
# 58369                  93.0                  3 -118.447229   4.382027
# 44240                  95.0                 70  -87.656500   5.293305
# 57759                  95.0                 94  -87.708795   4.060443
# 40254                  91.0                 68 -118.375224   4.174387
#
#         latitude  instant_bookable  host_since  host_response_rate  \
# 17236  42.328538                 0        2015               100.0
# 58369  34.033205                 1        2014                70.0
# 44240  41.947665                 1        2014               100.0
# 57759  41.882181                 0        2014               100.0
# 40254  33.928853                 1        2015               100.0
#
#        host_identity_verified  host_has_profile_pic  \
# 17236                       1                     1
# 58369                       1                     1
# 44240                       1                     1
# 57759                       1                     1
# 40254                       1                     1
#
#        dum: room_type: Shared room  dum: room_type: Private room  \
# 17236                            0                             0
# 58369                            0                             1
# 44240                            0                             0
# 57759                            0                             1
# 40254                            0                             1
#
#        dum: property_type: other  dum: property_type: Villa  \
# 17236                          0                          0
# 58369                          0                          0
# 44240                          0                          0
# 57759                          0                          0
# 40254                          0                          0
#
#        dum: property_type: Townhouse  dum: property_type: Other  \
# 17236                              0                          0
# 58369                              0                          0
# 44240                              0                          0
# 57759                              0                          0
# 40254                              0                          0
#
#        dum: property_type: Loft  dum: property_type: House  \
# 17236                         0                          0
# 58369                         0                          0
# 44240                         0                          0
# 57759                         0                          1
# 40254                         0                          1
#
#        dum: property_type: Guesthouse  dum: property_type: Guest suite  \
# 17236                               0                                0
# 58369                               0                                0
# 44240                               0                                0
# 57759                               0                                0
# 40254                               0                                0
#
#        dum: property_type: Dorm  dum: property_type: Condominium  \
# 17236                         0                                0
# 58369                         0                                0
# 44240                         0                                0
# 57759                         0                                0
# 40254                         0                                0
#
#        dum: property_type: Camper/RV  dum: property_type: Bungalow  \
# 17236                              0                             0
# 58369                              0                             0
# 44240                              0                             0
# 57759                              0                             0
# 40254                              0                             0
#
#        dum: property_type: Bed & Breakfast  dum: neighbourhood: no data  \
# 17236                                    0                            0
# 58369                                    0                            0
# 44240                                    0                            0
# 57759                                    0                            1
# 40254                                    0                            0
#
#        dum: neighbourhood: Wrigleyville  dum: neighbourhood: Woodside  \
# 17236                                 0                             0
# 58369                                 0                             0
# 44240                                 1                             0
# 57759                                 0                             0
# 40254                                 0                             0
#
#        dum: neighbourhood: Woodridge  dum: neighbourhood: Woodley Park  \
# 17236                              0                                 0
# 58369                              0                                 0
# 44240                              0                                 0
# 57759                              0                                 0
# 40254                              0                                 0
#
#        dum: neighbourhood: Woodlawn  \
# 17236                             0
# 58369                             0
# 44240                             0
# 57759                             0
# 40254                             0
#
#        dum: neighbourhood: Woodland Hills/Warner Center  \
# 17236                                                 0
# 58369                                                 0
# 44240                                                 0
# 57759                                                 0
# 40254                                                 0
#
#        dum: neighbourhood: Woodland  dum: neighbourhood: Woodhaven  \
# 17236                             0                              0
# 58369                             0                              0
# 44240                             0                              0
# 57759                             0                              0
# 40254                             0                              0
#
#        dum: neighbourhood: Winthrop  dum: neighbourhood: Winnetka  \
# 17236                             0                             0
# 58369                             0                             0
# 44240                             0                             0
# 57759                             0                             0
# 40254                             0                             0
#
#        dum: neighbourhood: Windsor Terrace  dum: neighbourhood: Wilmington  \
# 17236                                    0                               0
# 58369                                    0                               0
# 44240                                    0                               0
# 57759                                    0                               0
# 40254                                    0                               0
#
#        dum: neighbourhood: Williamsburg  dum: neighbourhood: Williamsbridge  \
# 17236                                 0                                   0
# 58369                                 0                                   0
# 44240                                 0                                   0
# 57759                                 0                                   0
# 40254                                 0                                   0
#
#        dum: neighbourhood: Wicker Park  dum: neighbourhood: Whittier  \
# 17236                                0                             0
# 58369                                0                             0
# 44240                                0                             0
# 57759                                0                             0
# 40254                                0                             0
#
#        dum: neighbourhood: Whitestone  dum: neighbourhood: Westwood  \
# 17236                               0                             0
# 58369                               0                             0
# 44240                               0                             0
# 57759                               0                             0
# 40254                               0                             0
#
#        dum: neighbourhood: Westside  dum: neighbourhood: Westlake  \
# 17236                             0                             0
# 58369                             0                             0
# 44240                             0                             0
# 57759                             0                             0
# 40254                             0                             0
#
#        dum: neighbourhood: Western Addition/NOPA  \
# 17236                                          0
# 58369                                          0
# 44240                                          0
# 57759                                          0
# 40254                                          0
#
#        dum: neighbourhood: Westerleigh  \
# 17236                                0
# 58369                                0
# 44240                                0
# 57759                                0
# 40254                                0
#
#        dum: neighbourhood: Westchester/Playa Del Rey  \
# 17236                                              0
# 58369                                              0
# 44240                                              0
# 57759                                              0
# 40254                                              0
#
#        dum: neighbourhood: Westchester Village  \
# 17236                                        0
# 58369                                        0
# 44240                                        0
# 57759                                        0
# 40254                                        0
#
#        dum: neighbourhood: West Village  \
# 17236                                 0
# 58369                                 0
# 44240                                 0
# 57759                                 0
# 40254                                 0
#
#        dum: neighbourhood: West Town/Noble Square  \
# 17236                                           0
# 58369                                           0
# 44240                                           0
# 57759                                           0
# 40254                                           0
#
#        dum: neighbourhood: West Town  dum: neighbourhood: West Roxbury  \
# 17236                              0                                 0
# 58369                              0                                 0
# 44240                              0                                 0
# 57759                              0                                 0
# 40254                              0                                 0
#
#        dum: neighbourhood: West Ridge  dum: neighbourhood: West Puente Valley  \
# 17236                               0                                       0
# 58369                               0                                       0
# 44240                               0                                       0
# 57759                               0                                       0
# 40254                               0                                       0
#
#        dum: neighbourhood: West Portal  dum: neighbourhood: West Los Angeles  \
# 17236                                0                                     0
# 58369                                0                                     1
# 44240                                0                                     0
# 57759                                0                                     0
# 40254                                0                                     0
#
#        dum: neighbourhood: West Loop/Greektown  dum: neighbourhood: West Lawn  \
# 17236                                        0                              0
# 58369                                        0                              0
# 44240                                        0                              0
# 57759                                        0                              0
# 40254                                        0                              0
#
#        dum: neighbourhood: West Hollywood  dum: neighbourhood: West Hills  \
# 17236                                   0                               0
# 58369                                   0                               0
# 44240                                   0                               0
# 57759                                   0                               0
# 40254                                   0                               0
#
#        dum: neighbourhood: West Farms  dum: neighbourhood: West End  \
# 17236                               0                             0
# 58369                               0                             0
# 44240                               0                             0
# 57759                               0                             0
# 40254                               0                             0
#
#        dum: neighbourhood: West Elsdon  dum: neighbourhood: West Covina  \
# 17236                                0                                0
# 58369                                0                                0
# 44240                                0                                0
# 57759                                0                                0
# 40254                                0                                0
#
#        dum: neighbourhood: West Brighton  dum: neighbourhood: West Athens  \
# 17236                                  0                                0
# 58369                                  0                                0
# 44240                                  0                                0
# 57759                                  0                                0
# 40254                                  0                                0
#
#        dum: neighbourhood: West Adams  dum: neighbourhood: Wesley Heights  \
# 17236                               0                                   0
# 58369                               0                                   0
# 44240                               0                                   0
# 57759                               0                                   0
# 40254                               0                                   0
#
#        dum: neighbourhood: Watts  dum: neighbourhood: Watertown  \
# 17236                          0                              0
# 58369                          0                              0
# 44240                          0                              0
# 57759                          0                              0
# 40254                          0                              0
#
#        dum: neighbourhood: Washington Park  \
# 17236                                    0
# 58369                                    0
# 44240                                    0
# 57759                                    0
# 40254                                    0
#
#        dum: neighbourhood: Washington Highlands  \
# 17236                                         0
# 58369                                         0
# 44240                                         0
# 57759                                         0
# 40254                                         0
#
#        dum: neighbourhood: Washington Heights  dum: neighbourhood: Wakefield  \
# 17236                                       0                              0
# 58369                                       0                              0
# 44240                                       0                              0
# 57759                                       0                              0
# 40254                                       0                              0
#
#        dum: neighbourhood: Visitacion Valley  \
# 17236                                      0
# 58369                                      0
# 44240                                      0
# 57759                                      0
# 40254                                      0
#
#        dum: neighbourhood: Vinegar Hill  dum: neighbourhood: Venice  \
# 17236                                 0                           0
# 58369                                 0                           0
# 44240                                 0                           0
# 57759                                 0                           0
# 40254                                 0                           0
#
#        dum: neighbourhood: Van Nuys  dum: neighbourhood: Van Nest  \
# 17236                             0                             0
# 58369                             0                             0
# 44240                             0                             0
# 57759                             0                             0
# 40254                             0                             0
#
#        dum: neighbourhood: Valley Village  dum: neighbourhood: Valley Glen  \
# 17236                                   0                                0
# 58369                                   0                                0
# 44240                                   0                                0
# 57759                                   0                                0
# 40254                                   0                                0
#
#        dum: neighbourhood: Utopia  dum: neighbourhood: Uptown  \
# 17236                           0                           0
# 58369                           0                           0
# 44240                           0                           0
# 57759                           0                           0
# 40254                           0                           0
#
#        dum: neighbourhood: Upper West Side  \
# 17236                                    0
# 58369                                    0
# 44240                                    0
# 57759                                    0
# 40254                                    0
#
#        dum: neighbourhood: Upper East Side  \
# 17236                                    0
# 58369                                    0
# 44240                                    0
# 57759                                    0
# 40254                                    0
#
#        dum: neighbourhood: University Heights  \
# 17236                                       0
# 58369                                       0
# 44240                                       0
# 57759                                       0
# 40254                                       0
#
#        dum: neighbourhood: Union Square  \
# 17236                                 0
# 58369                                 0
# 44240                                 0
# 57759                                 0
# 40254                                 0
#
#        dum: neighbourhood: Ukrainian Village  \
# 17236                                      0
# 58369                                      0
# 44240                                      0
# 57759                                      0
# 40254                                      0
#
#        dum: neighbourhood: U Street Corridor  dum: neighbourhood: Twining  \
# 17236                                      0                            0
# 58369                                      0                            0
# 44240                                      0                            0
# 57759                                      0                            0
# 40254                                      0                            0
#
#        dum: neighbourhood: Twin Peaks  dum: neighbourhood: Truxton Circle  \
# 17236                               0                                   0
# 58369                               0                                   0
# 44240                               0                                   0
# 57759                               0                                   0
# 40254                               0                                   0
#
#        dum: neighbourhood: Trinidad  dum: neighbourhood: Tribeca  \
# 17236                             0                            0
# 58369                             0                            0
# 44240                             0                            0
# 57759                             0                            0
# 40254                             0                            0
#
#        dum: neighbourhood: Tremont  dum: neighbourhood: Tottenville  \
# 17236                            0                                0
# 58369                            0                                0
# 44240                            0                                0
# 57759                            0                                0
# 40254                            0                                0
#
#        dum: neighbourhood: Torrance  dum: neighbourhood: Topanga  \
# 17236                             0                            0
# 58369                             0                            0
# 44240                             0                            0
# 57759                             0                            0
# 40254                             0                            0
#
#        dum: neighbourhood: Tompkinsville  dum: neighbourhood: Toluca Lake  \
# 17236                                  0                                0
# 58369                                  0                                0
# 44240                                  0                                0
# 57759                                  0                                0
# 40254                                  0                                0
#
#        dum: neighbourhood: Times Square/Theatre District  \
# 17236                                                  0
# 58369                                                  0
# 44240                                                  0
# 57759                                                  0
# 40254                                                  0
#
#        dum: neighbourhood: Throgs Neck  dum: neighbourhood: Theater District  \
# 17236                                0                                     0
# 58369                                0                                     0
# 44240                                0                                     0
# 57759                                0                                     0
# 40254                                0                                     0
#
#        dum: neighbourhood: The Rockaways  dum: neighbourhood: The Castro  \
# 17236                                  0                               0
# 58369                                  0                               0
# 44240                                  0                               0
# 57759                                  0                               0
# 40254                                  0                               0
#
#        dum: neighbourhood: The Bronx  dum: neighbourhood: Tenderloin  \
# 17236                              0                               0
# 58369                              0                               0
# 44240                              0                               0
# 57759                              0                               0
# 40254                              0                               0
#
#        dum: neighbourhood: Temple City  dum: neighbourhood: Telegraph Hill  \
# 17236                                0                                   0
# 58369                                0                                   0
# 44240                                0                                   0
# 57759                                0                                   0
# 40254                                0                                   0
#
#        dum: neighbourhood: Tarzana  dum: neighbourhood: Takoma Park, MD  \
# 17236                            0                                    0
# 58369                            0                                    0
# 44240                            0                                    0
# 57759                            0                                    0
# 40254                            0                                    0
#
#        dum: neighbourhood: Takoma  dum: neighbourhood: Sylmar  \
# 17236                           0                           0
# 58369                           0                           0
# 44240                           0                           0
# 57759                           0                           0
# 40254                           0                           0
#
#        dum: neighbourhood: Sunset Park  dum: neighbourhood: Sunnyside  \
# 17236                                0                              0
# 58369                                0                              0
# 44240                                0                              0
# 57759                                0                              0
# 40254                                0                              0
#
#        dum: neighbourhood: Sunland/Tujunga  dum: neighbourhood: Sun Valley  \
# 17236                                    0                               0
# 58369                                    0                               0
# 44240                                    0                               0
# 57759                                    0                               0
# 40254                                    0                               0
#
#        dum: neighbourhood: Suitland-Silver Hill, MD  \
# 17236                                             0
# 58369                                             0
# 44240                                             0
# 57759                                             0
# 40254                                             0
#
#        dum: neighbourhood: Studio City  dum: neighbourhood: Stronghold  \
# 17236                                0                               0
# 58369                                0                               0
# 44240                                0                               0
# 57759                                0                               0
# 40254                                0                               0
#
#        dum: neighbourhood: Streeterville  dum: neighbourhood: Stapleton  \
# 17236                                  0                              0
# 58369                                  0                              0
# 44240                                  0                              0
# 57759                                  0                              0
# 40254                                  0                              0
#
#        dum: neighbourhood: St. George  dum: neighbourhood: St. Elizabeths  \
# 17236                               0                                   0
# 58369                               0                                   0
# 44240                               0                                   0
# 57759                               0                                   0
# 40254                               0                                   0
#
#        dum: neighbourhood: Spuyten Duyvil  dum: neighbourhood: Spring Valley  \
# 17236                                   0                                  0
# 58369                                   0                                  0
# 44240                                   0                                  0
# 57759                                   0                                  0
# 40254                                   0                                  0
#
#        dum: neighbourhood: Southwest Waterfront  \
# 17236                                         0
# 58369                                         0
# 44240                                         0
# 57759                                         0
# 40254                                         0
#
#        dum: neighbourhood: South Whittier  \
# 17236                                   0
# 58369                                   0
# 44240                                   0
# 57759                                   0
# 40254                                   0
#
#        dum: neighbourhood: South Street Seaport  \
# 17236                                         0
# 58369                                         0
# 44240                                         0
# 57759                                         0
# 40254                                         0
#
#        dum: neighbourhood: South Shore  dum: neighbourhood: South San Gabriel  \
# 17236                                0                                      0
# 58369                                0                                      0
# 44240                                0                                      0
# 57759                                0                                      0
# 40254                                0                                      0
#
#        dum: neighbourhood: South Robertson  \
# 17236                                    0
# 58369                                    0
# 44240                                    0
# 57759                                    0
# 40254                                    0
#
#        dum: neighbourhood: South Pasadena  \
# 17236                                   0
# 58369                                   0
# 44240                                   0
# 57759                                   0
# 40254                                   0
#
#        dum: neighbourhood: South Ozone Park  \
# 17236                                     0
# 58369                                     0
# 44240                                     0
# 57759                                     0
# 40254                                     0
#
#        dum: neighbourhood: South Loop/Printers Row  \
# 17236                                            0
# 58369                                            0
# 44240                                            0
# 57759                                            0
# 40254                                            0
#
#        dum: neighbourhood: South LA  dum: neighbourhood: South Gate  \
# 17236                             0                               0
# 58369                             0                               0
# 44240                             0                               0
# 57759                             0                               0
# 40254                             0                               0
#
#        dum: neighbourhood: South End  dum: neighbourhood: South El Monte  \
# 17236                              0                                   0
# 58369                              0                                   0
# 44240                              0                                   0
# 57759                              0                                   0
# 40254                              0                                   0
#
#        dum: neighbourhood: South Chicago  dum: neighbourhood: South Boston  \
# 17236                                  0                                 0
# 58369                                  0                                 0
# 44240                                  0                                 0
# 57759                                  0                                 0
# 40254                                  0                                 0
#
#        dum: neighbourhood: South Beach  dum: neighbourhood: Soundview  \
# 17236                                0                              0
# 58369                                0                              0
# 44240                                0                              0
# 57759                                0                              0
# 40254                                0                              0
#
#        dum: neighbourhood: Somerville  dum: neighbourhood: Soho  \
# 17236                               0                         0
# 58369                               0                         0
# 44240                               0                         0
# 57759                               0                         0
# 40254                               0                         0
#
#        dum: neighbourhood: SoMa  dum: neighbourhood: Skyland  \
# 17236                         0                            0
# 58369                         0                            0
# 44240                         0                            0
# 57759                         0                            0
# 40254                         0                            0
#
#        dum: neighbourhood: Skid Row  dum: neighbourhood: Silver Spring, MD  \
# 17236                             0                                      0
# 58369                             0                                      0
# 44240                             0                                      0
# 57759                             0                                      0
# 40254                             0                                      0
#
#        dum: neighbourhood: Silver Lake  dum: neighbourhood: Signal Hill  \
# 17236                                0                                0
# 58369                                0                                0
# 44240                                0                                0
# 57759                                0                                0
# 40254                                0                                0
#
#        dum: neighbourhood: Sierra Madre  dum: neighbourhood: Shipley Terrace  \
# 17236                                 0                                    0
# 58369                                 0                                    0
# 44240                                 0                                    0
# 57759                                 0                                    0
# 40254                                 0                                    0
#
#        dum: neighbourhood: Sherman Oaks  dum: neighbourhood: Shepherd Park  \
# 17236                                 0                                  0
# 58369                                 0                                  0
# 44240                                 0                                  0
# 57759                                 0                                  0
# 40254                                 0                                  0
#
#        dum: neighbourhood: Sheepshead Bay  dum: neighbourhood: Shaw  \
# 17236                                   0                         0
# 58369                                   0                         0
# 44240                                   0                         0
# 57759                                   0                         0
# 40254                                   0                         0
#
#        dum: neighbourhood: Sea Gate  dum: neighbourhood: Sea Cliff  \
# 17236                             0                              0
# 58369                             0                              0
# 44240                             0                              0
# 57759                             0                              0
# 40254                             0                              0
#
#        dum: neighbourhood: Santa Monica  dum: neighbourhood: Santa Fe Springs  \
# 17236                                 0                                     0
# 58369                                 0                                     0
# 44240                                 0                                     0
# 57759                                 0                                     0
# 40254                                 0                                     0
#
#        dum: neighbourhood: San Pedro  dum: neighbourhood: San Marino  \
# 17236                              0                               0
# 58369                              0                               0
# 44240                              0                               0
# 57759                              0                               0
# 40254                              0                               0
#
#        dum: neighbourhood: San Gabriel  dum: neighbourhood: Russian Hill  \
# 17236                                0                                 0
# 58369                                0                                 0
# 44240                                0                                 0
# 57759                                0                                 0
# 40254                                0                                 0
#
#        dum: neighbourhood: Roxbury  dum: neighbourhood: Roslindale  \
# 17236                            0                               0
# 58369                            0                               0
# 44240                            0                               0
# 57759                            0                               0
# 40254                            0                               0
#
#        dum: neighbourhood: Rosemead  dum: neighbourhood: Roseland  \
# 17236                             0                             0
# 58369                             0                             0
# 44240                             0                             0
# 57759                             0                             0
# 40254                             0                             0
#
#        dum: neighbourhood: Rosebank  dum: neighbourhood: Roscoe Village  \
# 17236                             0                                   0
# 58369                             0                                   0
# 44240                             0                                   0
# 57759                             0                                   0
# 40254                             0                                   0
#
#        dum: neighbourhood: Roosevelt Island  \
# 17236                                     0
# 58369                                     0
# 44240                                     0
# 57759                                     0
# 40254                                     0
#
#        dum: neighbourhood: Rolling Hills Estates  \
# 17236                                          0
# 58369                                          0
# 44240                                          0
# 57759                                          0
# 40254                                          0
#
#        dum: neighbourhood: Rolling Hills  dum: neighbourhood: Rogers Park  \
# 17236                                  0                                0
# 58369                                  0                                0
# 44240                                  0                                0
# 57759                                  0                                0
# 40254                                  0                                0
#
#        dum: neighbourhood: Riverdale  dum: neighbourhood: River West  \
# 17236                              0                               0
# 58369                              0                               0
# 44240                              0                               0
# 57759                              0                               0
# 40254                              0                               0
#
#        dum: neighbourhood: River Terrace  dum: neighbourhood: River North  \
# 17236                                  0                                0
# 58369                                  0                                0
# 44240                                  0                                0
# 57759                                  0                                0
# 40254                                  0                                0
#
#        dum: neighbourhood: Ridgewood  dum: neighbourhood: Richmond Hill  \
# 17236                              0                                  0
# 58369                              0                                  0
# 44240                              0                                  0
# 57759                              0                                  0
# 40254                              0                                  0
#
#        dum: neighbourhood: Richmond District  dum: neighbourhood: Reseda  \
# 17236                                      0                           0
# 58369                                      0                           0
# 44240                                      0                           0
# 57759                                      0                           0
# 40254                                      0                           0
#
#        dum: neighbourhood: Rego Park  dum: neighbourhood: Redondo Beach  \
# 17236                              0                                  0
# 58369                              0                                  0
# 44240                              0                                  0
# 57759                              0                                  0
# 40254                              0                                  0
#
#        dum: neighbourhood: Red Hook  dum: neighbourhood: Randle Highlands  \
# 17236                             0                                     0
# 58369                             0                                     0
# 44240                             0                                     0
# 57759                             0                                     0
# 40254                             0                                     0
#
#        dum: neighbourhood: Randall Manor  \
# 17236                                  0
# 58369                                  0
# 44240                                  0
# 57759                                  0
# 40254                                  0
#
#        dum: neighbourhood: Rancho Palos Verdes  dum: neighbourhood: Queens  \
# 17236                                        0                           0
# 58369                                        0                           0
# 44240                                        0                           0
# 57759                                        0                           0
# 40254                                        0                           0
#
#        dum: neighbourhood: Pullman  dum: neighbourhood: Prospect Heights  \
# 17236                            0                                     0
# 58369                            0                                     0
# 44240                            0                                     0
# 57759                            0                                     0
# 40254                            0                                     0
#
#        dum: neighbourhood: Printers Row  dum: neighbourhood: Presidio Heights  \
# 17236                                 0                                     0
# 58369                                 0                                     0
# 44240                                 0                                     0
# 57759                                 0                                     0
# 40254                                 0                                     0
#
#        dum: neighbourhood: Presidio  dum: neighbourhood: Potrero Hill  \
# 17236                             0                                 0
# 58369                             0                                 0
# 44240                             0                                 0
# 57759                             0                                 0
# 40254                             0                                 0
#
#        dum: neighbourhood: Portola  dum: neighbourhood: Porter Ranch  \
# 17236                            0                                 0
# 58369                            0                                 0
# 44240                            0                                 0
# 57759                            0                                 0
# 40254                            0                                 0
#
#        dum: neighbourhood: Portage Park  dum: neighbourhood: Port Richmond  \
# 17236                                 0                                  0
# 58369                                 0                                  0
# 44240                                 0                                  0
# 57759                                 0                                  0
# 40254                                 0                                  0
#
#        dum: neighbourhood: Port Morris  dum: neighbourhood: Pleasant Plains  \
# 17236                                0                                    0
# 58369                                0                                    0
# 44240                                0                                    0
# 57759                                0                                    0
# 40254                                0                                    0
#
#        dum: neighbourhood: Pleasant Hill  dum: neighbourhood: Pilsen  \
# 17236                                  0                           0
# 58369                                  0                           0
# 44240                                  0                           0
# 57759                                  0                           0
# 40254                                  0                           0
#
#        dum: neighbourhood: Pico Rivera  dum: neighbourhood: Petworth  \
# 17236                                0                             0
# 58369                                0                             0
# 44240                                0                             0
# 57759                                0                             0
# 40254                                0                             0
#
#        dum: neighbourhood: Pelham Bay  dum: neighbourhood: Pasadena  \
# 17236                               0                             0
# 58369                               0                             0
# 44240                               0                             0
# 57759                               0                             0
# 40254                               0                             0
#
#        dum: neighbourhood: Parkside  dum: neighbourhood: Parkchester  \
# ...
#
#        amenities: Patio or balcony  amenities: Path to entrance lit at night  \
# 17236                            0                                         0
# 58369                            0                                         0
# 44240                            0                                         0
# 57759                            1                                         0
# 40254                            0                                         0
#
#        amenities: Paid parking off premises  \
# 17236                                     0
# 58369                                     0
# 44240                                     0
# 57759                                     0
# 40254                                     0
#
#        amenities: Pack ’n Play/travel crib  amenities: Oven  \
# 17236                                    0                1
# 58369                                    0                0
# 44240                                    0                0
# 57759                                    0                1
# 40254                                    0                0
#
#        amenities: Outlet covers  amenities: Other pet(s)  amenities: Other  \
# 17236                         0                        0                 0
# 58369                         0                        0                 0
# 44240                         0                        0                 0
# 57759                         0                        0                 0
# 40254                         0                        0                 0
#
#        amenities: Microwave  amenities: Luggage dropoff allowed  \
# 17236                     0                                   0
# 58369                     0                                   0
# 44240                     0                                   0
# 57759                     1                                   0
# 40254                     0                                   0
#
#        amenities: Long term stays allowed  amenities: Lockbox  \
# 17236                                   1                   0
# 58369                                   0                   0
# 44240                                   0                   0
# 57759                                   0                   0
# 40254                                   0                   0
#
#        amenities: Lock on bedroom door  amenities: Laptop friendly workspace  \
# 17236                                0                                     1
# 58369                                1                                     0
# 44240                                0                                     1
# 57759                                0                                     1
# 40254                                0                                     1
#
#        amenities: Lake access  amenities: Kitchen  amenities: Keypad  \
# 17236                       0                   1                  0
# 58369                       0                   1                  0
# 44240                       0                   1                  1
# 57759                       0                   1                  0
# 40254                       0                   1                  0
#
#        amenities: Iron  amenities: Internet  amenities: Indoor fireplace  \
# 17236                1                    1                            0
# 58369                1                    1                            0
# 44240                1                    1                            0
# 57759                1                    1                            0
# 40254                1                    1                            1
#
#        amenities: Hot water kettle  amenities: Hot water  amenities: Hot tub  \
# 17236                            0                     1                   0
# 58369                            0                     0                   0
# 44240                            0                     0                   0
# 57759                            0                     1                   0
# 40254                            0                     0                   0
#
#        amenities: Host greets you  amenities: High chair  amenities: Heating  \
# 17236                           0                      0                   1
# 58369                           0                      0                   1
# 44240                           0                      0                   1
# 57759                           0                      0                   1
# 40254                           0                      0                   1
#
#        amenities: Hangers  amenities: Handheld shower head  \
# 17236                   1                                0
# 58369                   1                                0
# 44240                   1                                0
# 57759                   1                                0
# 40254                   1                                0
#
#        amenities: Hair dryer  amenities: Gym  amenities: Ground floor access  \
# 17236                      1               1                               0
# 58369                      0               0                               0
# 44240                      1               0                               0
# 57759                      1               0                               0
# 40254                      1               0                               0
#
#        amenities: Garden or backyard  amenities: Game console  \
# 17236                              0                        0
# 58369                              0                        0
# 44240                              0                        0
# 57759                              1                        0
# 40254                              0                        0
#
#        amenities: Free parking on street  amenities: Free parking on premises  \
# 17236                                  0                                    0
# 58369                                  0                                    1
# 44240                                  0                                    0
# 57759                                  0                                    0
# 40254                                  0                                    1
#
#        amenities: Flat smooth pathway to front door  amenities: Flat  \
# 17236                                             0                0
# 58369                                             0                0
# 44240                                             0                0
# 57759                                             0                0
# 40254                                             0                0
#
#        amenities: Fixed grab bars for shower & toilet  \
# 17236                                               0
# 58369                                               0
# 44240                                               0
# 57759                                               0
# 40254                                               0
#
#        amenities: First aid kit  amenities: Firm mattress  \
# 17236                         0                         0
# 58369                         1                         0
# 44240                         1                         0
# 57759                         1                         0
# 40254                         0                         0
#
#        amenities: Firm matress  amenities: Fireplace guards  \
# 17236                        0                            0
# 58369                        0                            0
# 44240                        0                            0
# 57759                        0                            0
# 40254                        0                            0
#
#        amenities: Fire extinguisher  amenities: Family/kid friendly  \
# 17236                             0                               1
# 58369                             0                               1
# 44240                             1                               1
# 57759                             1                               0
# 40254                             1                               1
#
#        amenities: Extra pillows and blankets  amenities: Ethernet connection  \
# 17236                                      0                               0
# 58369                                      0                               0
# 44240                                      0                               0
# 57759                                      1                               0
# 40254                                      0                               0
#
#        amenities: Essentials  amenities: Elevator in building  \
# 17236                      1                                0
# 58369                      1                                0
# 44240                      1                                0
# 57759                      1                                0
# 40254                      1                                0
#
#        amenities: Elevator  amenities: EV charger  amenities: Dryer  \
# 17236                    1                      0                 1
# 58369                    0                      0                 1
# 44240                    0                      0                 1
# 57759                    0                      1                 1
# 40254                    0                      0                 1
#
#        amenities: Doorman Entry  amenities: Doorman  amenities: Dog(s)  \
# 17236                         0                   1                  0
# 58369                         0                   0                  0
# 44240                         0                   0                  0
# 57759                         0                   0                  0
# 40254                         0                   0                  1
#
#        amenities: Dishwasher  amenities: Dishes and silverware  \
# 17236                      0                                 0
# 58369                      0                                 0
# 44240                      0                                 0
# 57759                      1                                 1
# 40254                      0                                 0
#
#        amenities: Disabled parking spot  amenities: Crib  \
# 17236                                 0                0
# 58369                                 0                0
# 44240                                 0                0
# 57759                                 0                0
# 40254                                 0                0
#
#        amenities: Cooking basics  amenities: Coffee maker  \
# 17236                          0                        0
# 58369                          0                        0
# 44240                          0                        0
# 57759                          1                        1
# 40254                          0                        0
#
#        amenities: Cleaning before checkout  amenities: Children’s dinnerware  \
# 17236                                    0                                 0
# 58369                                    0                                 0
# 44240                                    0                                 0
# 57759                                    0                                 0
# 40254                                    0                                 0
#
#        amenities: Children’s books and toys  amenities: Changing table  \
# 17236                                     0                          0
# 58369                                     0                          0
# 44240                                     0                          0
# 57759                                     0                          0
# 40254                                     0                          0
#
#        amenities: Cat(s)  amenities: Carbon monoxide detector  \
# 17236                  0                                    1
# 58369                  0                                    1
# 44240                  0                                    1
# 57759                  0                                    1
# 40254                  0                                    0
#
#        amenities: Cable TV  amenities: Buzzer/wireless intercom  \
# 17236                    1                                    0
# 58369                    0                                    0
# 44240                    1                                    0
# 57759                    0                                    0
# 40254                    0                                    0
#
#        amenities: Breakfast  amenities: Bed linens  amenities: Beachfront  \
# 17236                     0                      1                      0
# 58369                     0                      0                      0
# 44240                     0                      0                      0
# 57759                     0                      1                      0
# 40254                     1                      0                      0
#
#        amenities: Beach essentials  amenities: Bathtub with shower chair  \
# 17236                            0                                     0
# 58369                            0                                     0
# 44240                            0                                     0
# 57759                            0                                     0
# 40254                            0                                     0
#
#        amenities: Bathtub  amenities: Babysitter recommendations  \
# 17236                   1                                      0
# 58369                   0                                      0
# 44240                   0                                      0
# 57759                   0                                      0
# 40254                   0                                      0
#
#        amenities: Baby monitor  amenities: Baby bath  amenities: BBQ grill  \
# 17236                        0                     0                     0
# 58369                        0                     0                     0
# 44240                        0                     0                     0
# 57759                        0                     0                     0
# 40254                        0                     0                     0
#
#        amenities: Air purifier  amenities: Air conditioning  \
# 17236                        0                            1
# 58369                        0                            0
# 44240                        0                            1
# 57759                        0                            1
# 40254                        0                            1
#
#        amenities: Accessible-height toilet  amenities: Accessible-height bed  \
# 17236                                    0                                 0
# 58369                                    0                                 0
# 44240                                    0                                 0
# 57759                                    0                                 0
# 40254                                    0                                 0
#
#        amenities: 24-hour check-in  accommodates
# 17236                            0             3
# 58369                            0             1
# 44240                            1             8
# 57759                            1             4
# 40254                            0             4

# %%
df_d[df_d.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [review_scores_rating, number_of_reviews, longitude, log_price, latitude, instant_bookable, host_since, host_response_rate, host_identity_verified, host_has_profile_pic, dum: room_type: Shared room, dum: room_type: Private room, dum: property_type: other, dum: property_type: Villa, dum: property_type: Townhouse, dum: property_type: Other, dum: property_type: Loft, dum: property_type: House, dum: property_type: Guesthouse, dum: property_type: Guest suite, dum: property_type: Dorm, dum: property_type: Condominium, dum: property_type: Camper/RV, dum: property_type: Bungalow, dum: property_type: Bed & Breakfast, dum: neighbourhood: no data, dum: neighbourhood: Wrigleyville, dum: neighbourhood: Woodside, dum: neighbourhood: Woodridge, dum: neighbourhood: Woodley Park, dum: neighbourhood: Woodlawn, dum: neighbourhood: Woodland Hills/Warner Center, dum: neighbourhood: Woodland, dum: neighbourhood: Woodhaven, dum: neighbourhood: Winthrop, dum: neighbourhood: Winnetka, dum: neighbourhood: Windsor Terrace, dum: neighbourhood: Wilmington, dum: neighbourhood: Williamsburg, dum: neighbourhood: Williamsbridge, dum: neighbourhood: Wicker Park, dum: neighbourhood: Whittier, dum: neighbourhood: Whitestone, dum: neighbourhood: Westwood, dum: neighbourhood: Westside, dum: neighbourhood: Westlake, dum: neighbourhood: Western Addition/NOPA, dum: neighbourhood: Westerleigh, dum: neighbourhood: Westchester/Playa Del Rey, dum: neighbourhood: Westchester Village, dum: neighbourhood: West Village, dum: neighbourhood: West Town/Noble Square, dum: neighbourhood: West Town, dum: neighbourhood: West Roxbury, dum: neighbourhood: West Ridge, dum: neighbourhood: West Puente Valley, dum: neighbourhood: West Portal, dum: neighbourhood: West Los Angeles, dum: neighbourhood: West Loop/Greektown, dum: neighbourhood: West Lawn, dum: neighbourhood: West Hollywood, dum: neighbourhood: West Hills, dum: neighbourhood: West Farms, dum: neighbourhood: West End, dum: neighbourhood: West Elsdon, dum: neighbourhood: West Covina, dum: neighbourhood: West Brighton, dum: neighbourhood: West Athens, dum: neighbourhood: West Adams, dum: neighbourhood: Wesley Heights, dum: neighbourhood: Watts, dum: neighbourhood: Watertown, dum: neighbourhood: Washington Park, dum: neighbourhood: Washington Highlands, dum: neighbourhood: Washington Heights, dum: neighbourhood: Wakefield, dum: neighbourhood: Visitacion Valley, dum: neighbourhood: Vinegar Hill, dum: neighbourhood: Venice, dum: neighbourhood: Van Nuys, dum: neighbourhood: Van Nest, dum: neighbourhood: Valley Village, dum: neighbourhood: Valley Glen, dum: neighbourhood: Utopia, dum: neighbourhood: Uptown, dum: neighbourhood: Upper West Side, dum: neighbourhood: Upper East Side, dum: neighbourhood: University Heights, dum: neighbourhood: Union Square, dum: neighbourhood: Ukrainian Village, dum: neighbourhood: U Street Corridor, dum: neighbourhood: Twining, dum: neighbourhood: Twin Peaks, dum: neighbourhood: Truxton Circle, dum: neighbourhood: Trinidad, dum: neighbourhood: Tribeca, dum: neighbourhood: Tremont, dum: neighbourhood: Tottenville, dum: neighbourhood: Torrance, dum: neighbourhood: Topanga, ...]
# Index: []

# %% [markdown]
# ## Prediction Model Deployment
# Predictive modeling is the subpart of data analytics that uses data mining and probability to predict results. Each model is built up by the number of predictors that are highly favorable to determine future decisions. Once the data is received for a specific predictor, an analytical model is formulated.
#
# Here we are going to use five different algorithms for the prediction model creation -
# * **Linear Regression** : Linear regression is a linear model, e.g. a model that assumes a linear relationship between the input variables (x) and the single output variable (y). ... Different techniques can be used to prepare or train the linear regression equation from data, the most common of which is called Ordinary Least Squares.
#
#
# * **Random Forest regressor** : A Random Forest is an ensemble technique capable of performing both regression and classification tasks with the use of multiple decision trees and a technique called Bootstrap and Aggregation, commonly known as bagging. The basic idea behind this is to combine multiple decision trees in determining the final output rather than relying on individual decision trees.
#
#
# * **Gradient Boosting Regressor** : Gradient boosting is a machine learning technique for regression, classification and other tasks, which produces a prediction model in the form of an ensemble of weak prediction models, typically decision trees.
#
#
# * **Neural Networks** : Neural networks, also known as artificial neural networks (ANNs) or simulated neural networks (SNNs), are a subset of machine learning and are at the heart of deep learning algorithms. Their name and structure are inspired by the human brain, mimicking the way that biological neurons signal to one another.
#
# let's deploy the model...

# %%
#adding missing columns to test \ validation sets and deleting unnecessary
columns_needed = set(df_d.columns)
def columns_standardization(df):
    df = df.copy()
    for col in columns_needed:
        if col not in set(df.columns):
            df.insert(loc = len(df.columns), column = col, value = 0, allow_duplicates=False)
    
    for col in set(df.columns):
        if col not in columns_needed:
            df.drop(columns = col, axis = 1, inplace = True)
    
    return df.sort_index(ascending=False, axis=1)

# %%
test = columns_standardization(processing(df_test))
test
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24128\675453541.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        review_scores_rating  number_of_reviews   longitude  log_price  \
# 4281                   94.0                 22  -71.080286   4.477337
# 36339                   0.0                  0 -122.426182   7.377759
# 53913                  94.0                  8  -73.956500   4.976734
# 72747                   0.0                  0 -118.565122   3.688879
# 69751                  99.0                 18  -73.949986   5.241747
# ...                     ...                ...         ...        ...
# 43562                 100.0                  1  -73.913538   3.637586
# 26475                  95.0                128 -122.401235   4.553877
# 28555                 100.0                  3 -122.408119   5.703782
# 73419                   0.0                  0 -118.475470   5.459586
# 51739                   0.0                  0 -118.376706   4.859812
#
#         latitude  instant_bookable  host_since  host_response_rate  \
# 4281   42.342498                 0        2017               100.0
# 36339  37.772892                 0        2012              -100.0
# 53913  40.719425                 0        2011              -100.0
# 72747  34.189818                 0        2013               100.0
# 69751  40.721229                 0        2013                70.0
# ...          ...               ...         ...                 ...
# 43562  40.702947                 0        2014              -100.0
# 26475  37.775361                 1        2013                97.0
# 28555  37.796619                 0        2013              -100.0
# 73419  34.003354                 0        2011              -100.0
# 51739  34.097810                 0        2016                 0.0
#
#        host_identity_verified  host_has_profile_pic  \
# 4281                        0                     1
# 36339                       1                     1
# 53913                       1                     1
# 72747                       1                     1
# 69751                       1                     1
# ...                       ...                   ...
# 43562                       1                     1
# 26475                       0                     1
# 28555                       1                     1
# 73419                       1                     1
# 51739                       1                     1
#
#        dum: room_type: Shared room  dum: room_type: Private room  \
# 4281                             0                             1
# 36339                            0                             0
# 53913                            0                             0
# 72747                            0                             1
# 69751                            0                             0
# ...                            ...                           ...
# 43562                            0                             1
# 26475                            0                             1
# 28555                            0                             0
# 73419                            0                             0
# 51739                            0                             1
#
#        dum: property_type: other  dum: property_type: Villa  \
# 4281                           0                          0
# 36339                          0                          0
# 53913                          0                          0
# 72747                          0                          0
# 69751                          0                          0
# ...                          ...                        ...
# 43562                          0                          0
# 26475                          0                          0
# 28555                          0                          0
# 73419                          0                          0
# 51739                          0                          0
#
#        dum: property_type: Townhouse  dum: property_type: Other  \
# 4281                               0                          0
# 36339                              0                          0
# 53913                              0                          0
# 72747                              0                          0
# 69751                              0                          0
# ...                              ...                        ...
# 43562                              0                          0
# 26475                              0                          0
# 28555                              0                          0
# 73419                              0                          0
# 51739                              0                          0
#
#        dum: property_type: Loft  dum: property_type: House  \
# 4281                          0                          0
# 36339                         0                          1
# 53913                         0                          0
# 72747                         0                          1
# 69751                         0                          0
# ...                         ...                        ...
# 43562                         0                          0
# 26475                         1                          0
# 28555                         0                          0
# 73419                         0                          0
# 51739                         0                          1
#
#        dum: property_type: Guesthouse  dum: property_type: Guest suite  \
# 4281                                0                                0
# 36339                               0                                0
# 53913                               0                                0
# 72747                               0                                0
# 69751                               0                                0
# ...                               ...                              ...
# 43562                               0                                0
# 26475                               0                                0
# 28555                               0                                0
# 73419                               0                                0
# 51739                               0                                0
#
#        dum: property_type: Dorm  dum: property_type: Condominium  \
# 4281                          0                                0
# 36339                         0                                0
# 53913                         0                                0
# 72747                         0                                0
# 69751                         0                                0
# ...                         ...                              ...
# 43562                         0                                0
# 26475                         0                                0
# 28555                         0                                0
# 73419                         0                                0
# 51739                         0                                0
#
#        dum: property_type: Camper/RV  dum: property_type: Bungalow  \
# 4281                               0                             0
# 36339                              0                             0
# 53913                              0                             0
# 72747                              0                             0
# 69751                              0                             0
# ...                              ...                           ...
# 43562                              0                             0
# 26475                              0                             0
# 28555                              0                             0
# 73419                              0                             0
# 51739                              0                             0
#
#        dum: property_type: Bed & Breakfast  dum: neighbourhood: no data  \
# 4281                                     0                            0
# 36339                                    0                            0
# 53913                                    0                            0
# 72747                                    0                            0
# 69751                                    0                            0
# ...                                    ...                          ...
# 43562                                    0                            0
# 26475                                    0                            0
# 28555                                    0                            0
# 73419                                    0                            0
# 51739                                    0                            1
#
#        dum: neighbourhood: Wrigleyville  dum: neighbourhood: Woodside  \
# 4281                                  0                             0
# 36339                                 0                             0
# 53913                                 0                             0
# 72747                                 0                             0
# 69751                                 0                             0
# ...                                 ...                           ...
# 43562                                 0                             0
# 26475                                 0                             0
# 28555                                 0                             0
# 73419                                 0                             0
# 51739                                 0                             0
#
#        dum: neighbourhood: Woodridge  dum: neighbourhood: Woodley Park  \
# 4281                               0                                 0
# 36339                              0                                 0
# 53913                              0                                 0
# 72747                              0                                 0
# 69751                              0                                 0
# ...                              ...                               ...
# 43562                              0                                 0
# 26475                              0                                 0
# 28555                              0                                 0
# 73419                              0                                 0
# 51739                              0                                 0
#
#        dum: neighbourhood: Woodlawn  \
# 4281                              0
# 36339                             0
# 53913                             0
# 72747                             0
# 69751                             0
# ...                             ...
# 43562                             0
# 26475                             0
# 28555                             0
# 73419                             0
# 51739                             0
#
#        dum: neighbourhood: Woodland Hills/Warner Center  \
# 4281                                                  0
# 36339                                                 0
# 53913                                                 0
# 72747                                                 1
# 69751                                                 0
# ...                                                 ...
# 43562                                                 0
# 26475                                                 0
# 28555                                                 0
# 73419                                                 0
# 51739                                                 0
#
#        dum: neighbourhood: Woodland  dum: neighbourhood: Woodhaven  \
# 4281                              0                              0
# 36339                             0                              0
# 53913                             0                              0
# 72747                             0                              0
# 69751                             0                              0
# ...                             ...                            ...
# 43562                             0                              0
# 26475                             0                              0
# 28555                             0                              0
# 73419                             0                              0
# 51739                             0                              0
#
#        dum: neighbourhood: Winthrop  dum: neighbourhood: Winnetka  \
# 4281                              0                             0
# 36339                             0                             0
# 53913                             0                             0
# 72747                             0                             0
# 69751                             0                             0
# ...                             ...                           ...
# 43562                             0                             0
# 26475                             0                             0
# 28555                             0                             0
# 73419                             0                             0
# 51739                             0                             0
#
#        dum: neighbourhood: Windsor Terrace  dum: neighbourhood: Wilmington  \
# 4281                                     0                               0
# 36339                                    0                               0
# 53913                                    0                               0
# 72747                                    0                               0
# 69751                                    0                               0
# ...                                    ...                             ...
# 43562                                    0                               0
# 26475                                    0                               0
# 28555                                    0                               0
# 73419                                    0                               0
# 51739                                    0                               0
#
#        dum: neighbourhood: Williamsburg  dum: neighbourhood: Williamsbridge  \
# 4281                                  0                                   0
# 36339                                 0                                   0
# 53913                                 1                                   0
# 72747                                 0                                   0
# 69751                                 0                                   0
# ...                                 ...                                 ...
# 43562                                 0                                   0
# 26475                                 0                                   0
# 28555                                 0                                   0
# 73419                                 0                                   0
# 51739                                 0                                   0
#
#        dum: neighbourhood: Wicker Park  dum: neighbourhood: Whittier  \
# 4281                                 0                             0
# 36339                                0                             0
# 53913                                0                             0
# 72747                                0                             0
# 69751                                0                             0
# ...                                ...                           ...
# 43562                                0                             0
# 26475                                0                             0
# 28555                                0                             0
# 73419                                0                             0
# 51739                                0                             0
#
#        dum: neighbourhood: Whitestone  dum: neighbourhood: Westwood  \
# 4281                                0                             0
# 36339                               0                             0
# 53913                               0                             0
# 72747                               0                             0
# 69751                               0                             0
# ...                               ...                           ...
# 43562                               0                             0
# 26475                               0                             0
# 28555                               0                             0
# 73419                               0                             0
# 51739                               0                             0
#
#        dum: neighbourhood: Westside  dum: neighbourhood: Westlake  \
# 4281                              0                             0
# 36339                             0                             0
# 53913                             0                             0
# 72747                             0                             0
# 69751                             0                             0
# ...                             ...                           ...
# 43562                             0                             0
# 26475                             0                             0
# 28555                             0                             0
# 73419                             0                             0
# 51739                             0                             0
#
#        dum: neighbourhood: Western Addition/NOPA  \
# 4281                                           0
# 36339                                          0
# 53913                                          0
# 72747                                          0
# 69751                                          0
# ...                                          ...
# 43562                                          0
# 26475                                          0
# 28555                                          0
# 73419                                          0
# 51739                                          0
#
#        dum: neighbourhood: Westerleigh  \
# 4281                                 0
# 36339                                0
# 53913                                0
# 72747                                0
# 69751                                0
# ...                                ...
# 43562                                0
# 26475                                0
# 28555                                0
# 73419                                0
# 51739                                0
#
#        dum: neighbourhood: Westchester/Playa Del Rey  \
# 4281                                               0
# 36339                                              0
# 53913                                              0
# 72747                                              0
# 69751                                              0
# ...                                              ...
# 43562                                              0
# 26475                                              0
# 28555                                              0
# 73419                                              0
# 51739                                              0
#
#        dum: neighbourhood: Westchester Village  \
# 4281                                         0
# 36339                                        0
# 53913                                        0
# 72747                                        0
# 69751                                        0
# ...                                        ...
# 43562                                        0
# 26475                                        0
# 28555                                        0
# 73419                                        0
# 51739                                        0
#
#        dum: neighbourhood: West Village  \
# 4281                                  0
# 36339                                 0
# 53913                                 0
# 72747                                 0
# 69751                                 0
# ...                                 ...
# 43562                                 0
# 26475                                 0
# 28555                                 0
# 73419                                 0
# 51739                                 0
#
#        dum: neighbourhood: West Town/Noble Square  \
# 4281                                            0
# 36339                                           0
# 53913                                           0
# 72747                                           0
# 69751                                           0
# ...                                           ...
# 43562                                           0
# 26475                                           0
# 28555                                           0
# 73419                                           0
# 51739                                           0
#
#        dum: neighbourhood: West Town  dum: neighbourhood: West Roxbury  \
# 4281                               0                                 0
# 36339                              0                                 0
# 53913                              0                                 0
# 72747                              0                                 0
# 69751                              0                                 0
# ...                              ...                               ...
# 43562                              0                                 0
# 26475                              0                                 0
# 28555                              0                                 0
# 73419                              0                                 0
# 51739                              0                                 0
#
#        dum: neighbourhood: West Ridge  dum: neighbourhood: West Puente Valley  \
# 4281                                0                                       0
# 36339                               0                                       0
# 53913                               0                                       0
# 72747                               0                                       0
# 69751                               0                                       0
# ...                               ...                                     ...
# 43562                               0                                       0
# 26475                               0                                       0
# 28555                               0                                       0
# 73419                               0                                       0
# 51739                               0                                       0
#
#        dum: neighbourhood: West Portal  dum: neighbourhood: West Los Angeles  \
# 4281                                 0                                     0
# 36339                                0                                     0
# 53913                                0                                     0
# 72747                                0                                     0
# 69751                                0                                     0
# ...                                ...                                   ...
# 43562                                0                                     0
# 26475                                0                                     0
# 28555                                0                                     0
# 73419                                0                                     0
# 51739                                0                                     0
#
#        dum: neighbourhood: West Loop/Greektown  dum: neighbourhood: West Lawn  \
# 4281                                         0                              0
# 36339                                        0                              0
# 53913                                        0                              0
# 72747                                        0                              0
# 69751                                        0                              0
# ...                                        ...                            ...
# 43562                                        0                              0
# 26475                                        0                              0
# 28555                                        0                              0
# 73419                                        0                              0
# 51739                                        0                              0
#
#        dum: neighbourhood: West Hollywood  dum: neighbourhood: West Hills  \
# 4281                                    0                               0
# 36339                                   0                               0
# 53913                                   0                               0
# 72747                                   0                               0
# 69751                                   0                               0
# ...                                   ...                             ...
# 43562                                   0                               0
# 26475                                   0                               0
# 28555                                   0                               0
# 73419                                   0                               0
# 51739                                   0                               0
#
#        dum: neighbourhood: West Farms  dum: neighbourhood: West End  \
# 4281                                0                             0
# 36339                               0                             0
# 53913                               0                             0
# 72747                               0                             0
# 69751                               0                             0
# ...                               ...                           ...
# 43562                               0                             0
# 26475                               0                             0
# 28555                               0                             0
# 73419                               0                             0
# 51739                               0                             0
#
#        dum: neighbourhood: West Elsdon  dum: neighbourhood: West Covina  \
# 4281                                 0                                0
# 36339                                0                                0
# 53913                                0                                0
# 72747                                0                                0
# 69751                                0                                0
# ...                                ...                              ...
# 43562                                0                                0
# 26475                                0                                0
# 28555                                0                                0
# 73419                                0                                0
# 51739                                0                                0
#
#        dum: neighbourhood: West Brighton  dum: neighbourhood: West Athens  \
# 4281                                   0                                0
# 36339                                  0                                0
# 53913                                  0                                0
# 72747                                  0                                0
# 69751                                  0                                0
# ...                                  ...                              ...
# 43562                                  0                                0
# 26475                                  0                                0
# 28555                                  0                                0
# 73419                                  0                                0
# 51739                                  0                                0
#
#        dum: neighbourhood: West Adams  dum: neighbourhood: Wesley Heights  \
# 4281                                0                                   0
# 36339                               0                                   0
# 53913                               0                                   0
# 72747                               0                                   0
# 69751                               0                                   0
# ...                               ...                                 ...
# 43562                               0                                   0
# 26475                               0                                   0
# 28555                               0                                   0
# 73419                               0                                   0
# 51739                               0                                   0
#
#        dum: neighbourhood: Watts  dum: neighbourhood: Watertown  \
# 4281                           0                              0
# 36339                          0                              0
# 53913                          0                              0
# 72747                          0                              0
# 69751                          0                              0
# ...                          ...                            ...
# 43562                          0                              0
# 26475                          0                              0
# 28555                          0                              0
# 73419                          0                              0
# 51739                          0                              0
#
#        dum: neighbourhood: Washington Park  \
# 4281                                     0
# 36339                                    0
# 53913                                    0
# 72747                                    0
# 69751                                    0
# ...                                    ...
# 43562                                    0
# 26475                                    0
# 28555                                    0
# 73419                                    0
# 51739                                    0
#
#        dum: neighbourhood: Washington Highlands  \
# 4281                                          0
# 36339                                         0
# 53913                                         0
# 72747                                         0
# 69751                                         0
# ...                                         ...
# 43562                                         0
# 26475                                         0
# 28555                                         0
# 73419                                         0
# 51739                                         0
#
#        dum: neighbourhood: Washington Heights  dum: neighbourhood: Wakefield  \
# 4281                                        0                              0
# 36339                                       0                              0
# 53913                                       0                              0
# 72747                                       0                              0
# 69751                                       0                              0
# ...                                       ...                            ...
# 43562                                       0                              0
# 26475                                       0                              0
# 28555                                       0                              0
# 73419                                       0                              0
# 51739                                       0                              0
#
#        dum: neighbourhood: Visitacion Valley  \
# 4281                                       0
# 36339                                      0
# 53913                                      0
# 72747                                      0
# 69751                                      0
# ...                                      ...
# 43562                                      0
# 26475                                      0
# 28555                                      0
# 73419                                      0
# 51739                                      0
#
#        dum: neighbourhood: Vinegar Hill  dum: neighbourhood: Venice  \
# 4281                                  0                           0
# 36339                                 0                           0
# 53913                                 0                           0
# 72747                                 0                           0
# 69751                                 0                           0
# ...                                 ...                         ...
# 43562                                 0                           0
# 26475                                 0                           0
# 28555                                 0                           0
# 73419                                 0                           0
# 51739                                 0                           0
#
#        dum: neighbourhood: Van Nuys  dum: neighbourhood: Van Nest  \
# 4281                              0                             0
# 36339                             0                             0
# 53913                             0                             0
# 72747                             0                             0
# 69751                             0                             0
# ...                             ...                           ...
# 43562                             0                             0
# 26475                             0                             0
# 28555                             0                             0
# 73419                             0                             0
# 51739                             0                             0
#
#        dum: neighbourhood: Valley Village  dum: neighbourhood: Valley Glen  \
# 4281                                    0                                0
# 36339                                   0                                0
# 53913                                   0                                0
# 72747                                   0                                0
# 69751                                   0                                0
# ...                                   ...                              ...
# 43562                                   0                                0
# 26475                                   0                                0
# 28555                                   0                                0
# 73419                                   0                                0
# 51739                                   0                                0
#
#        dum: neighbourhood: Utopia  dum: neighbourhood: Uptown  \
# 4281                            0                           0
# 36339                           0                           0
# 53913                           0                           0
# 72747                           0                           0
# 69751                           0                           0
# ...                           ...                         ...
# 43562                           0                           0
# 26475                           0                           0
# 28555                           0                           0
# 73419                           0                           0
# 51739                           0                           0
#
#        dum: neighbourhood: Upper West Side  \
# 4281                                     0
# 36339                                    0
# 53913                                    0
# 72747                                    0
# 69751                                    0
# ...                                    ...
# 43562                                    0
# 26475                                    0
# 28555                                    0
# 73419                                    0
# 51739                                    0
#
#        dum: neighbourhood: Upper East Side  \
# 4281                                     0
# 36339                                    0
# 53913                                    0
# 72747                                    0
# 69751                                    0
# ...                                    ...
# 43562                                    0
# 26475                                    0
# 28555                                    0
# 73419                                    0
# 51739                                    0
#
#        dum: neighbourhood: University Heights  \
# 4281                                        0
# 36339                                       0
# 53913                                       0
# 72747                                       0
# 69751                                       0
# ...                                       ...
# 43562                                       0
# 26475                                       0
# 28555                                       0
# 73419                                       0
# 51739                                       0
#
#        dum: neighbourhood: Union Square  \
# 4281                                  0
# 36339                                 0
# 53913                                 0
# 72747                                 0
# 69751                                 0
# ...                                 ...
# 43562                                 0
# 26475                                 0
# 28555                                 0
# 73419                                 0
# 51739                                 0
#
#        dum: neighbourhood: Ukrainian Village  \
# 4281                                       0
# 36339                                      0
# 53913                                      0
# 72747                                      0
# 69751                                      0
# ...                                      ...
# 43562                                      0
# 26475                                      0
# 28555                                      0
# 73419                                      0
# 51739                                      0
#
#        dum: neighbourhood: U Street Corridor  dum: neighbourhood: Twining  \
# 4281                                       0                            0
# 36339                                      0                            0
# 53913                                      0                            0
# 72747                                      0                            0
# 69751                                      0                            0
# ...                                      ...                          ...
# 43562                                      0                            0
# 26475                                      0                            0
# 28555                                      0                            0
# 73419                                      0                            0
# 51739                                      0                            0
#
#        dum: neighbourhood: Twin Peaks  dum: neighbourhood: Truxton Circle  \
# 4281                                0                                   0
# 36339                               0                                   0
# 53913                               0                                   0
# 72747                               0                                   0
# 69751                               0                                   0
# ...                               ...                                 ...
# 43562                               0                                   0
# 26475                               0                                   0
# 28555                               0                                   0
# 73419                               0                                   0
# 51739                               0                                   0
#
#        dum: neighbourhood: Trinidad  dum: neighbourhood: Tribeca  \
# 4281                              0                            0
# 36339                             0                            0
# 53913                             0                            0
# 72747                             0                            0
# 69751                             0                            0
# ...                             ...                          ...
# 43562                             0                            0
# 26475                             0                            0
# 28555                             0                            0
# 73419                             0                            0
# 51739                             0                            0
#
#        dum: neighbourhood: Tremont  dum: neighbourhood: Tottenville  \
# 4281                             0                                0
# 36339                            0                                0
# 53913                            0                                0
# 72747                            0                                0
# 69751                            0                                0
# ...                            ...                              ...
# 43562                            0                                0
# 26475                            0                                0
# 28555                            0                                0
# 73419                            0                                0
# 51739                            0                                0
#
#        dum: neighbourhood: Torrance  dum: neighbourhood: Topanga  \
# 4281                              0                            0
# 36339                             0                            0
# 53913                             0                            0
# 72747                             0                            0
# 69751                             0                            0
# ...                             ...                          ...
# 43562                             0                            0
# 26475                             0                            0
# 28555                             0                            0
# 73419                             0                            0
# 51739                             0                            0
#
#        dum: neighbourhood: Tompkinsville  dum: neighbourhood: Toluca Lake  \
# 4281                                   0                                0
# 36339                                  0                                0
# 53913                                  0                                0
# 72747                                  0                                0
# 69751                                  0                                0
# ...                                  ...                              ...
# 43562                                  0                                0
# 26475                                  0                                0
# 28555                                  0                                0
# 73419                                  0                                0
# 51739                                  0                                0
#
#        dum: neighbourhood: Times Square/Theatre District  \
# 4281                                                   0
# 36339                                                  0
# 53913                                                  0
# 72747                                                  0
# 69751                                                  0
# ...                                                  ...
# 43562                                                  0
# 26475                                                  0
# 28555                                                  0
# 73419                                                  0
# 51739                                                  0
#
#        dum: neighbourhood: Throgs Neck  dum: neighbourhood: Theater District  \
# 4281                                 0                                     0
# 36339                                0                                     0
# 53913                                0                                     0
# 72747                                0                                     0
# 69751                                0                                     0
# ...                                ...                                   ...
# 43562                                0                                     0
# 26475                                0                                     0
# 28555                                0                                     0
# 73419                                0                                     0
# 51739                                0                                     0
#
#        dum: neighbourhood: The Rockaways  dum: neighbourhood: The Castro  \
# 4281                                   0                               0
# 36339                                  0                               0
# 53913                                  0                               0
# 72747                                  0                               0
# 69751                                  0                               0
# ...                                  ...                             ...
# 43562                                  0                               0
# 26475                                  0                               0
# 28555                                  0                               0
# 73419                                  0                               0
# 51739                                  0                               0
#
#        dum: neighbourhood: The Bronx  dum: neighbourhood: Tenderloin  \
# 4281                               0                               0
# 36339                              0                               0
# ...
#
#        amenities: Fire extinguisher  amenities: Family/kid friendly  \
# 4281                              0                               0
# 36339                             0                               0
# 53913                             0                               0
# 72747                             0                               0
# 69751                             0                               1
# ...                             ...                             ...
# 43562                             0                               0
# 26475                             1                               0
# 28555                             0                               0
# 73419                             1                               0
# 51739                             0                               1
#
#        amenities: Extra pillows and blankets  amenities: Ethernet connection  \
# 4281                                       0                               0
# 36339                                      0                               0
# 53913                                      0                               0
# 72747                                      0                               0
# 69751                                      0                               0
# ...                                      ...                             ...
# 43562                                      0                               0
# 26475                                      1                               0
# 28555                                      0                               0
# 73419                                      0                               0
# 51739                                      0                               0
#
#        amenities: Essentials  amenities: Elevator in building  \
# 4281                       1                                0
# 36339                      1                                0
# 53913                      1                                0
# 72747                      1                                0
# 69751                      1                                0
# ...                      ...                              ...
# 43562                      0                                0
# 26475                      1                                0
# 28555                      1                                0
# 73419                      1                                0
# 51739                      0                                0
#
#        amenities: Elevator  amenities: EV charger  amenities: Dryer  \
# 4281                     0                      0                 0
# 36339                    0                      0                 1
# 53913                    0                      0                 0
# 72747                    0                      0                 1
# 69751                    1                      0                 0
# ...                    ...                    ...               ...
# 43562                    0                      0                 0
# 26475                    1                      0                 1
# 28555                    0                      0                 1
# 73419                    0                      0                 1
# 51739                    0                      0                 0
#
#        amenities: Doorman Entry  amenities: Doorman  amenities: Dog(s)  \
# 4281                          0                   0                  0
# 36339                         0                   0                  0
# 53913                         0                   0                  0
# 72747                         0                   0                  0
# 69751                         0                   0                  1
# ...                         ...                 ...                ...
# 43562                         0                   0                  0
# 26475                         0                   0                  0
# 28555                         0                   0                  0
# 73419                         0                   0                  0
# 51739                         0                   0                  0
#
#        amenities: Dishwasher  amenities: Dishes and silverware  \
# 4281                       0                                 0
# 36339                      0                                 0
# 53913                      0                                 0
# 72747                      0                                 0
# 69751                      0                                 0
# ...                      ...                               ...
# 43562                      0                                 0
# 26475                      1                                 1
# 28555                      0                                 0
# 73419                      0                                 0
# 51739                      0                                 0
#
#        amenities: Disabled parking spot  amenities: Crib  \
# 4281                                  0                0
# 36339                                 0                0
# 53913                                 0                0
# 72747                                 0                0
# 69751                                 0                0
# ...                                 ...              ...
# 43562                                 0                0
# 26475                                 0                0
# 28555                                 0                0
# 73419                                 0                0
# 51739                                 0                0
#
#        amenities: Cooking basics  amenities: Coffee maker  \
# 4281                           0                        0
# 36339                          0                        0
# 53913                          0                        0
# 72747                          0                        0
# 69751                          0                        0
# ...                          ...                      ...
# 43562                          0                        0
# 26475                          1                        1
# 28555                          0                        0
# 73419                          0                        0
# 51739                          0                        0
#
#        amenities: Cleaning before checkout  amenities: Children’s dinnerware  \
# 4281                                     0                                 0
# 36339                                    0                                 0
# 53913                                    0                                 0
# 72747                                    0                                 0
# 69751                                    0                                 0
# ...                                    ...                               ...
# 43562                                    0                                 0
# 26475                                    0                                 0
# 28555                                    0                                 0
# 73419                                    0                                 0
# 51739                                    0                                 0
#
#        amenities: Children’s books and toys  amenities: Changing table  \
# 4281                                      0                          0
# 36339                                     0                          0
# 53913                                     0                          0
# 72747                                     0                          0
# 69751                                     0                          0
# ...                                     ...                        ...
# 43562                                     0                          0
# 26475                                     0                          0
# 28555                                     0                          0
# 73419                                     0                          0
# 51739                                     0                          0
#
#        amenities: Cat(s)  amenities: Carbon monoxide detector  \
# 4281                   0                                    1
# 36339                  0                                    0
# 53913                  0                                    0
# 72747                  0                                    1
# 69751                  0                                    1
# ...                  ...                                  ...
# 43562                  0                                    0
# 26475                  0                                    1
# 28555                  0                                    1
# 73419                  0                                    0
# 51739                  0                                    0
#
#        amenities: Cable TV  amenities: Buzzer/wireless intercom  \
# 4281                     0                                    0
# 36339                    0                                    0
# 53913                    0                                    1
# 72747                    0                                    0
# 69751                    0                                    0
# ...                    ...                                  ...
# 43562                    0                                    0
# 26475                    0                                    1
# 28555                    0                                    0
# 73419                    0                                    0
# 51739                    0                                    0
#
#        amenities: Breakfast  amenities: Bed linens  amenities: Beachfront  \
# 4281                      0                      0                      0
# 36339                     0                      0                      0
# 53913                     0                      0                      0
# 72747                     0                      0                      0
# 69751                     0                      0                      0
# ...                     ...                    ...                    ...
# 43562                     0                      0                      0
# 26475                     1                      1                      0
# 28555                     0                      0                      0
# 73419                     0                      0                      0
# 51739                     0                      0                      0
#
#        amenities: Beach essentials  amenities: Bathtub with shower chair  \
# 4281                             0                                     0
# 36339                            0                                     0
# 53913                            0                                     0
# 72747                            0                                     0
# 69751                            0                                     0
# ...                            ...                                   ...
# 43562                            0                                     0
# 26475                            0                                     0
# 28555                            0                                     0
# 73419                            0                                     0
# 51739                            0                                     0
#
#        amenities: Bathtub  amenities: Babysitter recommendations  \
# 4281                    0                                      0
# 36339                   0                                      0
# 53913                   0                                      0
# 72747                   0                                      0
# 69751                   0                                      0
# ...                   ...                                    ...
# 43562                   0                                      0
# 26475                   1                                      0
# 28555                   0                                      0
# 73419                   0                                      0
# 51739                   0                                      0
#
#        amenities: Baby monitor  amenities: Baby bath  amenities: BBQ grill  \
# 4281                         0                     0                     0
# 36339                        0                     0                     0
# 53913                        0                     0                     0
# 72747                        0                     0                     0
# 69751                        0                     0                     0
# ...                        ...                   ...                   ...
# 43562                        0                     0                     0
# 26475                        0                     0                     0
# 28555                        0                     0                     0
# 73419                        0                     0                     0
# 51739                        0                     0                     0
#
#        amenities: Air purifier  amenities: Air conditioning  \
# 4281                         0                            0
# 36339                        0                            0
# 53913                        0                            1
# 72747                        0                            1
# 69751                        0                            1
# ...                        ...                          ...
# 43562                        0                            0
# 26475                        0                            0
# 28555                        0                            0
# 73419                        0                            0
# 51739                        0                            1
#
#        amenities: Accessible-height toilet  amenities: Accessible-height bed  \
# 4281                                     0                                 0
# 36339                                    0                                 0
# 53913                                    0                                 0
# 72747                                    0                                 0
# 69751                                    0                                 0
# ...                                    ...                               ...
# 43562                                    0                                 0
# 26475                                    0                                 0
# 28555                                    0                                 0
# 73419                                    0                                 0
# 51739                                    0                                 0
#
#        amenities: 24-hour check-in  accommodates
# 4281                             0             2
# 36339                            1            12
# 53913                            0             3
# 72747                            0             1
# 69751                            0             4
# ...                            ...           ...
# 43562                            0             2
# 26475                            1             2
# 28555                            0             3
# 73419                            1             2
# 51739                            0             2
#
# [13896 rows x 764 columns]

# %%
test[test.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [review_scores_rating, number_of_reviews, longitude, log_price, latitude, instant_bookable, host_since, host_response_rate, host_identity_verified, host_has_profile_pic, dum: room_type: Shared room, dum: room_type: Private room, dum: property_type: other, dum: property_type: Villa, dum: property_type: Townhouse, dum: property_type: Other, dum: property_type: Loft, dum: property_type: House, dum: property_type: Guesthouse, dum: property_type: Guest suite, dum: property_type: Dorm, dum: property_type: Condominium, dum: property_type: Camper/RV, dum: property_type: Bungalow, dum: property_type: Bed & Breakfast, dum: neighbourhood: no data, dum: neighbourhood: Wrigleyville, dum: neighbourhood: Woodside, dum: neighbourhood: Woodridge, dum: neighbourhood: Woodley Park, dum: neighbourhood: Woodlawn, dum: neighbourhood: Woodland Hills/Warner Center, dum: neighbourhood: Woodland, dum: neighbourhood: Woodhaven, dum: neighbourhood: Winthrop, dum: neighbourhood: Winnetka, dum: neighbourhood: Windsor Terrace, dum: neighbourhood: Wilmington, dum: neighbourhood: Williamsburg, dum: neighbourhood: Williamsbridge, dum: neighbourhood: Wicker Park, dum: neighbourhood: Whittier, dum: neighbourhood: Whitestone, dum: neighbourhood: Westwood, dum: neighbourhood: Westside, dum: neighbourhood: Westlake, dum: neighbourhood: Western Addition/NOPA, dum: neighbourhood: Westerleigh, dum: neighbourhood: Westchester/Playa Del Rey, dum: neighbourhood: Westchester Village, dum: neighbourhood: West Village, dum: neighbourhood: West Town/Noble Square, dum: neighbourhood: West Town, dum: neighbourhood: West Roxbury, dum: neighbourhood: West Ridge, dum: neighbourhood: West Puente Valley, dum: neighbourhood: West Portal, dum: neighbourhood: West Los Angeles, dum: neighbourhood: West Loop/Greektown, dum: neighbourhood: West Lawn, dum: neighbourhood: West Hollywood, dum: neighbourhood: West Hills, dum: neighbourhood: West Farms, dum: neighbourhood: West End, dum: neighbourhood: West Elsdon, dum: neighbourhood: West Covina, dum: neighbourhood: West Brighton, dum: neighbourhood: West Athens, dum: neighbourhood: West Adams, dum: neighbourhood: Wesley Heights, dum: neighbourhood: Watts, dum: neighbourhood: Watertown, dum: neighbourhood: Washington Park, dum: neighbourhood: Washington Highlands, dum: neighbourhood: Washington Heights, dum: neighbourhood: Wakefield, dum: neighbourhood: Visitacion Valley, dum: neighbourhood: Vinegar Hill, dum: neighbourhood: Venice, dum: neighbourhood: Van Nuys, dum: neighbourhood: Van Nest, dum: neighbourhood: Valley Village, dum: neighbourhood: Valley Glen, dum: neighbourhood: Utopia, dum: neighbourhood: Uptown, dum: neighbourhood: Upper West Side, dum: neighbourhood: Upper East Side, dum: neighbourhood: University Heights, dum: neighbourhood: Union Square, dum: neighbourhood: Ukrainian Village, dum: neighbourhood: U Street Corridor, dum: neighbourhood: Twining, dum: neighbourhood: Twin Peaks, dum: neighbourhood: Truxton Circle, dum: neighbourhood: Trinidad, dum: neighbourhood: Tribeca, dum: neighbourhood: Tremont, dum: neighbourhood: Tottenville, dum: neighbourhood: Torrance, dum: neighbourhood: Topanga, ...]
# Index: []

# %%
def show_metrics(prediction_test, prediction_train, y_test, y_train):
    MAE = round(metrics.mean_absolute_error(y_test, prediction_test), 2)
    MSE = round(metrics.mean_squared_error(y_test, prediction_test), 2)
    RMSE = round(np.sqrt(metrics.mean_squared_error(y_test, prediction_test)), 2)
    RMSE_ratio_test= round(np.sqrt(metrics.mean_squared_error(y_test, prediction_test)) / np.mean(y_test),3)
    RMSE_ratio_train = round(np.sqrt(metrics.mean_squared_error(y_train, prediction_train)) / np.mean(y_train),3)
    R_2_test = round(metrics.explained_variance_score(y_test, prediction_test), 2)
    R_2_train = round(metrics.explained_variance_score(y_train, prediction_train), 2)
    
    metrics_data = pd.DataFrame(data = [MAE, MSE, RMSE, RMSE_ratio_test, 
                                    RMSE_ratio_train, R_2_test, R_2_train]).T
    
    metrics_data.columns = ['MAE', 'MSE', 'RMSE', 'RMSE_ratio_test', 
                                    'RMSE_ratio_train', 'R_2_test', 'R_2_train']
    display(metrics_data)
           


def analysis(model, X_train, X_test, y_train, y_test):
    
    prediction_test = model.predict(X_test)
    prediction_train = model.predict(X_train)
        
    
    show_metrics(prediction_test, prediction_train, y_test, y_train)
    
    sns.regplot(x = y_test, y = prediction_test, fit_reg=False)
    plt.title('Prediction and real')
    plt.show()

    sns.distplot(y_test - prediction_test, bins = 50)
    plt.title('Error variance')
    plt.show()

# %% [markdown]
# ### Linear Regression
# Linear regression is a linear model, e.g. a model that assumes a linear relationship between the input variables (x) and the single output variable (y). ... Different techniques can be used to prepare or train the linear regression equation from data, the most common of which is called Ordinary Least Squares.

# %%
lm = LinearRegression(
        n_jobs = -1,
        normalize = True
)

lm.fit(df_d.drop('log_price', axis = 1), df_d['log_price'])

comment = ''

analysis(
    model = lm, 
    X_train = df_d.drop('log_price', axis = 1), 
    X_test = test.drop('log_price', axis = 1), 
    y_train = df_d['log_price'], 
    y_test = test['log_price']
)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning:
#
# 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#    MAE   MSE  RMSE  RMSE_ratio_test  RMSE_ratio_train  R_2_test  R_2_train
# 0  0.3  0.16  0.41            0.085             0.084      0.68       0.68
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# ### Random Forest Regressor
# A Random Forest is an ensemble technique capable of performing both regression and classification tasks with the use of multiple decision trees and a technique called Bootstrap and Aggregation, commonly known as bagging. The basic idea behind this is to combine multiple decision trees in determining the final output rather than relying on individual decision trees.

# %%
rfm = RandomForestRegressor(
          max_depth = 10,
          n_jobs = -1, 
          random_state = 101,
          n_estimators = 700
    
)
rfm.fit(df_d.drop('log_price', axis = 1), df_d['log_price'])

comment = ''

analysis(
    model = rfm, 
    X_train = df_d.drop('log_price', axis = 1), 
    X_test = test.drop('log_price', axis = 1), 
    y_train = df_d['log_price'], 
    y_test = test['log_price']
)
# Out:
#    MAE   MSE  RMSE  RMSE_ratio_test  RMSE_ratio_train  R_2_test  R_2_train
# 0  0.3  0.16   0.4            0.084             0.077      0.68       0.73
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# ### Gradient Boosting Algorithm
# Gradient boosting is a machine learning technique for regression, classification and other tasks, which produces a prediction model in the form of an ensemble of weak prediction models, typically decision trees.

# %%
gbr_model = GradientBoostingRegressor(random_state = 101)
gbr_model.fit(df_d.drop('log_price', axis = 1), df_d['log_price'])

comment = ''

analysis(
    model = gbr_model, 
    X_train = df_d.drop('log_price', axis = 1), 
    X_test = test.drop('log_price', axis = 1), 
    y_train = df_d['log_price'], 
    y_test = test['log_price']
)
# Out:
#    MAE   MSE  RMSE  RMSE_ratio_test  RMSE_ratio_train  R_2_test  R_2_train
# 0  0.3  0.16  0.41            0.085             0.085      0.68       0.68
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# ### Dense Neural Networks
# Neural networks, also known as artificial neural networks (ANNs) or simulated neural networks (SNNs), are a subset of machine learning and are at the heart of deep learning algorithms. Their name and structure are inspired by the human brain, mimicking the way that biological neurons signal to one another.

# %% [markdown]
# **MinMaxScaler** :
# MinMaxScaler preserves the shape of the original distribution. It doesn't meaningfully change the information embedded in the original data. Note that MinMaxScaler doesn't reduce the importance of outliers. The default range for the feature returned by MinMaxScaler is 0 to 1.

# %%
#scaling
scaler = MinMaxScaler()
scaler.fit(df_d.drop('log_price', axis = 1))
X_train_sc = scaler.transform(df_d.drop('log_price', axis = 1).values)
X_test_sc = scaler.transform(test.drop('log_price', axis = 1).values)
y_train = df_d['log_price'].values
y_test = test['log_price'].values
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning:
#
# X does not have valid feature names, but MinMaxScaler was fitted with feature names
#
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning:
#
# X does not have valid feature names, but MinMaxScaler was fitted with feature names

# %%
nn_model1 = Sequential()


es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)


nn_model1.add(Dense(64, activation = 'relu'))
nn_model1.add(Dropout(0.1))
nn_model1.add(Dense(1))

nn_model1.compile(
    optimizer='rmsprop',
    loss='mse'
)

nn_model1.fit(
    x = X_train_sc,
    y = y_train,
    epochs = 100,
    validation_data=(X_test_sc, y_test), 
    batch_size = 128,
    callbacks=[es]
)


pd.DataFrame(nn_model1.history.history).plot()
plt.show()

analysis(model = nn_model1, 
         X_train = X_train_sc, 
         X_test = X_test_sc, 
         y_train = y_train, 
         y_test = y_test)
# Out:
# Epoch 1/100
# 326/326 [==============================] - 2s 5ms/step - loss: 1.1071 - val_loss: 0.2360
# Epoch 2/100
# 326/326 [==============================] - 1s 4ms/step - loss: 0.2982 - val_loss: 0.1866
# Epoch 3/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2763 - val_loss: 0.1820
# Epoch 4/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2696 - val_loss: 0.1903
# Epoch 5/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2650 - val_loss: 0.1741
# Epoch 6/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2576 - val_loss: 0.1699
# Epoch 7/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2520 - val_loss: 0.1702
# Epoch 8/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2481 - val_loss: 0.1648
# Epoch 9/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2467 - val_loss: 0.1894
# Epoch 10/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2400 - val_loss: 0.1635
# Epoch 11/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2375 - val_loss: 0.1889
# Epoch 12/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2341 - val_loss: 0.1646
# Epoch 13/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2318 - val_loss: 0.1623
# Epoch 14/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2289 - val_loss: 0.1605
# Epoch 15/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2244 - val_loss: 0.1604
# Epoch 16/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2214 - val_loss: 0.1758
# Epoch 17/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2188 - val_loss: 0.1592
# Epoch 18/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2159 - val_loss: 0.1579
# Epoch 19/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2134 - val_loss: 0.1667
# Epoch 20/100
# 326/326 [==============================] - 1s 2ms/step - loss: 0.2114 - val_loss: 0.1582
# Epoch 21/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2071 - val_loss: 0.1688
# Epoch 22/100
# 326/326 [==============================] - 1s 3ms/step - loss: 0.2073 - val_loss: 0.1604
# Epoch 22: early stopping
# 435/435 [==============================] - 1s 1ms/step
# 1303/1303 [==============================] - 1s 912us/step
#    MAE   MSE  RMSE  RMSE_ratio_test  RMSE_ratio_train  R_2_test  R_2_train
# 0  0.3  0.16   0.4            0.084             0.081      0.69       0.71
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24128\3277752383.py in <module>
#      27 plt.show()
#      28
# ---> 29 analysis(model = nn_model1,
#      30          X_train = X_train_sc,
#      31          X_test = X_test_sc,
#
# ~\AppData\Local\Temp\ipykernel_24128\4124505080.py in analysis(model, X_train, X_test, y_train, y_test)
#      29     plt.show()
#      30
# ---> 31     sns.distplot(y_test - prediction_test, bins = 50)
#      32     plt.title('Error variance')
#      33     plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2685     if kde:
#    2686         kde_color = kde_kws.pop("color", color)
# -> 2687         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#    2688         if kde_color != color:
#    2689             kde_kws["color"] = kde_color
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, warn_singular, **kwargs)
#    1768             plot_kws["color"] = color
#    1769
# -> 1770         p.plot_univariate_density(
#    1771             multiple=multiple,
#    1772             common_norm=common_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in plot_univariate_density(self, multiple, common_norm, common_grid, warn_singular, fill, legend, estimate_kws, **plot_kws)
#     926
#     927         # Do the computation
# --> 928         densities = self._compute_univariate_density(
#     929             self.data_variable,
#     930             common_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale, warn_singular)
#     301         densities = {}
#     302
# --> 303         for sub_vars, sub_data in self.iter_data("hue", from_comp_data=True):
#     304
#     305             # Extract the data points from this sub set and remove nulls
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in comp_data(self)
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057                 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1058
#    1059                 if axis.get_scale() == "log":
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1691             self._setitem_with_indexer_split_path(indexer, value, name)
#    1692         else:
# -> 1693             self._setitem_single_block(indexer, value, name)
#    1694
#    1695     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_single_block(self, indexer, value, name)
#    1932             # setting for extensionarrays that store dicts. Need to decide
#    1933             # if it's worth supporting that.
# -> 1934             value = self._align_series(indexer, Series(value))
#    1935
#    1936         elif isinstance(value, ABCDataFrame) and name != "iloc":
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2094                 if obj.ndim == 2 and is_empty_indexer(indexer[0], ser._values):
#    2095                     return ser._values.copy()
# -> 2096                 ser = ser.reindex(obj.axes[0][indexer[0]], copy=True)._values
#    2097
#    2098                 # single indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, *args, **kwargs)
#    4670                 )
#    4671             kwargs.update({"index": index})
# -> 4672         return super().reindex(**kwargs)
#    4673
#    4674     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4956         ):
#    4957             if copy:
# -> 4958                 return self.copy()
#    4959             return self
#    4960
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    6030         dtype: object
#    6031         """
# -> 6032         data = self._mgr.copy(deep=deep)
#    6033         self._clear_item_cache()
#    6034         return self._constructor(data).__finalize__(self, method="copy")
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     601             new_axes = list(self.axes)
#     602
# --> 603         res = self.apply("copy", deep=deep)
#     604
#     605         res.axes = new_axes
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     641         values = self.values
#     642         if deep:
# --> 643             values = values.copy()
#     644         return type(self)(values, placement=self._mgr_locs, ndim=self.ndim)
#     645
#
# MemoryError: Unable to allocate 1.44 GiB for an array with shape (193098816,) and data type float64

# %% [markdown]
# ********************
# ### Model comparison
# Here I have deployed four algorithms to deploy the models, now let's check the accuracy scores for these models.
#
# |Models|Accuray Score|
# |-|-|
# |Linear Regression|0.68|
# |Random Forest Regression|0.73|
# |Gradient Boosting Regressor|0.68|
# |Dense Neural Networks|0.69|
#
# According to the accuracy scores, **Random Forest Regressor** is the best model to be fitted here. So, we are going with random forest regressor model for further tuning procedure.
# ********************************

# %% [markdown]
# ### Using text data from 'description' column

# %%
df_train['description']
# Out:
# 17236    Enjoy a beautiful contemporary residence with ...
# 58369    My place is close to Don Antonio's, Metro Expo...
# 44240    Stay one block from Wrigley Field! This renova...
# 57759    This room is in the lower level of Fort Washin...
# 40254    Welcome to your home away from home! Cozy priv...
#                                ...
# 34345    Nestled under a canopy of oak trees, this 1920...
# 58878    Our comfortable 2 bedroom apt, centrally locat...
# 50162        Our lovely apartment has high ceilings and...
# 49893    Spacious, clean, and flooded with sunlight: Pe...
# 68913    A simple and sensible apartment ideal for thos...
# Name: description, Length: 41686, dtype: object

# %%
def del_punct(text):
    chars = [char for char in text if char not in string.punctuation]
    return ''.join(chars)

def del_stopwords(text):
    words = [word for word in text.split() if word.lower() not in stopwords.words('english')]
    return words

def text_preparation(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'\d+', 'somenumbers', text)
    text = del_stopwords(del_punct(text))
    return text
    
    
text_preparation('Enjoy a beautiful 67 contemporary residence with')
# Out:
# ['enjoy', 'beautiful', 'somenumbers', 'contemporary', 'residence']

# %%
bow_transformer = CountVectorizer(analyzer = text_preparation, max_features = 1500).fit(df_train['description'])
bow = bow_transformer.transform(df_train['description'])
bow.shape
# Out:
# (41686, 1500)

# %% [markdown]
# ### tf-idf transformer
# Transform a count matrix to a normalized tf or tf-idf representation. Tf means term-frequency while tf-idf means term-frequency times inverse document-frequency.

# %%
tfidf_transformer = TfidfTransformer().fit(bow)
train_tfidf = tfidf_transformer.transform(bow)

bow_test = bow_transformer.transform(df_test['description'])
test_tfidf = tfidf_transformer.transform(bow_test)

# %% [markdown]
# **Applying the tf-idf transformer on the Random forest regressor**

# %%
rfm_text = RandomForestRegressor(
    max_depth = 10, 
    n_estimators = 500,
    n_jobs = -1, 
    random_state = 101
)
rfm_text.fit(train_tfidf, df_train['log_price'])

comment = ''

analysis(
    model = rfm_text, 
    X_train = train_tfidf, 
    X_test = test_tfidf, 
    y_train = df_train['log_price'], 
    y_test = df_test['log_price']
)
# Out:
#     MAE   MSE  RMSE  RMSE_ratio_test  RMSE_ratio_train  R_2_test  R_2_train
# 0  0.47  0.38  0.61            0.129             0.121      0.27       0.35
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# ### Observation
#
# We can see that there is not much information in description of object, that can be used for price prediction, but we can try use this in general model. As an experiment we can try to create a model, that would we a stack of 2 models - prediction of text model will be used in model built on all available features as one more feature.

# %% [markdown]
# ****************
# ### Applying Stacked Regression
# Stacking Regressions is a method for forming linear combinations of different predictors to give improved prediction accuracy. The idea is to use cross-validation data and least squares under non-negativity contraints to determine the coefficients in the combination.

# %%
class StackRegression:
    
    def __init__(self, model_general, model_secondary):
        self.model_general = model_general
        self.model_secondary = model_secondary
    
    def fit_predict(self, X_train_general, X_train_secondary, y_train, X_test_general, X_test_secondary, y_test):
        self.model_secondary.fit(X_train_secondary, y_train)
        
        self.secondary_predictions_test =  self.model_secondary.predict(X_test_secondary)
        self.secondary_predictions_train =  self.model_secondary.predict(X_train_secondary)
        
        self.X_train_full = X_train_general.copy()
        self.X_train_full.assign(secondary_model_predictions = self.secondary_predictions_train)
        
        self.X_test_full = X_test_general.copy()
        self.X_test_full.assign(secondary_model_predictions = self.secondary_predictions_test)
                        
        self.model_general.fit(self.X_train_full, y_train)
        
        return self.model_general.predict(self.X_test_full)

# %%
model_general = RandomForestRegressor(
          max_depth = 10,
          n_jobs = -1, 
          random_state = 101,
          n_estimators = 700
    
)

model_for_text = RandomForestRegressor(
          max_depth = 10,
          n_jobs = -1, 
          random_state = 101,
          n_estimators = 700
    
)

stack_model = StackRegression(model_general, model_for_text)


prediction_test = stack_model.fit_predict(
    X_train_general = df_d.drop('log_price', axis = 1), 
    X_train_secondary = train_tfidf, 
    y_train = df_d['log_price'], 
    X_test_general = test.drop('log_price', axis = 1), 
    X_test_secondary = test_tfidf, 
    y_test = test['log_price']
)

prediction_train = stack_model.fit_predict(
    X_train_general = df_d.drop('log_price', axis = 1), 
    X_train_secondary = train_tfidf, 
    y_train = df_d['log_price'], 
    X_test_general = df_d.drop('log_price', axis = 1), 
    X_test_secondary = train_tfidf, 
    y_test = df_d['log_price']
)

show_metrics(prediction_test, prediction_train, y_test = test['log_price'], y_train = df_d['log_price'])


sns.regplot(x = test['log_price'], y = prediction_test, fit_reg=False)
plt.title('Prediction and real')
plt.show()

sns.distplot(test['log_price'] - prediction_test, bins = 50)
plt.title('Error variance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24128\50783621.py in <module>
#      18
#      19
# ---> 20 prediction_test = stack_model.fit_predict(
#      21     X_train_general = df_d.drop('log_price', axis = 1),
#      22     X_train_secondary = train_tfidf,
#
# ~\AppData\Local\Temp\ipykernel_24128\1353343780.py in fit_predict(self, X_train_general, X_train_secondary, y_train, X_test_general, X_test_secondary, y_test)
#       6
#       7     def fit_predict(self, X_train_general, X_train_secondary, y_train, X_test_general, X_test_secondary, y_test):
# ----> 8         self.model_secondary.fit(X_train_secondary, y_train)
#       9
#      10         self.secondary_predictions_test =  self.model_secondary.predict(X_test_secondary)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     448             # parallel_backend contexts set at a higher level,
#     449             # since correctness does not rely on using threads.
# --> 450             trees = Parallel(
#     451                 n_jobs=self.n_jobs,
#     452                 verbose=self.verbose,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# ~\anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# ~\anaconda3\lib\multiprocessing\pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __call__(self, *args, **kwargs)
#     618     def __call__(self, *args, **kwargs):
#     619         try:
# --> 620             return self.func(*args, **kwargs)
#     621         except KeyboardInterrupt as e:
#     622             # We capture the KeyboardInterrupt and reraise it as
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     183             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     184
# --> 185         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     186     else:
#     187         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1313         """
#    1314
# -> 1315         super().fit(
#    1316             X,
#    1317             y,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._add_node()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._resize_c()
#
# sklearn\tree\_utils.pyx in sklearn.tree._utils.safe_realloc()
#
# MemoryError: could not allocate 57344 bytes

# %% [markdown]
# ### Observation
#
# This model doesn't have an advantage over more simple models. So for final submission I prefer to use just simple RFR

# %% [markdown]
# ### Validation Process

# %%
val_data_for_model = columns_standardization(processing(validation_df))
val_data_for_model

# %%
val_data_for_model[val_data_for_model.isnull().any(axis=1)]

# %% [markdown]
# ### Final Model Deployment

# %%
analysis(
    model = rfm, 
    X_train = df_d.drop('log_price', axis = 1), 
    X_test = val_data_for_model.drop('log_price', axis = 1), 
    y_train = df_d['log_price'], 
    y_test = val_data_for_model['log_price']
)

# %% [markdown]
# ************************
# ## Conclusion
# * Here I have applied four different algorithms along with the Neural Networks.
# * But the Random Forest Regressor stand out to be the best model among all those implemented models based on the accuracy scores.
# * After the tf-idf transformation on Random Forest Regressor, the models accuracy decreased, so, I will suggest rather not to use the transformation on Random Forest.
# * Also after the stacked regression process, the model does not provides too much of accuracy.
# * So, for this project, the best model is only **Random forest regressor** without any kind of transformation or stacked regression.
#
# ******************************
# ### Hope you like this project. Thank you!
